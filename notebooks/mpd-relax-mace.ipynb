# %%
import ll

ll.pretty()
# Out:
# TensorBoard/TensorBoardX not found. Disabling TensorBoardLogger. Please install TensorBoard with `pip install tensorboard` or TensorBoardX with `pip install tensorboardx` to enable TensorBoard logging.

# %%
from pathlib import Path

id = "asz41quw"
base_path = Path("/workspaces/repositories/jmp-peft/lltrainer")
print(base_path)

path = base_path / id / "predictions"
print(path)

# !ls -l {path} | head -n 10
# Out:
# /workspaces/repositories/jmp-peft/lltrainer
# /workspaces/repositories/jmp-peft/lltrainer/asz41quw/predictions
# ⠁ updating pypi packages in 'default'
# ⠁ updating pypi packages in 'default'm────────────────────]    0/1
# ⠁ updating pypi packages in 'default'm────────────────────]    0/1
# ⠁ updating pypi packages in 'default'm────────────────────]    0/1    building: /
# ⠉ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠉ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠙ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠙ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠚ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠚ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠒ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠒ updating pypi packages in 'default'm────────────────────]    0/1    building ed
# ⠂ updating pypi packages in 'default'                                               2mbuilding ed
# ⠂ updating pypi packages in 'default'm────────────────────]    0/1
# ⠂ updating pypi packages in 'default'm────────────────────]    0/1
# ⠂ updating pypi packages in 'default'm────────────────────]    0/1    jmp-peft
# total 21508updating pypi packages in 'default'                                               2m
# -rw-r--r-- 1 root root  19616 May 28 00:43 prediction_rank0_batch0.pt
# -rw-r--r-- 1 root root   5036 May 28 01:00 prediction_rank0_batch1000.pt
# -rw-r--r-- 1 root root   5036 May 28 01:00 prediction_rank0_batch1001.pt
# -rw-r--r-- 1 root root  10732 May 28 01:00 prediction_rank0_batch1002.pt
# -rw-r--r-- 1 root root  18476 May 28 01:00 prediction_rank0_batch1003.pt
# -rw-r--r-- 1 root root  20460 May 28 01:00 prediction_rank0_batch1004.pt
# -rw-r--r-- 1 root root   9388 May 28 01:00 prediction_rank0_batch1005.pt
# -rw-r--r-- 1 root root   8108 May 28 01:00 prediction_rank0_batch1006.pt
# -rw-r--r-- 1 root root  13420 May 28 01:00 prediction_rank0_batch1007.pt

# %%
pt_files = list(path.glob("*.pt"))
# print(pt_files)
# Sort by batch idx
pt_files.sort(key=lambda x: int(x.stem.rsplit("_", 1)[1][len("batch") :]))

# %%
import pandas as pd
from matbench_discovery import Key
from matbench_discovery.data import DATA_FILES

df_summary = pd.read_csv(DATA_FILES.wbm_summary).set_index(Key.mat_id)
df_summary
# Out:
# Loading 'wbm_summary' from cached file at '/root/.cache/matbench-discovery/1.0.0/wbm/2023-12-13-wbm-summary.csv.gz'
#                  formula  n_sites  volume  uncorrected_energy  \
# material_id
# wbm-1-1           Ac6 U2      8.0  317.48             -42.954
# wbm-1-2          Ac1 Th3      4.0  137.42             -25.858
# wbm-1-3           Ac1 U3      4.0  100.81             -34.934
# wbm-1-4      Ag2 Au1 Hg1      4.0   76.26              -9.114
# wbm-1-5      Ag2 Ba1 La1      4.0  124.15             -13.222
# ...                  ...      ...     ...                 ...
# wbm-5-23304   I2 Te2 Zr2      6.0  203.35             -31.883
# wbm-5-23305      Tl2 Zr2      4.0   92.16             -21.578
# wbm-5-23306  Pb2 Tm1 Zr1      4.0  108.43             -21.085
# wbm-5-23307  Pb2 Tm2 Zr2      6.0  171.01             -35.591
# wbm-5-23308  Pb2 Yb1 Zr1      4.0  113.16             -18.109
#
#              e_form_per_atom_wbm  e_above_hull_wbm  bandgap_pbe  \
# material_id
# wbm-1-1                    0.550             0.550          0.0
# wbm-1-2                    0.125             0.125          0.0
# wbm-1-3                    0.768             0.768          0.0
# wbm-1-4                    0.030             0.063          0.0
# wbm-1-5                   -0.178             0.100          0.0
# ...                          ...               ...          ...
# wbm-5-23304               -0.911             0.021          0.0
# wbm-5-23305                0.062             0.141          0.0
# wbm-5-23306               -0.163             0.126          0.0
# wbm-5-23307               -0.356            -0.059          0.0
# wbm-5-23308               -0.157             0.219          0.0
#
#             wyckoff_spglib_initial_structure  uncorrected_energy_from_cse  \
# material_id
# wbm-1-1                 A3B_hP8_194_h_c:Ac-U                   -42.955387
# wbm-1-2               AB3_tI8_139_a_bd:Ac-Th                   -25.858142
# wbm-1-3                AB3_tI8_139_a_bd:Ac-U                   -34.934045
# wbm-1-4         A2BC_cF16_225_c_a_b:Ag-Au-Hg                    -9.114021
# wbm-1-5         A2BC_cF16_225_c_a_b:Ag-Ba-La                   -13.222006
# ...                                      ...                          ...
# wbm-5-23304         ABC_oP6_59_a_a_b:I-Te-Zr                   -31.885257
# wbm-5-23305             AB_cP2_221_a_b:Tl-Zr                   -21.579593
# wbm-5-23306      A2BC_tI8_139_d_a_b:Pb-Tm-Zr                   -21.081939
# wbm-5-23307       ABC_tP6_129_c_c_a:Pb-Tm-Zr                   -35.593295
# wbm-5-23308      A2BC_tI8_139_d_a_b:Pb-Yb-Zr                   -18.108613
#
#              e_correction_per_atom_mp2020  e_correction_per_atom_mp_legacy  \
# material_id
# wbm-1-1                             0.000                              0.0
# wbm-1-2                             0.000                              0.0
# wbm-1-3                             0.000                              0.0
# wbm-1-4                             0.000                              0.0
# wbm-1-5                             0.000                              0.0
# ...                                   ...                              ...
# wbm-5-23304                        -0.267                              0.0
# wbm-5-23305                         0.000                              0.0
# wbm-5-23306                         0.000                              0.0
# wbm-5-23307                         0.000                              0.0
# wbm-5-23308                         0.000                              0.0
#
#              e_form_per_atom_uncorrected  e_form_per_atom_mp2020_corrected  \
# material_id
# wbm-1-1                         0.544327                          0.544327
# wbm-1-2                         0.126190                          0.126190
# wbm-1-3                         0.765339                          0.765339
# wbm-1-4                         0.032195                          0.032195
# wbm-1-5                        -0.175452                         -0.175452
# ...                                  ...                               ...
# wbm-5-23304                    -0.926076                         -1.193076
# wbm-5-23305                     0.060252                          0.060252
# wbm-5-23306                    -0.158310                         -0.158310
# wbm-5-23307                    -0.353516                         -0.353516
# wbm-5-23308                    -0.149028                         -0.149028
#
#              e_above_hull_mp2020_corrected_ppd_mp  \
# material_id
# wbm-1-1                                  0.544310
# wbm-1-2                                  0.126152
# wbm-1-3                                  0.765340
# wbm-1-4                                  0.062869
# wbm-1-5                                  0.092193
# ...                                           ...
# wbm-5-23304                              0.019279
# wbm-5-23305                              0.139899
# wbm-5-23306                              0.113990
# wbm-5-23307                             -0.020498
# wbm-5-23308                              0.192635
#
#              site_stats_fingerprint_init_final_norm_diff  \
# material_id
# wbm-1-1                                         0.128576
# wbm-1-2                                         0.051626
# wbm-1-3                                         0.061782
# wbm-1-4                                         0.067272
# wbm-1-5                                         0.050158
# ...                                                  ...
# wbm-5-23304                                     0.352661
# wbm-5-23305                                     0.029811
# wbm-5-23306                                     0.546470
# wbm-5-23307                                     0.125237
# wbm-5-23308                                     0.939303
#
#                            wyckoff_spglib  unique_prototype
# material_id
# wbm-1-1              A3B_hP8_194_h_c:Ac-U              True
# wbm-1-2            AB3_tI8_139_a_bd:Ac-Th              True
# wbm-1-3             AB3_tI8_139_a_bd:Ac-U              True
# wbm-1-4      A2BC_cF16_225_c_a_b:Ag-Au-Hg              True
# wbm-1-5      A2BC_cF16_225_c_a_b:Ag-Ba-La              True
# ...                                   ...               ...
# wbm-5-23304      ABC_oP6_59_a_a_b:I-Te-Zr              True
# wbm-5-23305          AB_cP2_221_a_b:Tl-Zr             False
# wbm-5-23306   A2BC_tI8_139_d_a_b:Pb-Tm-Zr              True
# wbm-5-23307    ABC_tP6_129_c_c_a:Pb-Tm-Zr              True
# wbm-5-23308   A2BC_tI8_139_d_a_b:Pb-Yb-Zr              True
#
# [256963 rows x 17 columns]

# %%
from typing import Any

import torch


def correct_energy(
    model_pred: float,
    batch: dict[str, Any],
):
    """
    To avoid confusion for anyone reading this code, we calculate the formation energy MAE
    here and report it as the MAE for the energy above the convex hull prediction. The
    former is more easily calculated but the two quantities are the same. The formation
    energy of a material is the difference in energy between a material and its
    constituent elements in their standard states. The distance to the convex hull is
    defined as the difference between a material's formation energy and the minimum
    formation energy of all possible stable materials made from the same elements. Since
    the formation energy of a material is used to calculate the distance to the convex
    hull, the error of a formation energy prediction directly determines the error in the
    distance to the convex hull prediction.

    A further point of clarification: whenever we say convex hull distance we mean
    the signed distance that is positive for thermodynamically unstable materials above
    the hull and negative for stable materials below it.

    See https://github.com/pbenner/matbench-discovery/blob/818173c68f434b02d4139c7fb032bd703af83fe9/matbench_discovery/preds.py#L221-L234
    From Matbench discovery:

    # dataframe of all models' energy above convex hull (EACH) predictions (eV/atom)
    df_each_pred = pd.DataFrame()
    for model in models:
        df_each_pred[model] = (
            df_preds[Key.each_true] + df_preds[model] - df_preds[Key.e_form]
        )
    """

    y_formation_pred = model_pred

    # each_true => batch["y_above_hull"] => e_above_hull_mp2020_corrected_ppd_mp
    # e_form => batch["y_formation"] => e_form_per_atom_mp2020_corrected

    y_above_hull_true = batch["y_above_hull"].item()
    y_formation_true = batch["y_formation"].item()

    y_above_hull_pred = y_above_hull_true + y_formation_pred - y_formation_true
    return (y_formation_true, y_above_hull_true), (y_above_hull_pred, y_formation_pred)

# %%
import rich
from pymatgen.core.structure import Structure
from pymatgen.io.ase import AseAtomsAdaptor


print(len(pt_files))
file = pt_files[1]

data = torch.load(file, map_location="cpu")
structure = Structure.from_dict(data["relax_out"]["final_structure"])
rich.print(structure)

# Convert to ASE Atoms
ase_adaptor = AseAtomsAdaptor()
atoms = ase_adaptor.get_atoms(structure)
rich.print(atoms)
# Out:
# 1024
# Full Formula (Pr8 Os4)
# Reduced Formula: Pr2Os
# abc   :   4.351437   7.484743   8.922546
# angles:  90.000273  90.000000  90.000000
# pbc   :       True       True       True
# Sites (12)
#   #  SP           a         b         c
# ---  ----  --------  --------  --------
#   0  Pr    0.75006   0.862285  0.909169
#   1  Pr    0.251342  0.509901  0.829039
#   2  Pr    0.250347  0.008877  0.672269
#   3  Pr    0.748732  0.361469  0.592793
#   4  Pr    0.250021  0.643285  0.405377
#   5  Pr    0.749121  0.994927  0.32847
#   6  Pr    0.748129  0.493214  0.166272
#   7  Pr    0.250103  0.143267  0.08752
#   8  Os    0.74935   0.260877  0.910879
#   9  Os    0.750338  0.757472  0.587288
#  10  Os    0.24892   0.244319  0.414604
#  11  Os    0.250938  0.74655   0.082958
# Atoms(symbols='Pr8Os4', pbc=True, cell=[[4.351437091827393, 0.0, 2.664486925282823e-16], [0.0, 7.484743118286133,
# -3.5606699384516105e-05], [0.0, 0.0, 8.92254638671875]])

# %%
from typing import cast
import rich

from matbench_discovery.energy import get_e_form_per_atom
from pymatgen.core import Structure
from pymatgen.entries.computed_entries import ComputedStructureEntry
from mace.calculators import mace_mp
from pymatgen.io.ase import AseAtomsAdaptor

print(len(pt_files))
file = pt_files[1]


data = torch.load(file, map_location="cpu")

device = torch.device("cpu")
mace = mace_mp("https://tinyurl.com/5yyxdm76", device="cpu")


def run_mace(model_out: dict[str, Any]):
    final_structure = cast(
        Structure, Structure.from_dict(model_out["relax_out"]["final_structure"])
    )
    atoms = AseAtomsAdaptor().get_atoms(final_structure)
    atoms.set_calculator(mace)
    energy = atoms.get_potential_energy()

    cse = ComputedStructureEntry(final_structure, energy)
    e_form = get_e_form_per_atom(cse)
    return e_form


energy = run_mace(data)
print(energy)

(
    (y_formation_true, y_above_hull_true),
    (y_formation_pred, y_above_hull_pred),
) = correct_energy(energy, data["batch"])
rich.print(
    {"y_formation_pred": y_formation_pred, "y_above_hull_pred": y_above_hull_pred},
    {"y_formation_true": y_formation_true, "y_above_hull_true": y_above_hull_true},
)
# Out:
# 1024
# Using Materials Project MACE for MACECalculator with /root/.cache/mace/5yyxdm76
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# [12:22:15] INFO     Using CPU                                                                     ]8;id=520720;file:///opt/conda/envs/jmp-peft/lib/python3.11/site-packages/mace/tools/torch_tools.py\torch_tools.py]8;;\:]8;id=646375;file:///opt/conda/envs/jmp-peft/lib/python3.11/site-packages/mace/tools/torch_tools.py#67\67]8;;\
# Default dtype float32 does not match model dtype float64, converting models to float32.
# 0.11079539591471388
# {'y_formation_pred': 0.18168739648560717, 'y_above_hull_pred': 0.11079539591471388}
# {'y_formation_true': -0.021984999999403954, 'y_above_hull_true': 0.048907000571489334}

# %%
from tqdm.auto import tqdm


y_formation_preds: list[float] = []
y_formation_trues: list[float] = []

y_above_hull_preds: list[float] = []
y_above_hull_trues: list[float] = []


for file in tqdm(pt_files):
    data = torch.load(file, map_location=device)
    energy = run_mace(data)

    (
        (y_formation_true, y_above_hull_true),
        (y_formation_pred, y_above_hull_pred),
    ) = correct_energy(energy, data["batch"])

    y_formation_preds.append(float(y_formation_pred))
    y_formation_trues.append(float(y_formation_true))
    y_above_hull_preds.append(float(y_above_hull_pred))
    y_above_hull_trues.append(float(y_above_hull_true))

rich.print({})
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# {}

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

sns.histplot(-np.array(y_formation_preds), label="y_formation_preds")
sns.histplot(np.array(y_formation_trues), label="y_formation_trues")
plt.legend()
plt.show()

sns.scatterplot(x=y_formation_trues, y=y_formation_preds)
plt.show()

# sns.histplot(np.array(y_formation_preds))
# plt.show()

# %%
from matbench_discovery.metrics import stable_metrics

metrics = stable_metrics(
    np.array(y_above_hull_trues),
    np.array(y_above_hull_preds),
    fillna=False,
)
rich.print(metrics)

# Also print MAE of formation energy
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_formation_trues, y_formation_preds)
rich.print({"mae": mae})

# Draw a scatter plot of the true vs predicted values
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme("notebook")

plt.figure()
sns.scatterplot(x=y_above_hull_trues, y=y_above_hull_preds)
plt.xlabel("True")
plt.ylabel("Predicted")
plt.show()
# Out:
# {
#     'F1': 0.284965034965035,
#     'DAF': 1.0080444498127794,
#     'Precision': 0.1673511293634497,
#     'Recall': 0.9588235294117647,
#     'Accuracy': 0.201171875,
#     'TPR': 0.9588235294117647,
#     'FPR': 0.949648711943794,
#     'TNR': 0.05035128805620609,
#     'FNR': 0.041176470588235294,
#     'TP': 163,
#     'FP': 811,
#     'TN': 43,
#     'FN': 7,
#     'MAE': 1.0757076798984273,
#     'RMSE': 1.2580203758609911,
#     'R2': -19.81863371004837
# }
# {'mae': 1.2859037229335903}

# %%
from typing import cast
from tqdm.auto import tqdm

from chgnet.graph import CrystalGraph
from chgnet.graph.converter import CrystalGraphConverter
from chgnet.model import CHGNet
from matbench_discovery.energy import get_e_form_per_atom
from pymatgen.core import Structure
from pymatgen.entries.computed_entries import ComputedStructureEntry


device = torch.device("cpu")

model = CHGNet.load().to(device)
model.is_intensive = True
model.eval()

converter = CrystalGraphConverter(
    atom_graph_cutoff=12.0,
    bond_graph_cutoff=6.0,
).to(device)
converter.eval()


y_formation_preds: list[float] = []
y_formation_trues: list[float] = []

y_above_hull_preds: list[float] = []
y_above_hull_trues: list[float] = []


for file in tqdm(pt_files):
    data = torch.load(file, map_location=device)

    final_structure = cast(
        Structure, Structure.from_dict(data["relax_out"]["final_structure"])
    )
    graph = cast(CrystalGraph, converter(final_structure))

    # Compute the energy
    with torch.no_grad(), torch.inference_mode():
        out = model([graph.to(device)], task="e")
        energy = out["e"].view(-1).item()

    (
        (y_formation_true, y_above_hull_true),
        (y_formation_pred, y_above_hull_pred),
    ) = correct_energy(energy, data["batch"], divide_by_num_atoms=False)

    y_formation_preds.append(float(y_formation_pred))
    y_formation_trues.append(float(y_formation_true))
    y_above_hull_preds.append(float(y_above_hull_pred))
    y_above_hull_trues.append(float(y_above_hull_true))

rich.print({})
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda:1
#   0%|          | 0/1024 [00:00<?, ?it/s]
# {}

# %%
model = CHGNet.load().to(device)

model.is_intensive
# Out:
# CHGNet v0.3.0 initialized with 412,525 parameters
# CHGNet will run on cuda:1
# True

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.histplot(np.array(y_formation_preds), label="y_formation_preds")
sns.histplot(np.array(y_formation_trues), label="y_formation_trues")
plt.legend()
plt.show()

sns.scatterplot(x=y_formation_trues, y=y_formation_preds)
plt.show()

# sns.histplot(np.array(y_formation_preds))
# plt.show()

# %%
from matbench_discovery.metrics import stable_metrics

metrics = stable_metrics(
    np.array(y_above_hull_trues),
    np.array(y_above_hull_preds),
    fillna=False,
)
rich.print(metrics)

# Also print MAE of formation energy
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_formation_trues, y_formation_preds)
rich.print({"mae": mae})

# Draw a scatter plot of the true vs predicted values
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme("notebook")

plt.figure()
sns.scatterplot(x=y_above_hull_trues, y=y_above_hull_preds)
plt.xlabel("True")
plt.ylabel("Predicted")
plt.show()
# Out:
# {
#     'F1': 0.2847571189279732,
#     'DAF': 1.0,
#     'Precision': 0.166015625,
#     'Recall': 1.0,
#     'Accuracy': 0.166015625,
#     'TPR': 1.0,
#     'FPR': 1.0,
#     'TNR': 0.0,
#     'FNR': 0.0,
#     'TP': 170,
#     'FP': 854,
#     'TN': 0,
#     'FN': 0,
#     'MAE': 5.884446806037754,
#     'RMSE': 6.186340838561909,
#     'R2': -502.4363399001134
# }
# {'mae': 4.17172865043587}
