# %%
import pandas as pd
from matbench_discovery.data import DATA_FILES, Key

df_initial_structures = pd.read_json(DATA_FILES.wbm_initial_structures).set_index(
    Key.mat_id
)
df_summary = pd.read_csv(DATA_FILES.wbm_summary).set_index(Key.mat_id)
# Out:
# Loading 'wbm_summary' from cached file at '/root/.cache/matbench-discovery/1.0.0/wbm/2023-12-13-wbm-summary.csv.gz'

# %%
display(df_initial_structures.head())
display(df_summary.head())
# Out:
#             formula_from_cse  \
# material_id
# wbm-1-1               Ac6 U2
# wbm-1-2              Ac1 Th3
# wbm-1-3               Ac1 U3
# wbm-1-4          Ag2 Au1 Hg1
# wbm-1-5          Ag2 Ba1 La1
#
#                                              initial_structure
# material_id
# wbm-1-1      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-2      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-3      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-4      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-5      {'@module': 'pymatgen.core.structure', '@class...
#                  formula  n_sites  volume  uncorrected_energy  \
# material_id
# wbm-1-1           Ac6 U2      8.0  317.48             -42.954
# wbm-1-2          Ac1 Th3      4.0  137.42             -25.858
# wbm-1-3           Ac1 U3      4.0  100.81             -34.934
# wbm-1-4      Ag2 Au1 Hg1      4.0   76.26              -9.114
# wbm-1-5      Ag2 Ba1 La1      4.0  124.15             -13.222
#
#              e_form_per_atom_wbm  e_above_hull_wbm  bandgap_pbe  \
# material_id
# wbm-1-1                    0.550             0.550          0.0
# wbm-1-2                    0.125             0.125          0.0
# wbm-1-3                    0.768             0.768          0.0
# wbm-1-4                    0.030             0.063          0.0
# wbm-1-5                   -0.178             0.100          0.0
#
#             wyckoff_spglib_initial_structure  uncorrected_energy_from_cse  \
# material_id
# wbm-1-1                 A3B_hP8_194_h_c:Ac-U                   -42.955387
# wbm-1-2               AB3_tI8_139_a_bd:Ac-Th                   -25.858142
# wbm-1-3                AB3_tI8_139_a_bd:Ac-U                   -34.934045
# wbm-1-4         A2BC_cF16_225_c_a_b:Ag-Au-Hg                    -9.114021
# wbm-1-5         A2BC_cF16_225_c_a_b:Ag-Ba-La                   -13.222006
#
#              e_correction_per_atom_mp2020  e_correction_per_atom_mp_legacy  \
# material_id
# wbm-1-1                               0.0                              0.0
# wbm-1-2                               0.0                              0.0
# wbm-1-3                               0.0                              0.0
# wbm-1-4                               0.0                              0.0
# wbm-1-5                               0.0                              0.0
#
#              e_form_per_atom_uncorrected  e_form_per_atom_mp2020_corrected  \
# material_id
# wbm-1-1                         0.544327                          0.544327
# wbm-1-2                         0.126190                          0.126190
# wbm-1-3                         0.765339                          0.765339
# wbm-1-4                         0.032195                          0.032195
# wbm-1-5                        -0.175452                         -0.175452
#
#              e_above_hull_mp2020_corrected_ppd_mp  \
# material_id
# wbm-1-1                                  0.544310
# wbm-1-2                                  0.126152
# wbm-1-3                                  0.765340
# wbm-1-4                                  0.062869
# wbm-1-5                                  0.092193
#
#              site_stats_fingerprint_init_final_norm_diff  \
# material_id
# wbm-1-1                                         0.128576
# wbm-1-2                                         0.051626
# wbm-1-3                                         0.061782
# wbm-1-4                                         0.067272
# wbm-1-5                                         0.050158
#
#                            wyckoff_spglib  unique_prototype
# material_id
# wbm-1-1              A3B_hP8_194_h_c:Ac-U              True
# wbm-1-2            AB3_tI8_139_a_bd:Ac-Th              True
# wbm-1-3             AB3_tI8_139_a_bd:Ac-U              True
# wbm-1-4      A2BC_cF16_225_c_a_b:Ag-Au-Hg              True
# wbm-1-5      A2BC_cF16_225_c_a_b:Ag-Ba-La              True

# %%
# Merge the two dataframes
df = df_summary.merge(df_initial_structures, left_index=True, right_index=True)
display(df.head())
# Out:
#                  formula  n_sites  volume  uncorrected_energy  \
# material_id
# wbm-1-1           Ac6 U2      8.0  317.48             -42.954
# wbm-1-2          Ac1 Th3      4.0  137.42             -25.858
# wbm-1-3           Ac1 U3      4.0  100.81             -34.934
# wbm-1-4      Ag2 Au1 Hg1      4.0   76.26              -9.114
# wbm-1-5      Ag2 Ba1 La1      4.0  124.15             -13.222
#
#              e_form_per_atom_wbm  e_above_hull_wbm  bandgap_pbe  \
# material_id
# wbm-1-1                    0.550             0.550          0.0
# wbm-1-2                    0.125             0.125          0.0
# wbm-1-3                    0.768             0.768          0.0
# wbm-1-4                    0.030             0.063          0.0
# wbm-1-5                   -0.178             0.100          0.0
#
#             wyckoff_spglib_initial_structure  uncorrected_energy_from_cse  \
# material_id
# wbm-1-1                 A3B_hP8_194_h_c:Ac-U                   -42.955387
# wbm-1-2               AB3_tI8_139_a_bd:Ac-Th                   -25.858142
# wbm-1-3                AB3_tI8_139_a_bd:Ac-U                   -34.934045
# wbm-1-4         A2BC_cF16_225_c_a_b:Ag-Au-Hg                    -9.114021
# wbm-1-5         A2BC_cF16_225_c_a_b:Ag-Ba-La                   -13.222006
#
#              e_correction_per_atom_mp2020  e_correction_per_atom_mp_legacy  \
# material_id
# wbm-1-1                               0.0                              0.0
# wbm-1-2                               0.0                              0.0
# wbm-1-3                               0.0                              0.0
# wbm-1-4                               0.0                              0.0
# wbm-1-5                               0.0                              0.0
#
#              e_form_per_atom_uncorrected  e_form_per_atom_mp2020_corrected  \
# material_id
# wbm-1-1                         0.544327                          0.544327
# wbm-1-2                         0.126190                          0.126190
# wbm-1-3                         0.765339                          0.765339
# wbm-1-4                         0.032195                          0.032195
# wbm-1-5                        -0.175452                         -0.175452
#
#              e_above_hull_mp2020_corrected_ppd_mp  \
# material_id
# wbm-1-1                                  0.544310
# wbm-1-2                                  0.126152
# wbm-1-3                                  0.765340
# wbm-1-4                                  0.062869
# wbm-1-5                                  0.092193
#
#              site_stats_fingerprint_init_final_norm_diff  \
# material_id
# wbm-1-1                                         0.128576
# wbm-1-2                                         0.051626
# wbm-1-3                                         0.061782
# wbm-1-4                                         0.067272
# wbm-1-5                                         0.050158
#
#                            wyckoff_spglib  unique_prototype formula_from_cse  \
# material_id
# wbm-1-1              A3B_hP8_194_h_c:Ac-U              True           Ac6 U2
# wbm-1-2            AB3_tI8_139_a_bd:Ac-Th              True          Ac1 Th3
# wbm-1-3             AB3_tI8_139_a_bd:Ac-U              True           Ac1 U3
# wbm-1-4      A2BC_cF16_225_c_a_b:Ag-Au-Hg              True      Ag2 Au1 Hg1
# wbm-1-5      A2BC_cF16_225_c_a_b:Ag-Ba-La              True      Ag2 Ba1 La1
#
#                                              initial_structure
# material_id
# wbm-1-1      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-2      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-3      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-4      {'@module': 'pymatgen.core.structure', '@class...
# wbm-1-5      {'@module': 'pymatgen.core.structure', '@class...

# %%
df["id"] = df.index
df["material_id"] = df.index

# %%
import datasets
import numpy as np
from pymatgen.core import Structure

datasets.disable_caching()


def generator():
    # Iterate through the dataframe rows
    for i, row in df.iloc[0:100].iterrows():
        # yield {**row.to_dict(), "id": i, "material_id": i}
        d = row.to_dict()
        d["id"] = i
        d["material_id"] = i

        structure = Structure.from_dict(d[Key.init_struct])
        d["frac_pos"] = structure.frac_coords
        d["cart_pos"] = structure.cart_coords
        d["pos"] = structure.cart_coords

        d["cell"] = structure.lattice.matrix.reshape(3, 3)
        d["num_atoms"] = len(structure)

        atomic_numbers = structure.atomic_numbers
        d["atomic_numbers"] = atomic_numbers
        d["composition"] = np.bincount(atomic_numbers, minlength=120).tolist()

        yield d


num_shards = 1
# shard the dataframe


dataset = datasets.Dataset.from_generator(
    generator,
)
dataset
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 36
#      32 # shard the dataframe
#      33 df_sharded = df
# ---> 36 dataset = datasets.Dataset.from_generator(
#      37     generator,
#      38 )
#      39 dataset
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/arrow_dataset.py:1117, in Dataset.from_generator(generator, features, cache_dir, keep_in_memory, gen_kwargs, num_proc, **kwargs)
#    1068 """Create a Dataset from a generator.
#    1069
#    1070 Args:
#    (...)
#    1113 ```
#    1114 """
#    1115 from .io.generator import GeneratorDatasetInputStream
# -> 1117 return GeneratorDatasetInputStream(
#    1118     generator=generator,
#    1119     features=features,
#    1120     cache_dir=cache_dir,
#    1121     keep_in_memory=keep_in_memory,
#    1122     gen_kwargs=gen_kwargs,
#    1123     num_proc=num_proc,
#    1124     **kwargs,
#    1125 ).read()
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/io/generator.py:28, in GeneratorDatasetInputStream.__init__(self, generator, features, cache_dir, keep_in_memory, streaming, gen_kwargs, num_proc, **kwargs)
#       9 def __init__(
#      10     self,
#      11     generator: Callable,
#    (...)
#      18     **kwargs,
#      19 ):
#      20     super().__init__(
#      21         features=features,
#      22         cache_dir=cache_dir,
#    (...)
#      26         **kwargs,
#      27     )
# ---> 28     self.builder = Generator(
#      29         cache_dir=cache_dir,
#      30         features=features,
#      31         generator=generator,
#      32         gen_kwargs=gen_kwargs,
#      33         **kwargs,
#      34     )
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/builder.py:374, in DatasetBuilder.__init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, use_auth_token, repo_id, data_files, data_dir, storage_options, writer_batch_size, name, **config_kwargs)
#     372     config_kwargs["data_dir"] = data_dir
#     373 self.config_kwargs = config_kwargs
# --> 374 self.config, self.config_id = self._create_builder_config(
#     375     config_name=config_name,
#     376     custom_features=features,
#     377     **config_kwargs,
#     378 )
#     380 # prepare info: DatasetInfo are a standardized dataclass across all datasets
#     381 # Prefill datasetinfo
#     382 if info is None:
#     383     # TODO FOR PACKAGED MODULES IT IMPORTS DATA FROM src/packaged_modules which doesn't make sense
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/builder.py:633, in DatasetBuilder._create_builder_config(self, config_name, custom_features, **config_kwargs)
#     627 builder_config._resolve_data_files(
#     628     base_path=self.base_path,
#     629     download_config=DownloadConfig(token=self.token, storage_options=self.storage_options),
#     630 )
#     632 # compute the config id that is going to be used for caching
# --> 633 config_id = builder_config.create_config_id(
#     634     config_kwargs,
#     635     custom_features=custom_features,
#     636 )
#     637 is_custom = (config_id not in self.builder_configs) and config_id != "default"
#     638 if is_custom:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/builder.py:193, in BuilderConfig.create_config_id(self, config_kwargs, custom_features)
#     191             suffix = Hasher.hash(config_kwargs_to_add_to_suffix)
#     192     else:
# --> 193         suffix = Hasher.hash(config_kwargs_to_add_to_suffix)
#     195 if custom_features is not None:
#     196     m = Hasher()
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/fingerprint.py:228, in Hasher.hash(cls, value)
#     226 @classmethod
#     227 def hash(cls, value: Any) -> str:
# --> 228     return cls.hash_bytes(dumps(value))
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:109, in dumps(obj)
#     107 """Pickle an object to a string."""
#     108 file = BytesIO()
# --> 109 dump(obj, file)
#     110 return file.getvalue()
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:103, in dump(obj, file)
#     101 def dump(obj, file):
#     102     """Pickle an object to a file."""
# --> 103     Pickler(file, recurse=True).dump(obj)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:420, in Pickler.dump(self, obj)
#     418 def dump(self, obj): #NOTE: if settings change, need to update attributes
#     419     logger.trace_setup(self)
# --> 420     StockPickler.dump(self, obj)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:487, in _Pickler.dump(self, obj)
#     485 if self.proto >= 4:
#     486     self.framer.start_framing()
# --> 487 self.save(obj)
#     488 self.write(STOP)
#     489 self.framer.end_framing()
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1985, in save_function(pickler, obj)
#    1982 if state_dict:
#    1983     state = state, state_dict
# -> 1985 _save_with_postproc(pickler, (_create_function, (
#    1986         obj.__code__, globs, obj.__name__, obj.__defaults__,
#    1987         closure
#    1988 ), state), obj=obj, postproc_list=postproc_list)
#    1990 # Lift closure cell update to earliest function (#458)
#    1991 if _postproc:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1112, in _save_with_postproc(pickler, reduction, is_pickler_dill, obj, postproc_list)
#    1110 if source:
#    1111     pickler.write(pickler.get(pickler.memo[id(dest)][0]))
# -> 1112     pickler._batch_setitems(iter(source.items()))
#    1113 else:
#    1114     # Updating with an empty dictionary. Same as doing nothing.
#    1115     continue
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:902, in _Pickler.save_tuple(self, obj)
#     900 write(MARK)
#     901 for element in obj:
# --> 902     save(element)
#     904 if id(obj) in memo:
#     905     # Subtle.  d was not in memo when we entered save_tuple(), so
#     906     # the process of saving the tuple's elements must have saved
#    (...)
#     910     # could have been done in the "for element" loop instead, but
#     911     # recursive tuples are a rare thing.
#     912     get = self.get(memo[id(obj)][0])
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:692, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690 else:
#     691     save(func)
# --> 692     save(args)
#     693     write(REDUCE)
#     695 if obj is not None:
#     696     # If the object is already in the memo, this means it is
#     697     # recursive. In this case, throw away everything we put on the
#     698     # stack, and fetch the object back from the memo.
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:887, in _Pickler.save_tuple(self, obj)
#     885 if n <= 3 and self.proto >= 2:
#     886     for element in obj:
# --> 887         save(element)
#     888     # Subtle.  Same as in the big comment below.
#     889     if id(obj) in memo:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:603, in _Pickler.save(self, obj, save_persistent_id)
#     599     raise PicklingError("Tuple returned by %s must have "
#     600                         "two to six elements" % reduce)
#     602 # Save the reduce() output and finally memoize the object
# --> 603 self.save_reduce(obj=obj, *rv)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:717, in _Pickler.save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715 if state is not None:
#     716     if state_setter is None:
# --> 717         save(state)
#     718         write(BUILD)
#     719     else:
#     720         # If a state_setter is specified, call it instead of load_build
#     721         # to update obj's with its previous state.
#     722         # First, push state_setter and its tuple of expected arguments
#     723         # (obj, state) onto the stack.
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:902, in _Pickler.save_tuple(self, obj)
#     900 write(MARK)
#     901 for element in obj:
# --> 902     save(element)
#     904 if id(obj) in memo:
#     905     # Subtle.  d was not in memo when we entered save_tuple(), so
#     906     # the process of saving the tuple's elements must have saved
#    (...)
#     910     # could have been done in the "for element" loop instead, but
#     911     # recursive tuples are a rare thing.
#     912     get = self.get(memo[id(obj)][0])
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:932, in _Pickler.save_list(self, obj)
#     929     self.write(MARK + LIST)
#     931 self.memoize(obj)
# --> 932 self._batch_appends(obj)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:956, in _Pickler._batch_appends(self, items)
#     954     write(MARK)
#     955     for x in tmp:
# --> 956         save(x)
#     957     write(APPENDS)
#     958 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:560, in _Pickler.save(self, obj, save_persistent_id)
#     558 f = self.dispatch.get(t)
#     559 if f is not None:
# --> 560     f(self, obj)  # Call unbound method with explicit self
#     561     return
#     563 # Check private dispatch table if any, or else
#     564 # copyreg.dispatch_table
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:1217, in save_module_dict(pickler, obj)
#    1214     if is_dill(pickler, child=False) and pickler._session:
#    1215         # we only care about session the first pass thru
#    1216         pickler._first_pass = False
# -> 1217     StockPickler.save_dict(pickler, obj)
#    1218     logger.trace(pickler, "# D2")
#    1219 return
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:972, in _Pickler.save_dict(self, obj)
#     969     self.write(MARK + DICT)
#     971 self.memoize(obj)
# --> 972 self._batch_setitems(obj.items())
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:83, in Pickler._batch_setitems(self, items)
#      80     from datasets.fingerprint import Hasher
#      82     items = sorted(items, key=lambda x: Hasher.hash(x[0]))
# ---> 83 dill.Pickler._batch_setitems(self, items)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:998, in _Pickler._batch_setitems(self, items)
#     996     for k, v in tmp:
#     997         save(k)
# --> 998         save(v)
#     999     write(SETITEMS)
#    1000 elif n:
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/datasets/utils/_dill.py:70, in Pickler.save(self, obj, save_persistent_id)
#      68 if obj_type is FunctionType:
#      69     obj = getattr(obj, "_torchdynamo_orig_callable", obj)
# ---> 70 dill.Pickler.save(self, obj, save_persistent_id=save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:414, in Pickler.save(self, obj, save_persistent_id)
#     412     msg = "Can't pickle %s: attribute lookup builtins.generator failed" % GeneratorType
#     413     raise PicklingError(msg)
# --> 414 StockPickler.save(self, obj, save_persistent_id)
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/pickle.py:558, in _Pickler.save(self, obj, save_persistent_id)
#     555 if rv is NotImplemented:
#     556     # Check the type dispatch table
#     557     t = type(obj)
# --> 558     f = self.dispatch.get(t)
#     559     if f is not None:
#     560         f(self, obj)  # Call unbound method with explicit self
#
# File /opt/conda/envs/jmp-peft/lib/python3.11/site-packages/dill/_dill.py:316, in MetaCatchingDict.get(self, key, default)
#     315 class MetaCatchingDict(dict):
# --> 316     def get(self, key, default=None):
#     317         try:
#     318             return self[key]
#
# KeyboardInterrupt:

# %%
dataset.features
