# %%
from pathlib import Path

run_id = "rog61gn4"
run_dir = Path(
    f"/net/csefiles/coc-fung-cluster/nima/shared/experiment-data/nshtrainer/{run_id}/"
)
assert (
    run_dir.exists() and run_dir.is_dir()
), f"run_dir: {run_dir} does not exist or is not a directory"
print(run_dir)

if (snapshot_dir := next(run_dir.glob("./nshrunner/snapshots/*/"), None)) is not None:
    import nshrunner

    nshrunner.load_existing_snapshot(snapshot_dir)
# Out:
# /net/csefiles/coc-fung-cluster/nima/shared/experiment-data/nshtrainer/rog61gn4
# Added /net/csefiles/coc-fung-cluster/nima/shared/experiment-data/nshrunner/41d0be4a-1762-47f3-9ce3-e52cd9b2bd12/snapshots/20240730143647--b58fd01f-2780-4203-b600-70978a2ceb5c to sys.path. Modules: jmppeft

# %%
import os

os.environ["LL_DISABLE_TYPECHECKING"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"


import torch

torch.no_grad().__enter__()
torch.inference_mode().__enter__()

device = torch.device("cuda:0")
default_dtype = torch.float32

# %%
from jmppeft.tasks.finetune import matbench_discovery as M

ckpt_path = (run_dir / "checkpoint" / "latest.ckpt").resolve()
model = M.MatbenchDiscoveryModel.load_checkpoint(ckpt_path, map_location=device)
model = model.to(device, dtype=default_dtype)
model
# Out:
# Type checking the following modules: ('jmppeft',)
# TensorBoard/TensorBoardX not found. Disabling TensorBoardLogger. Please install TensorBoard with `pip install tensorboard` or TensorBoardX with `pip install tensorboardx` to enable TensorBoard logging.
# NSHRUNNER_SESSION_DIR is not set. Skipping symlink creation.
# NSHRUNNER_SESSION_DIR is not set. Skipping symlink creation.
# NSHRUNNER_SESSION_DIR is not set. Skipping symlink creation.
# NSHRUNNER_SESSION_DIR is not set. Skipping symlink creation.
# Using regular backbone
# Unrecognized arguments:  dict_keys(['name', 'learnable_rbf', 'learnable_rbf_stds', 'unique_basis_per_layer', 'dropout', 'edge_dropout', 'ln_per_layer', 'scale_factor_to_ln'])
# Constructed backbone with dlora=None
# Freezing 0 parameters (0.00%) out of 43,146,824 total parameters (43,146,824 trainable)
# MatbenchDiscoveryModel(config=MatbenchDiscoveryConfig(name=mptrj-jmps-bsz40-linrefenergy-lr8e-05-ln-direct-maceenergy-maceforce-rele-ec5.0-fc10.0-sc100.0-posaug_std0.01, project=jmp_mptrj), device=cuda:0)

# %%
from jmppeft.tasks.finetune.base import FinetuneMatBenchDiscoveryIS2REDatasetConfig

dataset_config = FinetuneMatBenchDiscoveryIS2REDatasetConfig(
    # sample_n=DatasetSampleNConfig(sample_n=16, seed=42)
)
print(dataset_config)

dataset_og = dataset_config.create_dataset()
dataset_og, len(dataset_og)
# Out:
# Loading 'wbm_summary' from cached file at '/nethome/nsg6/.cache/matbench-discovery/1.0.0/wbm/2023-12-13-wbm-summary.csv.gz'
# (<jmppeft.datasets.mpd_is2re.MatBenchDiscoveryIS2REDataset at 0x7ff25258a610>,
#  256963)

# %%
from collections import Counter

import jmppeft.modules.dataset.dataset_transform as DT
import nshutils
import rich
import torch.utils._pytree as tree
from lightning.fabric.utilities.apply_func import move_data_to_device
from torch_geometric.data import Batch, Data

nshutils.pretty()


def data_transform(data: Data):
    data = model.data_transform(data)
    data = Data.from_dict(
        tree.tree_map(
            lambda x: x.type(default_dtype)
            if torch.is_tensor(x) and torch.is_floating_point(x)
            else x,
            data.to_dict(),
        )
    )
    return data


def composition(data: Batch):
    return dict(Counter(data.atomic_numbers.tolist()))


num_items = 1024

dataset = DT.transform(dataset_og, data_transform)
dataset = DT.sample_n_transform(dataset, n=num_items, seed=42)


idx = 32
data = Batch.from_data_list([dataset[idx]])
rich.print(data.to_dict(), composition(data))
# Out:
# {
#     'pos': tensor[11, 3] n=33 x∈[-4.287, 6.937] μ=1.412 σ=2.423,
#     'id': ['wbm-3-72883'],
#     'atomic_numbers': tensor[11] i64 x∈[50, 79] μ=62.000 σ=14.269,
#     'cell': tensor[1, 3, 3] n=9 x∈[-3.509, 6.938] μ=1.065 σ=4.112 [[[6.029, 0., -3.509], [-2.037, 5.674, -3.509],
# [0., 0., 6.938]]],
#     'y_formation': tensor[1] [-0.236],
#     'y_formation_correction': tensor[1] [0.],
#     'y_above_hull': tensor[1] [0.093],
#     'natoms': tensor[1] i64 [11],
#     'pos_noise': tensor[11, 3] n=33 all_zeros,
#     'tags': tensor[11] i64 x∈[2, 2] μ=2.000 σ=0.,
#     'fixed': tensor[11] bool all_zeros,
#     'batch': tensor[11] i64 all_zeros,
#     'ptr': tensor[2] i64 μ=5.500 σ=7.778 [0, 11]
# }
# {66: 1, 50: 6, 79: 4}

# %%
import numpy as np
from jmppeft.modules.relaxer import ModelOutput, Relaxer
from matbench_discovery.energy import get_e_form_per_atom

LINREF = np.load(
    "/net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/notebooks/mptrj_linref.npy"
)


def model_fn(data, initial_data, *, use_y_relaxed: bool) -> ModelOutput:
    model_out = model.forward_denormalized(data)

    # energy = model_out["y_relaxed"] if use_y_relaxed else model_out["y"]
    energy = model_out["y"]
    relaxed_energy = model_out["y_relaxed"]
    forces = model_out["force"]
    stress = model_out["stress"]

    # Undo the linref
    if LINREF is not None:
        energy = energy + LINREF[data.atomic_numbers.cpu().numpy()].sum()
        relaxed_energy = (
            relaxed_energy + LINREF[data.atomic_numbers.cpu().numpy()].sum()
        )

    # JMP-S v2 energy is corrected_energy, i.e., DFT total energy
    # This energy is now DFT total energy, we need to convert it to formation energy per atom
    energy = get_e_form_per_atom(
        {
            "composition": composition(data),
            "energy": energy,
        }
    )
    relaxed_energy = get_e_form_per_atom(
        {
            "composition": composition(data),
            "energy": relaxed_energy,
        }
    )
    assert isinstance(energy, torch.Tensor)
    assert isinstance(relaxed_energy, torch.Tensor)

    # Add the correction factor
    if False:
        energy += initial_data.y_formation_correction.item()

    # energy, relaxed_energy = tree.tree_map(
    #     lambda energy: energy.view(1), (energy, relaxed_energy)
    # )
    energy = energy.view(1)
    relaxed_energy = relaxed_energy.view(1)
    forces = forces.view(-1, 3)
    stress = stress.view(1, 3, 3) if stress.numel() == 9 else stress.view(1, 6)

    return {
        "current_energy": energy,
        "relaxed_energy": relaxed_energy,
        "energy": relaxed_energy if use_y_relaxed else energy,
        "forces": forces,
        "stress": stress,
    }


data = move_data_to_device(data, model.device)
model_fn(data, data, use_y_relaxed=False)
# Out:
# {'current_energy': tensor[1] cuda:0 [0.135],
#  'relaxed_energy': tensor[1] cuda:0 [-0.115],
#  'energy': tensor[1] cuda:0 [0.135],
#  'forces': tensor[11, 3] n=33 x∈[-0.820, 0.814] μ=-0.001 σ=0.420 cuda:0,
#  'stress': tensor[1, 3, 3] n=9 x∈[-0.124, -0.002] μ=-0.043 σ=0.060 cuda:0 [[[-0.122, -0.002, -0.002], [-0.002, -0.124, -0.003], [-0.002, -0.003, -0.124]]]}

# %%
from functools import partial

import rich
from jmppeft.modules.relaxer import RelaxerConfig

config = RelaxerConfig(
    compute_stress=True,
    stress_weight=0.1,
    optimizer="FIRE",
    fmax=0.05,
    ase_filter="exp",
)
relaxer = Relaxer(
    config=config,
    model=partial(model_fn, use_y_relaxed=False),
    collate_fn=model.collate_fn,
    device=model.device,
)
rich.print(data.y_formation)
relax_out = relaxer.relax(data)
# rich.print(relax_out)

energy = relax_out.atoms.get_total_energy()
rich.print(energy, data.y_formation)
# Out:
# tensor[1] cuda:0 [-0.236]
#       Step     Time          Energy          fmax
# FIRE:    0 12:20:48        0.135402        2.952579
# FIRE:    1 12:20:48       -0.036928        1.201562
# FIRE:    2 12:20:49       -0.114881        0.468614
# FIRE:    3 12:20:49       -0.115098        0.463799
# FIRE:    4 12:20:49       -0.115887        0.460155
# FIRE:    5 12:20:49       -0.117830        0.458473
# FIRE:    6 12:20:49       -0.117868        0.437506
# FIRE:    7 12:20:49       -0.117869        0.412105
# FIRE:    8 12:20:50       -0.117842        0.385969
# FIRE:    9 12:20:50       -0.112863        0.359343
# FIRE:   10 12:20:50       -0.111781        0.333125
# FIRE:   11 12:20:50       -0.112081        0.310654
# FIRE:   12 12:20:50       -0.115379        0.288041
# FIRE:   13 12:20:50       -0.127590        0.275256
# FIRE:   14 12:20:50       -0.133358        0.258740
# FIRE:   15 12:20:50       -0.139715        0.245784
# FIRE:   16 12:20:51       -0.145232        0.239121
# FIRE:   17 12:20:51       -0.151695        0.226325
# FIRE:   18 12:20:51       -0.155785        0.196991
# FIRE:   19 12:20:51       -0.159736        0.156993
# FIRE:   20 12:20:51       -0.164338        0.167862
# FIRE:   21 12:20:51       -0.163662        0.362680
# FIRE:   22 12:20:51       -0.167699        0.450850
# FIRE:   23 12:20:51       -0.173505        0.411290
# FIRE:   24 12:20:51       -0.181988        0.306035
# FIRE:   25 12:20:52       -0.192910        0.178922
# FIRE:   26 12:20:52       -0.193988        0.131992
# FIRE:   27 12:20:52       -0.194866        0.123346
# FIRE:   28 12:20:52       -0.195422        0.111145
# FIRE:   29 12:20:52       -0.195659        0.101784
# FIRE:   30 12:20:52       -0.195827        0.091747
# FIRE:   31 12:20:52       -0.196318        0.084745
# FIRE:   32 12:20:52       -0.196481        0.058165
# FIRE:   33 12:20:53       -0.196523        0.032614
# -0.19652314484119415 tensor[1] cuda:0 [-0.236]

# %%
import copy


def relax_and_return_structure(
    relaxer: Relaxer,
    graph: Batch,
    device: str | torch.device | None = None,
    verbose: bool = True,
):
    out_graph = copy.deepcopy(graph)
    output = relaxer.relax(graph, verbose=verbose)

    atoms = output.atoms
    # Convert the relaxed structure to a graph
    out_graph.pos = torch.tensor(
        atoms.positions,
        dtype=out_graph.pos.dtype,
        device=out_graph.pos.device,
    )
    out_graph.cell = torch.tensor(
        atoms.cell.array,
        dtype=out_graph.cell.dtype,
        device=out_graph.cell.device,
    ).reshape_as(out_graph.cell)

    out_graph.y_prediction = torch.tensor(
        atoms.get_total_energy(),
        dtype=torch.float,
        device=out_graph.pos.device,
    ).view(-1)

    if device is not None:
        out_graph = cast(Batch, move_data_to_device(out_graph, device))

    return out_graph, output

# %%
from collections import defaultdict
from functools import partial
from typing import TypedDict, cast

import numpy as np
from jmppeft.modules.relaxer import RelaxationOutput
from torch.utils.data import DataLoader
from torch_geometric.data import Batch
from tqdm.auto import tqdm

use_y_relaxed = True

config = RelaxerConfig(
    compute_stress=True,
    stress_weight=0.1,
    optimizer="FIRE",
    # fmax=0.01,
    # ase_filter="frechet",
    fmax=0.05,
    ase_filter="exp",
)
relaxer = Relaxer(
    config=config,
    model=partial(model_fn, use_y_relaxed=use_y_relaxed),
    collate_fn=model.collate_fn,
    device=model.device,
)

dl = DataLoader(
    dataset,
    batch_size=1,
    collate_fn=model.collate_fn,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

preds_targets = defaultdict[str, list[tuple[float, float]]](lambda: [])
mae_error = 0.0
mae_count = 0


class ProblematicSample(TypedDict):
    error: float
    initial_data: Batch
    relaxed_data: Batch
    relax_out: RelaxationOutput


problematic_samples: list[ProblematicSample] = []
ae_threshold = 0.1

for data in tqdm(dl, total=len(dl)):
    data = cast(Batch, data)
    data = move_data_to_device(data, model.device)
    data.y_prediction = data.y_formation
    relaxed_data, relax_out = relax_and_return_structure(relaxer, data, verbose=False)

    e_form_true = data.y_formation.item()
    e_form_pred = relax_out.atoms.get_total_energy()
    preds_targets["e_form"].append((e_form_pred, e_form_true))

    e_above_hull_true = data.y_above_hull.item()
    e_above_hull_pred = e_above_hull_true + (e_form_pred - e_form_true)
    preds_targets["e_above_hull"].append((e_above_hull_pred, e_above_hull_true))

    mae_error += abs(e_form_pred - e_form_true)
    mae_count += 1
    mae_running = mae_error / mae_count

    nsteps = len(relax_out.trajectory.frames)

    error = abs(e_form_pred - e_form_true)
    prefix = "✅"
    if error > ae_threshold:
        problematic_samples.append(
            {
                "error": error,
                "initial_data": move_data_to_device(data, "cpu"),
                "relaxed_data": move_data_to_device(relaxed_data, "cpu"),
                "relax_out": move_data_to_device(relax_out, "cpu"),
            }
        )
        prefix = "❌"

    print(
        f"{prefix} # Steps: {nsteps}; e_form: P={e_form_pred:.4f}, GT={e_form_true:.4f}, Δ={abs(e_form_pred - e_form_true):.4f}, MAE={mae_running:.4f}"
    )
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ✅ # Steps: 20; e_form: P=-0.8565, GT=-0.8008, Δ=0.0557, MAE=0.0557
# ✅ # Steps: 20; e_form: P=0.0053, GT=-0.0220, Δ=0.0273, MAE=0.0415
# ✅ # Steps: 11; e_form: P=-0.5985, GT=-0.6088, Δ=0.0102, MAE=0.0311
# ✅ # Steps: 44; e_form: P=-0.1902, GT=-0.1544, Δ=0.0358, MAE=0.0322
# ❌ # Steps: 56; e_form: P=-0.2731, GT=-0.1154, Δ=0.1577, MAE=0.0573
# ✅ # Steps: 18; e_form: P=-0.3801, GT=-0.3905, Δ=0.0103, MAE=0.0495
# ✅ # Steps: 12; e_form: P=-0.2392, GT=-0.2468, Δ=0.0076, MAE=0.0435
# ✅ # Steps: 16; e_form: P=-0.5418, GT=-0.4542, Δ=0.0876, MAE=0.0490
# ✅ # Steps: 11; e_form: P=-1.9549, GT=-1.9089, Δ=0.0460, MAE=0.0487
# ✅ # Steps: 6; e_form: P=-0.1521, GT=-0.1224, Δ=0.0298, MAE=0.0468
# ✅ # Steps: 4; e_form: P=-1.8769, GT=-1.8781, Δ=0.0012, MAE=0.0426
# ✅ # Steps: 13; e_form: P=-1.5886, GT=-1.6101, Δ=0.0214, MAE=0.0409
# ✅ # Steps: 15; e_form: P=-1.8900, GT=-1.8180, Δ=0.0720, MAE=0.0433
# ✅ # Steps: 4; e_form: P=-0.3360, GT=-0.3333, Δ=0.0028, MAE=0.0404
# ✅ # Steps: 14; e_form: P=-0.7610, GT=-0.7299, Δ=0.0311, MAE=0.0398
# ✅ # Steps: 11; e_form: P=-0.0315, GT=-0.0433, Δ=0.0118, MAE=0.0380
# ✅ # Steps: 18; e_form: P=-0.5535, GT=-0.5591, Δ=0.0056, MAE=0.0361
# ✅ # Steps: 4; e_form: P=-3.1418, GT=-3.0844, Δ=0.0574, MAE=0.0373
# ❌ # Steps: 17; e_form: P=-1.3712, GT=-1.7130, Δ=0.3418, MAE=0.0533
# ❌ # Steps: 25; e_form: P=-2.6814, GT=-2.8650, Δ=0.1836, MAE=0.0598
# ✅ # Steps: 21; e_form: P=-2.4125, GT=-2.3807, Δ=0.0319, MAE=0.0585
# ✅ # Steps: 23; e_form: P=-0.7101, GT=-0.6476, Δ=0.0625, MAE=0.0587
# ✅ # Steps: 7; e_form: P=-0.3990, GT=-0.4119, Δ=0.0128, MAE=0.0567
# ✅ # Steps: 7; e_form: P=0.0038, GT=-0.0061, Δ=0.0099, MAE=0.0547
# ✅ # Steps: 45; e_form: P=-0.6278, GT=-0.5812, Δ=0.0466, MAE=0.0544
# ✅ # Steps: 25; e_form: P=-0.4792, GT=-0.4616, Δ=0.0177, MAE=0.0530
# ✅ # Steps: 36; e_form: P=-1.1006, GT=-1.0945, Δ=0.0060, MAE=0.0513
# ✅ # Steps: 14; e_form: P=-2.0570, GT=-2.0012, Δ=0.0559, MAE=0.0514
# ✅ # Steps: 13; e_form: P=-2.1884, GT=-2.1870, Δ=0.0014, MAE=0.0497
# ✅ # Steps: 13; e_form: P=-0.7831, GT=-0.7626, Δ=0.0205, MAE=0.0487
# ✅ # Steps: 14; e_form: P=-1.8826, GT=-1.9263, Δ=0.0437, MAE=0.0486
# ✅ # Steps: 4; e_form: P=-0.1455, GT=-0.1229, Δ=0.0226, MAE=0.0478
# ✅ # Steps: 35; e_form: P=-0.1981, GT=-0.2364, Δ=0.0383, MAE=0.0475
# ✅ # Steps: 10; e_form: P=-0.2104, GT=-0.1713, Δ=0.0391, MAE=0.0472
# ✅ # Steps: 5; e_form: P=-0.5322, GT=-0.5257, Δ=0.0065, MAE=0.0461
# ✅ # Steps: 19; e_form: P=-0.4676, GT=-0.4484, Δ=0.0192, MAE=0.0453
# ✅ # Steps: 10; e_form: P=-0.8670, GT=-0.9048, Δ=0.0378, MAE=0.0451
# ✅ # Steps: 40; e_form: P=-0.1812, GT=-0.2392, Δ=0.0580, MAE=0.0455
# ✅ # Steps: 23; e_form: P=-0.6062, GT=-0.6018, Δ=0.0045, MAE=0.0444
# ✅ # Steps: 5; e_form: P=-0.4070, GT=-0.4596, Δ=0.0526, MAE=0.0446
# ✅ # Steps: 16; e_form: P=-0.0171, GT=0.0228, Δ=0.0398, MAE=0.0445
# ✅ # Steps: 9; e_form: P=-0.6460, GT=-0.6482, Δ=0.0022, MAE=0.0435
# ✅ # Steps: 7; e_form: P=-0.3318, GT=-0.3384, Δ=0.0066, MAE=0.0426
# ✅ # Steps: 18; e_form: P=0.0046, GT=0.0744, Δ=0.0699, MAE=0.0432
# ✅ # Steps: 2; e_form: P=-0.3350, GT=-0.2690, Δ=0.0660, MAE=0.0437
# ✅ # Steps: 21; e_form: P=-2.9974, GT=-2.9990, Δ=0.0016, MAE=0.0428
# ✅ # Steps: 11; e_form: P=-1.0201, GT=-1.0127, Δ=0.0074, MAE=0.0421
# ✅ # Steps: 5; e_form: P=-0.4069, GT=-0.4317, Δ=0.0248, MAE=0.0417
# ✅ # Steps: 5; e_form: P=-0.7998, GT=-0.8011, Δ=0.0013, MAE=0.0409
# ✅ # Steps: 33; e_form: P=-3.2195, GT=-3.2035, Δ=0.0160, MAE=0.0404
# ✅ # Steps: 16; e_form: P=-0.1644, GT=-0.1638, Δ=0.0006, MAE=0.0396
# ✅ # Steps: 23; e_form: P=-1.3948, GT=-1.3358, Δ=0.0590, MAE=0.0400
# ✅ # Steps: 9; e_form: P=-1.1766, GT=-1.1612, Δ=0.0154, MAE=0.0395
# ✅ # Steps: 2; e_form: P=-0.1266, GT=-0.1789, Δ=0.0523, MAE=0.0398
# ✅ # Steps: 26; e_form: P=-0.3073, GT=-0.3186, Δ=0.0112, MAE=0.0392
# ✅ # Steps: 17; e_form: P=0.4179, GT=0.4827, Δ=0.0648, MAE=0.0397
# ✅ # Steps: 14; e_form: P=-1.7859, GT=-1.7589, Δ=0.0271, MAE=0.0395
# ✅ # Steps: 7; e_form: P=-0.3209, GT=-0.2765, Δ=0.0444, MAE=0.0396
# ✅ # Steps: 4; e_form: P=-3.2562, GT=-3.3041, Δ=0.0479, MAE=0.0397
# ✅ # Steps: 4; e_form: P=-0.3474, GT=-0.3660, Δ=0.0186, MAE=0.0394
# ✅ # Steps: 12; e_form: P=-0.6462, GT=-0.6369, Δ=0.0093, MAE=0.0389
# ✅ # Steps: 35; e_form: P=-2.6378, GT=-2.6335, Δ=0.0043, MAE=0.0383
# ❌ # Steps: 12; e_form: P=-1.9472, GT=-1.5591, Δ=0.3881, MAE=0.0439
# ✅ # Steps: 23; e_form: P=0.1805, GT=0.1733, Δ=0.0072, MAE=0.0433
# ✅ # Steps: 29; e_form: P=-0.1836, GT=-0.1928, Δ=0.0092, MAE=0.0428
# ✅ # Steps: 16; e_form: P=0.0752, GT=0.0012, Δ=0.0740, MAE=0.0432
# ✅ # Steps: 21; e_form: P=-0.8536, GT=-0.8882, Δ=0.0346, MAE=0.0431
# ❌ # Steps: 2; e_form: P=-0.6673, GT=-0.5519, Δ=0.1154, MAE=0.0442
# ✅ # Steps: 29; e_form: P=-2.1583, GT=-2.1893, Δ=0.0311, MAE=0.0440
# ✅ # Steps: 18; e_form: P=-0.1026, GT=-0.0716, Δ=0.0310, MAE=0.0438
# ✅ # Steps: 6; e_form: P=0.0253, GT=0.0055, Δ=0.0198, MAE=0.0435
# ✅ # Steps: 7; e_form: P=0.1943, GT=0.2183, Δ=0.0240, MAE=0.0432
# ✅ # Steps: 30; e_form: P=-0.0449, GT=-0.0323, Δ=0.0126, MAE=0.0428
# ✅ # Steps: 9; e_form: P=-1.2258, GT=-1.2014, Δ=0.0245, MAE=0.0425
# ✅ # Steps: 8; e_form: P=0.3414, GT=0.3216, Δ=0.0199, MAE=0.0422
# ✅ # Steps: 5; e_form: P=-3.6777, GT=-3.7061, Δ=0.0284, MAE=0.0420
# ✅ # Steps: 9; e_form: P=-2.3913, GT=-2.3751, Δ=0.0162, MAE=0.0417
# ❌ # Steps: 8; e_form: P=-0.6042, GT=-0.4485, Δ=0.1557, MAE=0.0432
# ❌ # Steps: 21; e_form: P=-0.8676, GT=-1.1411, Δ=0.2735, MAE=0.0461
# ✅ # Steps: 5; e_form: P=0.2094, GT=0.3030, Δ=0.0936, MAE=0.0467
# ✅ # Steps: 7; e_form: P=-0.2903, GT=-0.2621, Δ=0.0282, MAE=0.0464
# ✅ # Steps: 5; e_form: P=0.1109, GT=0.1009, Δ=0.0100, MAE=0.0460
# ✅ # Steps: 36; e_form: P=-0.2195, GT=-0.2268, Δ=0.0073, MAE=0.0455
# ✅ # Steps: 2; e_form: P=-0.4218, GT=-0.4042, Δ=0.0176, MAE=0.0452
# ✅ # Steps: 19; e_form: P=-0.7946, GT=-0.7625, Δ=0.0320, MAE=0.0450
# ✅ # Steps: 13; e_form: P=-0.0900, GT=-0.0655, Δ=0.0245, MAE=0.0448
# ❌ # Steps: 15; e_form: P=0.0581, GT=0.2421, Δ=0.1840, MAE=0.0464
# ✅ # Steps: 7; e_form: P=-0.6407, GT=-0.5644, Δ=0.0763, MAE=0.0467
# ✅ # Steps: 23; e_form: P=-0.9798, GT=-0.9880, Δ=0.0083, MAE=0.0463
# ✅ # Steps: 15; e_form: P=0.0114, GT=0.0243, Δ=0.0129, MAE=0.0459
# ✅ # Steps: 14; e_form: P=-0.2787, GT=-0.2068, Δ=0.0719, MAE=0.0462
# ✅ # Steps: 10; e_form: P=-0.9662, GT=-1.0161, Δ=0.0499, MAE=0.0463
# ✅ # Steps: 21; e_form: P=-0.6065, GT=-0.6459, Δ=0.0394, MAE=0.0462
# ✅ # Steps: 5; e_form: P=-0.0490, GT=-0.0518, Δ=0.0028, MAE=0.0457
# ✅ # Steps: 13; e_form: P=0.1878, GT=0.2311, Δ=0.0433, MAE=0.0457
# ✅ # Steps: 17; e_form: P=-2.5959, GT=-2.6037, Δ=0.0078, MAE=0.0453
# ✅ # Steps: 28; e_form: P=-0.5774, GT=-0.5099, Δ=0.0676, MAE=0.0455
# ✅ # Steps: 21; e_form: P=-0.5310, GT=-0.4995, Δ=0.0315, MAE=0.0454
# ✅ # Steps: 32; e_form: P=-2.8327, GT=-2.8406, Δ=0.0078, MAE=0.0450
# ✅ # Steps: 6; e_form: P=-0.4597, GT=-0.5100, Δ=0.0503, MAE=0.0451
# ❌ # Steps: 6; e_form: P=-0.3123, GT=-0.1759, Δ=0.1364, MAE=0.0460
# ✅ # Steps: 22; e_form: P=-3.1152, GT=-3.1097, Δ=0.0055, MAE=0.0456
# ✅ # Steps: 6; e_form: P=-0.0216, GT=-0.0740, Δ=0.0524, MAE=0.0456
# ✅ # Steps: 5; e_form: P=-0.6964, GT=-0.6186, Δ=0.0779, MAE=0.0459
# ✅ # Steps: 8; e_form: P=-0.5436, GT=-0.5333, Δ=0.0103, MAE=0.0456
# ✅ # Steps: 6; e_form: P=-0.8174, GT=-0.7920, Δ=0.0254, MAE=0.0454
# ✅ # Steps: 6; e_form: P=-1.7736, GT=-1.7156, Δ=0.0580, MAE=0.0455
# ✅ # Steps: 9; e_form: P=-1.8498, GT=-1.8573, Δ=0.0075, MAE=0.0452
# ✅ # Steps: 4; e_form: P=-0.3184, GT=-0.3303, Δ=0.0119, MAE=0.0449
# ✅ # Steps: 8; e_form: P=-1.0410, GT=-1.0368, Δ=0.0041, MAE=0.0445
# ✅ # Steps: 8; e_form: P=-0.7031, GT=-0.7102, Δ=0.0071, MAE=0.0442
# ✅ # Steps: 16; e_form: P=-0.1361, GT=-0.1778, Δ=0.0417, MAE=0.0441
# ✅ # Steps: 44; e_form: P=-2.8450, GT=-2.8529, Δ=0.0079, MAE=0.0438
# ✅ # Steps: 11; e_form: P=-1.6424, GT=-1.6165, Δ=0.0260, MAE=0.0437
# ✅ # Steps: 17; e_form: P=-0.2801, GT=-0.1979, Δ=0.0822, MAE=0.0440
# ✅ # Steps: 10; e_form: P=-0.0613, GT=-0.0864, Δ=0.0251, MAE=0.0438
# ✅ # Steps: 13; e_form: P=-0.4930, GT=-0.4755, Δ=0.0175, MAE=0.0436
# ✅ # Steps: 8; e_form: P=-3.0800, GT=-3.0706, Δ=0.0094, MAE=0.0433
# ✅ # Steps: 7; e_form: P=-0.5065, GT=-0.5204, Δ=0.0139, MAE=0.0431
# ✅ # Steps: 30; e_form: P=-0.2082, GT=-0.2087, Δ=0.0005, MAE=0.0427
# ✅ # Steps: 11; e_form: P=-3.1147, GT=-3.1452, Δ=0.0305, MAE=0.0426
# ✅ # Steps: 12; e_form: P=-1.3062, GT=-1.2898, Δ=0.0165, MAE=0.0424
# ✅ # Steps: 11; e_form: P=-0.5464, GT=-0.5218, Δ=0.0246, MAE=0.0423
# ✅ # Steps: 27; e_form: P=-0.8571, GT=-0.8567, Δ=0.0005, MAE=0.0419
# ✅ # Steps: 19; e_form: P=-3.4711, GT=-3.4760, Δ=0.0048, MAE=0.0416
# ✅ # Steps: 10; e_form: P=-0.2999, GT=-0.2446, Δ=0.0553, MAE=0.0417
# ✅ # Steps: 34; e_form: P=-0.3088, GT=-0.2800, Δ=0.0288, MAE=0.0416
# ❌ # Steps: 11; e_form: P=0.0617, GT=0.1744, Δ=0.1126, MAE=0.0422
# ✅ # Steps: 2; e_form: P=-0.1224, GT=-0.1078, Δ=0.0146, MAE=0.0420
# ✅ # Steps: 31; e_form: P=-0.8055, GT=-0.7996, Δ=0.0059, MAE=0.0417
# ✅ # Steps: 14; e_form: P=-0.4485, GT=-0.4252, Δ=0.0232, MAE=0.0416
# ✅ # Steps: 24; e_form: P=-0.8352, GT=-0.8202, Δ=0.0149, MAE=0.0414
# ✅ # Steps: 11; e_form: P=0.0576, GT=0.0943, Δ=0.0368, MAE=0.0413
# ✅ # Steps: 13; e_form: P=-2.9449, GT=-2.9469, Δ=0.0020, MAE=0.0410
# ✅ # Steps: 12; e_form: P=-0.2851, GT=-0.2326, Δ=0.0525, MAE=0.0411
# ✅ # Steps: 19; e_form: P=-0.6811, GT=-0.6756, Δ=0.0055, MAE=0.0409
# ❌ # Steps: 20; e_form: P=-0.5575, GT=-0.6712, Δ=0.1136, MAE=0.0414
# ✅ # Steps: 12; e_form: P=-0.4625, GT=-0.4400, Δ=0.0224, MAE=0.0412
# ✅ # Steps: 18; e_form: P=-0.6185, GT=-0.6389, Δ=0.0204, MAE=0.0411
# ❌ # Steps: 22; e_form: P=0.0601, GT=-0.0895, Δ=0.1495, MAE=0.0419
# ✅ # Steps: 14; e_form: P=0.0502, GT=0.0838, Δ=0.0336, MAE=0.0418
# ✅ # Steps: 6; e_form: P=-2.9591, GT=-2.9472, Δ=0.0118, MAE=0.0416
# ✅ # Steps: 6; e_form: P=-0.1872, GT=-0.1927, Δ=0.0055, MAE=0.0413
# ✅ # Steps: 5; e_form: P=-0.5312, GT=-0.5382, Δ=0.0070, MAE=0.0411
# ✅ # Steps: 15; e_form: P=0.0888, GT=0.1247, Δ=0.0360, MAE=0.0411
# ✅ # Steps: 46; e_form: P=-2.8096, GT=-2.8257, Δ=0.0161, MAE=0.0409
# ✅ # Steps: 7; e_form: P=0.2902, GT=0.3290, Δ=0.0388, MAE=0.0409
# ✅ # Steps: 25; e_form: P=-0.1328, GT=-0.1536, Δ=0.0208, MAE=0.0408
# ✅ # Steps: 4; e_form: P=-0.8593, GT=-0.8690, Δ=0.0097, MAE=0.0405
# ✅ # Steps: 24; e_form: P=-0.0876, GT=-0.0742, Δ=0.0134, MAE=0.0404
# ✅ # Steps: 5; e_form: P=-0.4221, GT=-0.4073, Δ=0.0148, MAE=0.0402
# ✅ # Steps: 2; e_form: P=-0.1361, GT=-0.1300, Δ=0.0061, MAE=0.0400
# ✅ # Steps: 30; e_form: P=-0.3217, GT=-0.2779, Δ=0.0438, MAE=0.0400
# ✅ # Steps: 8; e_form: P=-0.3589, GT=-0.3386, Δ=0.0203, MAE=0.0399
# ✅ # Steps: 2; e_form: P=-0.3745, GT=-0.3727, Δ=0.0018, MAE=0.0396
# ✅ # Steps: 16; e_form: P=-0.5431, GT=-0.5487, Δ=0.0056, MAE=0.0394
# ✅ # Steps: 25; e_form: P=-3.5478, GT=-3.5561, Δ=0.0083, MAE=0.0392
# ✅ # Steps: 25; e_form: P=-0.4113, GT=-0.4416, Δ=0.0303, MAE=0.0392
# ✅ # Steps: 9; e_form: P=-0.2117, GT=-0.1298, Δ=0.0819, MAE=0.0394
# ✅ # Steps: 6; e_form: P=-1.0202, GT=-0.9992, Δ=0.0209, MAE=0.0393
# ✅ # Steps: 5; e_form: P=-0.1214, GT=-0.0392, Δ=0.0822, MAE=0.0396
# ✅ # Steps: 16; e_form: P=0.5998, GT=0.5879, Δ=0.0119, MAE=0.0394
# ✅ # Steps: 20; e_form: P=-2.9007, GT=-2.9056, Δ=0.0048, MAE=0.0392
# ✅ # Steps: 11; e_form: P=-4.3643, GT=-4.4045, Δ=0.0402, MAE=0.0392
# ✅ # Steps: 4; e_form: P=-2.7855, GT=-2.7839, Δ=0.0016, MAE=0.0390
# ✅ # Steps: 12; e_form: P=-0.4259, GT=-0.3821, Δ=0.0438, MAE=0.0390
# ✅ # Steps: 7; e_form: P=-0.9073, GT=-0.9093, Δ=0.0020, MAE=0.0388
# ✅ # Steps: 11; e_form: P=-0.4768, GT=-0.4430, Δ=0.0338, MAE=0.0387
# ✅ # Steps: 6; e_form: P=-1.1594, GT=-1.0645, Δ=0.0949, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-2.5601, GT=-2.5655, Δ=0.0054, MAE=0.0389
# ✅ # Steps: 21; e_form: P=0.1434, GT=0.1622, Δ=0.0189, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-2.4582, GT=-2.5002, Δ=0.0420, MAE=0.0388
# ✅ # Steps: 23; e_form: P=-0.1846, GT=-0.1793, Δ=0.0053, MAE=0.0386
# ❌ # Steps: 17; e_form: P=0.4179, GT=0.5282, Δ=0.1104, MAE=0.0390
# ✅ # Steps: 21; e_form: P=0.2182, GT=0.2220, Δ=0.0037, MAE=0.0388
# ✅ # Steps: 12; e_form: P=-0.5025, GT=-0.4476, Δ=0.0549, MAE=0.0389
# ✅ # Steps: 17; e_form: P=0.3052, GT=0.3214, Δ=0.0162, MAE=0.0388
# ✅ # Steps: 4; e_form: P=-0.8637, GT=-0.8584, Δ=0.0054, MAE=0.0386
# ✅ # Steps: 5; e_form: P=-0.8016, GT=-0.8007, Δ=0.0009, MAE=0.0384
# ✅ # Steps: 5; e_form: P=-1.9389, GT=-1.9317, Δ=0.0072, MAE=0.0382
# ✅ # Steps: 12; e_form: P=-0.5831, GT=-0.6179, Δ=0.0349, MAE=0.0382
# ✅ # Steps: 9; e_form: P=-3.6717, GT=-3.6750, Δ=0.0033, MAE=0.0380
# ✅ # Steps: 10; e_form: P=-1.1550, GT=-1.1545, Δ=0.0004, MAE=0.0378
# ✅ # Steps: 6; e_form: P=-0.6729, GT=-0.7540, Δ=0.0811, MAE=0.0380
# ❌ # Steps: 6; e_form: P=-0.6393, GT=-0.5240, Δ=0.1152, MAE=0.0384
# ✅ # Steps: 2; e_form: P=-0.5037, GT=-0.4766, Δ=0.0270, MAE=0.0384
# ✅ # Steps: 15; e_form: P=-0.9549, GT=-0.9658, Δ=0.0109, MAE=0.0382
# ✅ # Steps: 7; e_form: P=-0.0672, GT=-0.0569, Δ=0.0102, MAE=0.0381
# ✅ # Steps: 21; e_form: P=-0.4241, GT=-0.3982, Δ=0.0259, MAE=0.0380
# ✅ # Steps: 17; e_form: P=0.1949, GT=0.1746, Δ=0.0203, MAE=0.0379
# ✅ # Steps: 6; e_form: P=-0.2698, GT=-0.2275, Δ=0.0423, MAE=0.0379
# ✅ # Steps: 19; e_form: P=-2.6851, GT=-2.6930, Δ=0.0080, MAE=0.0378
# ✅ # Steps: 10; e_form: P=-0.6778, GT=-0.6667, Δ=0.0111, MAE=0.0376
# ✅ # Steps: 22; e_form: P=-2.3869, GT=-2.3839, Δ=0.0030, MAE=0.0375
# ✅ # Steps: 21; e_form: P=-0.3338, GT=-0.3227, Δ=0.0111, MAE=0.0373
# ✅ # Steps: 11; e_form: P=-0.3795, GT=-0.3888, Δ=0.0093, MAE=0.0372
# ✅ # Steps: 20; e_form: P=-0.7076, GT=-0.6294, Δ=0.0782, MAE=0.0374
# ✅ # Steps: 16; e_form: P=-0.6553, GT=-0.6788, Δ=0.0235, MAE=0.0373
# ✅ # Steps: 9; e_form: P=-0.0433, GT=-0.0314, Δ=0.0120, MAE=0.0372
# ✅ # Steps: 20; e_form: P=-0.9185, GT=-0.9285, Δ=0.0100, MAE=0.0371
# ✅ # Steps: 22; e_form: P=-0.2947, GT=-0.2881, Δ=0.0066, MAE=0.0369
# ✅ # Steps: 15; e_form: P=0.2481, GT=0.3054, Δ=0.0572, MAE=0.0370
# ✅ # Steps: 26; e_form: P=-0.6096, GT=-0.5965, Δ=0.0130, MAE=0.0369
# ✅ # Steps: 6; e_form: P=-0.3168, GT=-0.2966, Δ=0.0201, MAE=0.0368
# ✅ # Steps: 7; e_form: P=-0.4209, GT=-0.3991, Δ=0.0217, MAE=0.0367
# ✅ # Steps: 5; e_form: P=0.1935, GT=0.1580, Δ=0.0355, MAE=0.0367
# ✅ # Steps: 15; e_form: P=-1.1442, GT=-1.1812, Δ=0.0371, MAE=0.0367
# ✅ # Steps: 2; e_form: P=-0.4030, GT=-0.3573, Δ=0.0457, MAE=0.0368
# ✅ # Steps: 11; e_form: P=-0.9645, GT=-0.9678, Δ=0.0034, MAE=0.0366
# ✅ # Steps: 11; e_form: P=-0.5616, GT=-0.5402, Δ=0.0214, MAE=0.0365
# ✅ # Steps: 2; e_form: P=-0.2440, GT=-0.2690, Δ=0.0250, MAE=0.0365
# ✅ # Steps: 23; e_form: P=-1.0630, GT=-1.0754, Δ=0.0124, MAE=0.0364
# ✅ # Steps: 29; e_form: P=-2.5700, GT=-2.5812, Δ=0.0111, MAE=0.0363
# ✅ # Steps: 9; e_form: P=-0.4025, GT=-0.4015, Δ=0.0011, MAE=0.0361
# ❌ # Steps: 17; e_form: P=-0.5145, GT=-0.6224, Δ=0.1079, MAE=0.0364
# ✅ # Steps: 17; e_form: P=-0.4975, GT=-0.4467, Δ=0.0508, MAE=0.0365
# ✅ # Steps: 11; e_form: P=-0.3632, GT=-0.3721, Δ=0.0090, MAE=0.0364
# ✅ # Steps: 13; e_form: P=-0.8689, GT=-0.8439, Δ=0.0249, MAE=0.0363
# ✅ # Steps: 7; e_form: P=-1.3074, GT=-1.2718, Δ=0.0356, MAE=0.0363
# ✅ # Steps: 37; e_form: P=-0.5013, GT=-0.4772, Δ=0.0241, MAE=0.0363
# ❌ # Steps: 7; e_form: P=0.1316, GT=0.0123, Δ=0.1193, MAE=0.0366
# ✅ # Steps: 6; e_form: P=-0.7474, GT=-0.7463, Δ=0.0011, MAE=0.0365
# ✅ # Steps: 9; e_form: P=-0.3619, GT=-0.3658, Δ=0.0040, MAE=0.0363
# ✅ # Steps: 25; e_form: P=-1.0345, GT=-1.0477, Δ=0.0131, MAE=0.0362
# ✅ # Steps: 10; e_form: P=-1.0879, GT=-1.0524, Δ=0.0355, MAE=0.0362
# ✅ # Steps: 5; e_form: P=-0.6645, GT=-0.6714, Δ=0.0069, MAE=0.0361
# ✅ # Steps: 17; e_form: P=-0.4249, GT=-0.3983, Δ=0.0266, MAE=0.0360
# ✅ # Steps: 31; e_form: P=-0.3222, GT=-0.3037, Δ=0.0185, MAE=0.0360
# ❌ # Steps: 21; e_form: P=-0.1319, GT=-0.3480, Δ=0.2162, MAE=0.0368
# ✅ # Steps: 9; e_form: P=-1.0626, GT=-1.0525, Δ=0.0101, MAE=0.0366
# ✅ # Steps: 18; e_form: P=-0.9881, GT=-0.9909, Δ=0.0028, MAE=0.0365
# ✅ # Steps: 5; e_form: P=-3.0719, GT=-3.0627, Δ=0.0092, MAE=0.0364
# ✅ # Steps: 23; e_form: P=-0.4302, GT=-0.3499, Δ=0.0804, MAE=0.0366
# ✅ # Steps: 13; e_form: P=-0.1984, GT=-0.1976, Δ=0.0008, MAE=0.0364
# ✅ # Steps: 23; e_form: P=-3.3394, GT=-3.3686, Δ=0.0292, MAE=0.0364
# ✅ # Steps: 8; e_form: P=-0.7484, GT=-0.7212, Δ=0.0272, MAE=0.0363
# ✅ # Steps: 13; e_form: P=-0.1548, GT=-0.1401, Δ=0.0147, MAE=0.0362
# ✅ # Steps: 31; e_form: P=-2.8654, GT=-2.8415, Δ=0.0238, MAE=0.0362
# ✅ # Steps: 22; e_form: P=-1.5767, GT=-1.5647, Δ=0.0120, MAE=0.0361
# ✅ # Steps: 9; e_form: P=-0.1307, GT=-0.1571, Δ=0.0264, MAE=0.0361
# ✅ # Steps: 13; e_form: P=-0.6399, GT=-0.6765, Δ=0.0366, MAE=0.0361
# ✅ # Steps: 5; e_form: P=-3.6502, GT=-3.6802, Δ=0.0300, MAE=0.0360
# ✅ # Steps: 44; e_form: P=-0.4170, GT=-0.3848, Δ=0.0322, MAE=0.0360
# ❌ # Steps: 29; e_form: P=-1.3845, GT=-1.5717, Δ=0.1872, MAE=0.0366
# ❌ # Steps: 22; e_form: P=-0.1947, GT=-0.3421, Δ=0.1474, MAE=0.0371
# ✅ # Steps: 10; e_form: P=0.1516, GT=0.1931, Δ=0.0416, MAE=0.0371
# ✅ # Steps: 6; e_form: P=-0.2558, GT=-0.2368, Δ=0.0190, MAE=0.0370
# ❌ # Steps: 23; e_form: P=-0.2851, GT=-0.1679, Δ=0.1171, MAE=0.0374
# ✅ # Steps: 13; e_form: P=0.0667, GT=0.0467, Δ=0.0200, MAE=0.0373
# ✅ # Steps: 12; e_form: P=-0.1921, GT=-0.1632, Δ=0.0288, MAE=0.0373
# ✅ # Steps: 7; e_form: P=-1.3494, GT=-1.3506, Δ=0.0012, MAE=0.0371
# ✅ # Steps: 13; e_form: P=0.2409, GT=0.2362, Δ=0.0047, MAE=0.0370
# ❌ # Steps: 14; e_form: P=-0.9992, GT=-1.1042, Δ=0.1050, MAE=0.0372
# ✅ # Steps: 12; e_form: P=-1.5550, GT=-1.5607, Δ=0.0057, MAE=0.0371
# ✅ # Steps: 5; e_form: P=-0.3480, GT=-0.3255, Δ=0.0225, MAE=0.0371
# ✅ # Steps: 18; e_form: P=-0.1082, GT=-0.1849, Δ=0.0767, MAE=0.0372
# ✅ # Steps: 5; e_form: P=-0.0165, GT=0.0284, Δ=0.0449, MAE=0.0373
# ✅ # Steps: 23; e_form: P=-2.1615, GT=-2.1538, Δ=0.0077, MAE=0.0371
# ✅ # Steps: 7; e_form: P=-0.1245, GT=-0.1270, Δ=0.0025, MAE=0.0370
# ✅ # Steps: 31; e_form: P=-2.5173, GT=-2.5486, Δ=0.0313, MAE=0.0370
# ❌ # Steps: 7; e_form: P=0.0776, GT=0.2551, Δ=0.1775, MAE=0.0375
# ✅ # Steps: 29; e_form: P=-1.0864, GT=-1.0975, Δ=0.0111, MAE=0.0374
# ✅ # Steps: 7; e_form: P=-0.5264, GT=-0.5501, Δ=0.0237, MAE=0.0374
# ❌ # Steps: 36; e_form: P=0.0778, GT=-0.0254, Δ=0.1032, MAE=0.0376
# ✅ # Steps: 6; e_form: P=-0.3926, GT=-0.3760, Δ=0.0166, MAE=0.0375
# ✅ # Steps: 27; e_form: P=-2.8884, GT=-2.8902, Δ=0.0017, MAE=0.0374
# ✅ # Steps: 11; e_form: P=-0.1511, GT=-0.1396, Δ=0.0115, MAE=0.0373
# ✅ # Steps: 20; e_form: P=-0.3430, GT=-0.3002, Δ=0.0428, MAE=0.0373
# ✅ # Steps: 18; e_form: P=-1.2045, GT=-1.2135, Δ=0.0089, MAE=0.0372
# ✅ # Steps: 22; e_form: P=-0.9718, GT=-0.9548, Δ=0.0171, MAE=0.0371
# ✅ # Steps: 2; e_form: P=-0.8065, GT=-0.7914, Δ=0.0152, MAE=0.0371
# ✅ # Steps: 13; e_form: P=-0.4933, GT=-0.4398, Δ=0.0535, MAE=0.0371
# ✅ # Steps: 6; e_form: P=-0.3648, GT=-0.2929, Δ=0.0718, MAE=0.0373
# ✅ # Steps: 19; e_form: P=-0.7319, GT=-0.7239, Δ=0.0080, MAE=0.0371
# ❌ # Steps: 44; e_form: P=-0.1937, GT=-0.3606, Δ=0.1669, MAE=0.0376
# ✅ # Steps: 11; e_form: P=-1.4266, GT=-1.4032, Δ=0.0235, MAE=0.0376
# ✅ # Steps: 5; e_form: P=-3.4649, GT=-3.4962, Δ=0.0313, MAE=0.0375
# ✅ # Steps: 18; e_form: P=-1.1639, GT=-1.1287, Δ=0.0352, MAE=0.0375
# ✅ # Steps: 7; e_form: P=-0.5695, GT=-0.5259, Δ=0.0436, MAE=0.0376
# ✅ # Steps: 2; e_form: P=-0.2809, GT=-0.2606, Δ=0.0202, MAE=0.0375
# ✅ # Steps: 6; e_form: P=-0.3057, GT=-0.2970, Δ=0.0087, MAE=0.0374
# ✅ # Steps: 11; e_form: P=-0.6498, GT=-0.5697, Δ=0.0802, MAE=0.0375
# ✅ # Steps: 15; e_form: P=-2.5845, GT=-2.5824, Δ=0.0020, MAE=0.0374
# ✅ # Steps: 15; e_form: P=-0.4383, GT=-0.4214, Δ=0.0170, MAE=0.0373
# ✅ # Steps: 18; e_form: P=-0.0746, GT=-0.0098, Δ=0.0647, MAE=0.0374
# ✅ # Steps: 19; e_form: P=-0.4546, GT=-0.4612, Δ=0.0066, MAE=0.0373
# ✅ # Steps: 34; e_form: P=-0.3145, GT=-0.2485, Δ=0.0660, MAE=0.0374
# ✅ # Steps: 7; e_form: P=-0.6214, GT=-0.5462, Δ=0.0752, MAE=0.0376
# ✅ # Steps: 9; e_form: P=-3.1602, GT=-3.1631, Δ=0.0029, MAE=0.0374
# ✅ # Steps: 29; e_form: P=-0.0777, GT=-0.0943, Δ=0.0166, MAE=0.0374
# ✅ # Steps: 22; e_form: P=-0.6671, GT=-0.6579, Δ=0.0092, MAE=0.0373
# ✅ # Steps: 6; e_form: P=-0.6605, GT=-0.6384, Δ=0.0221, MAE=0.0372
# ✅ # Steps: 29; e_form: P=-0.3739, GT=-0.3552, Δ=0.0187, MAE=0.0372
# ✅ # Steps: 29; e_form: P=-0.7706, GT=-0.8418, Δ=0.0712, MAE=0.0373
# ✅ # Steps: 5; e_form: P=-1.1040, GT=-1.0746, Δ=0.0294, MAE=0.0373
# ✅ # Steps: 20; e_form: P=-1.5996, GT=-1.5943, Δ=0.0053, MAE=0.0371
# ✅ # Steps: 15; e_form: P=-0.6083, GT=-0.5547, Δ=0.0536, MAE=0.0372
# ✅ # Steps: 19; e_form: P=0.1202, GT=0.0806, Δ=0.0396, MAE=0.0372
# ✅ # Steps: 35; e_form: P=-1.4280, GT=-1.4336, Δ=0.0056, MAE=0.0371
# ✅ # Steps: 16; e_form: P=-2.3704, GT=-2.3755, Δ=0.0051, MAE=0.0370
# ✅ # Steps: 11; e_form: P=-1.4414, GT=-1.4308, Δ=0.0106, MAE=0.0369
# ✅ # Steps: 14; e_form: P=-0.3340, GT=-0.3374, Δ=0.0034, MAE=0.0368
# ✅ # Steps: 21; e_form: P=-0.9301, GT=-0.9316, Δ=0.0015, MAE=0.0367
# ✅ # Steps: 18; e_form: P=-0.3174, GT=-0.3162, Δ=0.0012, MAE=0.0366
# ✅ # Steps: 7; e_form: P=0.0534, GT=0.0511, Δ=0.0023, MAE=0.0365
# ✅ # Steps: 26; e_form: P=0.1638, GT=0.1616, Δ=0.0023, MAE=0.0363
# ✅ # Steps: 18; e_form: P=-0.1065, GT=-0.0789, Δ=0.0276, MAE=0.0363
# ✅ # Steps: 2; e_form: P=-0.2673, GT=-0.2545, Δ=0.0128, MAE=0.0362
# ✅ # Steps: 15; e_form: P=-0.0960, GT=0.0015, Δ=0.0975, MAE=0.0364
# ✅ # Steps: 2; e_form: P=-0.1525, GT=-0.1631, Δ=0.0107, MAE=0.0363
# ✅ # Steps: 2; e_form: P=-0.1828, GT=-0.1271, Δ=0.0557, MAE=0.0364
# ✅ # Steps: 6; e_form: P=-0.5264, GT=-0.5222, Δ=0.0043, MAE=0.0363
# ✅ # Steps: 8; e_form: P=-1.9775, GT=-1.9784, Δ=0.0008, MAE=0.0362
# ✅ # Steps: 7; e_form: P=-0.5937, GT=-0.5776, Δ=0.0161, MAE=0.0361
# ✅ # Steps: 22; e_form: P=-0.2710, GT=-0.2747, Δ=0.0037, MAE=0.0360
# ✅ # Steps: 5; e_form: P=-1.4824, GT=-1.4847, Δ=0.0024, MAE=0.0359
# ✅ # Steps: 2; e_form: P=-0.3402, GT=-0.3292, Δ=0.0110, MAE=0.0358
# ✅ # Steps: 38; e_form: P=-0.9811, GT=-0.9625, Δ=0.0186, MAE=0.0358
# ✅ # Steps: 11; e_form: P=-0.5336, GT=-0.5177, Δ=0.0159, MAE=0.0357
# ✅ # Steps: 16; e_form: P=0.1727, GT=0.2082, Δ=0.0355, MAE=0.0357
# ✅ # Steps: 12; e_form: P=-0.4011, GT=-0.3508, Δ=0.0503, MAE=0.0358
# ✅ # Steps: 14; e_form: P=-0.4327, GT=-0.4470, Δ=0.0144, MAE=0.0357
# ✅ # Steps: 10; e_form: P=0.2269, GT=0.1911, Δ=0.0358, MAE=0.0357
# ✅ # Steps: 5; e_form: P=0.1985, GT=0.1542, Δ=0.0443, MAE=0.0357
# ✅ # Steps: 18; e_form: P=-0.8291, GT=-0.8076, Δ=0.0214, MAE=0.0357
# ✅ # Steps: 5; e_form: P=0.1392, GT=0.0925, Δ=0.0467, MAE=0.0357
# ✅ # Steps: 33; e_form: P=-1.7797, GT=-1.8111, Δ=0.0314, MAE=0.0357
# ✅ # Steps: 14; e_form: P=-0.1303, GT=-0.1634, Δ=0.0330, MAE=0.0357
# ✅ # Steps: 10; e_form: P=-0.4983, GT=-0.5007, Δ=0.0024, MAE=0.0356
# ✅ # Steps: 26; e_form: P=-1.4187, GT=-1.4078, Δ=0.0109, MAE=0.0355
# ✅ # Steps: 18; e_form: P=-0.2150, GT=-0.1708, Δ=0.0442, MAE=0.0355
# ✅ # Steps: 23; e_form: P=-0.3921, GT=-0.3685, Δ=0.0236, MAE=0.0355
# ✅ # Steps: 35; e_form: P=0.0003, GT=0.0935, Δ=0.0932, MAE=0.0357
# ✅ # Steps: 12; e_form: P=-0.2561, GT=-0.1931, Δ=0.0630, MAE=0.0358
# ✅ # Steps: 10; e_form: P=-0.0900, GT=-0.1240, Δ=0.0339, MAE=0.0358
# ✅ # Steps: 12; e_form: P=0.0849, GT=0.1337, Δ=0.0488, MAE=0.0358
# ✅ # Steps: 5; e_form: P=0.0552, GT=0.0083, Δ=0.0469, MAE=0.0358
# ❌ # Steps: 18; e_form: P=-0.5576, GT=-0.8105, Δ=0.2529, MAE=0.0365
# ✅ # Steps: 5; e_form: P=-0.5472, GT=-0.4951, Δ=0.0521, MAE=0.0365
# ✅ # Steps: 45; e_form: P=-2.7090, GT=-2.7213, Δ=0.0124, MAE=0.0365
# ✅ # Steps: 9; e_form: P=-0.3868, GT=-0.3632, Δ=0.0236, MAE=0.0364
# ❌ # Steps: 7; e_form: P=0.0299, GT=0.2833, Δ=0.2534, MAE=0.0370
# ✅ # Steps: 5; e_form: P=-1.2851, GT=-1.2431, Δ=0.0419, MAE=0.0371
# ✅ # Steps: 23; e_form: P=-0.3881, GT=-0.3484, Δ=0.0397, MAE=0.0371
# ✅ # Steps: 2; e_form: P=-0.1534, GT=-0.1932, Δ=0.0398, MAE=0.0371
# ✅ # Steps: 5; e_form: P=0.0300, GT=0.0308, Δ=0.0007, MAE=0.0370
# ✅ # Steps: 8; e_form: P=-0.5856, GT=-0.5981, Δ=0.0125, MAE=0.0369
# ❌ # Steps: 9; e_form: P=0.3295, GT=0.5118, Δ=0.1823, MAE=0.0373
# ✅ # Steps: 2; e_form: P=-0.4173, GT=-0.4102, Δ=0.0071, MAE=0.0372
# ✅ # Steps: 23; e_form: P=-2.6838, GT=-2.6799, Δ=0.0039, MAE=0.0371
# ✅ # Steps: 5; e_form: P=-0.4943, GT=-0.5014, Δ=0.0071, MAE=0.0371
# ✅ # Steps: 7; e_form: P=-0.3012, GT=-0.2690, Δ=0.0322, MAE=0.0370
# ✅ # Steps: 11; e_form: P=-0.2895, GT=-0.2638, Δ=0.0257, MAE=0.0370
# ✅ # Steps: 12; e_form: P=-0.4063, GT=-0.3963, Δ=0.0101, MAE=0.0369
# ✅ # Steps: 25; e_form: P=-0.3552, GT=-0.2654, Δ=0.0898, MAE=0.0371
# ❌ # Steps: 9; e_form: P=-0.4197, GT=-0.6032, Δ=0.1835, MAE=0.0375
# ✅ # Steps: 17; e_form: P=-0.1316, GT=-0.1310, Δ=0.0006, MAE=0.0374
# ✅ # Steps: 16; e_form: P=0.1352, GT=0.1694, Δ=0.0342, MAE=0.0374
# ✅ # Steps: 9; e_form: P=-1.3454, GT=-1.3569, Δ=0.0115, MAE=0.0373
# ✅ # Steps: 21; e_form: P=-0.7775, GT=-0.8004, Δ=0.0229, MAE=0.0373
# ✅ # Steps: 6; e_form: P=-0.3398, GT=-0.3201, Δ=0.0197, MAE=0.0372
# ✅ # Steps: 26; e_form: P=-0.4694, GT=-0.4318, Δ=0.0376, MAE=0.0372
# ✅ # Steps: 31; e_form: P=-1.9704, GT=-2.0279, Δ=0.0575, MAE=0.0373
# ✅ # Steps: 21; e_form: P=-0.6486, GT=-0.6544, Δ=0.0058, MAE=0.0372
# ✅ # Steps: 18; e_form: P=0.3358, GT=0.3798, Δ=0.0441, MAE=0.0372
# ✅ # Steps: 11; e_form: P=-0.6349, GT=-0.5976, Δ=0.0373, MAE=0.0372
# ✅ # Steps: 26; e_form: P=-1.4841, GT=-1.4740, Δ=0.0100, MAE=0.0371
# ✅ # Steps: 2; e_form: P=-0.3213, GT=-0.2463, Δ=0.0750, MAE=0.0372
# ❌ # Steps: 6; e_form: P=-1.3380, GT=-1.2141, Δ=0.1239, MAE=0.0375
# ✅ # Steps: 18; e_form: P=-1.1733, GT=-1.1408, Δ=0.0325, MAE=0.0375
# ✅ # Steps: 5; e_form: P=-0.5993, GT=-0.5878, Δ=0.0115, MAE=0.0374
# ✅ # Steps: 5; e_form: P=-0.5214, GT=-0.4503, Δ=0.0711, MAE=0.0375
# ✅ # Steps: 14; e_form: P=-0.2632, GT=-0.3049, Δ=0.0417, MAE=0.0375
# ✅ # Steps: 5; e_form: P=-0.9705, GT=-0.9830, Δ=0.0125, MAE=0.0374
# ✅ # Steps: 29; e_form: P=-0.1443, GT=-0.1532, Δ=0.0089, MAE=0.0373
# ✅ # Steps: 6; e_form: P=-0.3112, GT=-0.3044, Δ=0.0068, MAE=0.0373
# ✅ # Steps: 6; e_form: P=-1.7090, GT=-1.6222, Δ=0.0867, MAE=0.0374
# ✅ # Steps: 16; e_form: P=-0.0344, GT=-0.0301, Δ=0.0042, MAE=0.0373
# ✅ # Steps: 5; e_form: P=-0.4561, GT=-0.4251, Δ=0.0310, MAE=0.0373
# ✅ # Steps: 33; e_form: P=-0.5244, GT=-0.5130, Δ=0.0114, MAE=0.0372
# ✅ # Steps: 21; e_form: P=-3.1242, GT=-3.1520, Δ=0.0278, MAE=0.0372
# ✅ # Steps: 5; e_form: P=-0.4087, GT=-0.3649, Δ=0.0438, MAE=0.0372
# ✅ # Steps: 11; e_form: P=-2.2079, GT=-2.2342, Δ=0.0263, MAE=0.0372
# ✅ # Steps: 11; e_form: P=-0.5512, GT=-0.5325, Δ=0.0187, MAE=0.0371
# ✅ # Steps: 17; e_form: P=-0.4810, GT=-0.4471, Δ=0.0339, MAE=0.0371
# ✅ # Steps: 11; e_form: P=-2.7044, GT=-2.7168, Δ=0.0124, MAE=0.0371
# ✅ # Steps: 19; e_form: P=-1.1376, GT=-1.2164, Δ=0.0788, MAE=0.0372
# ✅ # Steps: 17; e_form: P=-2.1424, GT=-2.1397, Δ=0.0027, MAE=0.0371
# ✅ # Steps: 18; e_form: P=-0.3655, GT=-0.3764, Δ=0.0110, MAE=0.0370
# ✅ # Steps: 14; e_form: P=-0.8834, GT=-0.8865, Δ=0.0031, MAE=0.0369
# ✅ # Steps: 33; e_form: P=0.2187, GT=0.2417, Δ=0.0230, MAE=0.0369
# ✅ # Steps: 2; e_form: P=-0.1593, GT=-0.1682, Δ=0.0088, MAE=0.0368
# ✅ # Steps: 4; e_form: P=-0.2469, GT=-0.3432, Δ=0.0964, MAE=0.0370
# ✅ # Steps: 2; e_form: P=-0.2675, GT=-0.2321, Δ=0.0354, MAE=0.0370
# ✅ # Steps: 17; e_form: P=-0.1534, GT=-0.1878, Δ=0.0344, MAE=0.0370
# ✅ # Steps: 27; e_form: P=-0.0658, GT=-0.1427, Δ=0.0770, MAE=0.0371
# ❌ # Steps: 26; e_form: P=0.2042, GT=0.5987, Δ=0.3945, MAE=0.0380
# ✅ # Steps: 4; e_form: P=-1.2931, GT=-1.2601, Δ=0.0330, MAE=0.0380
# ✅ # Steps: 10; e_form: P=-0.1009, GT=-0.0534, Δ=0.0474, MAE=0.0380
# ✅ # Steps: 16; e_form: P=-0.3752, GT=-0.3431, Δ=0.0321, MAE=0.0380
# ✅ # Steps: 4; e_form: P=-0.3355, GT=-0.3222, Δ=0.0133, MAE=0.0379
# ✅ # Steps: 30; e_form: P=0.1551, GT=0.1170, Δ=0.0382, MAE=0.0379
# ✅ # Steps: 5; e_form: P=-0.4216, GT=-0.4119, Δ=0.0096, MAE=0.0378
# ❌ # Steps: 15; e_form: P=-0.1902, GT=-0.4360, Δ=0.2458, MAE=0.0383
# ✅ # Steps: 21; e_form: P=-0.8439, GT=-0.8111, Δ=0.0328, MAE=0.0383
# ✅ # Steps: 17; e_form: P=-3.1847, GT=-3.1884, Δ=0.0037, MAE=0.0382
# ✅ # Steps: 26; e_form: P=-0.2210, GT=-0.1988, Δ=0.0222, MAE=0.0382
# ✅ # Steps: 24; e_form: P=-0.5860, GT=-0.5643, Δ=0.0217, MAE=0.0382
# ✅ # Steps: 12; e_form: P=-1.9420, GT=-1.8787, Δ=0.0633, MAE=0.0382
# ✅ # Steps: 7; e_form: P=0.0465, GT=-0.0276, Δ=0.0741, MAE=0.0383
# ❌ # Steps: 5; e_form: P=-2.5537, GT=-2.2873, Δ=0.2664, MAE=0.0389
# ✅ # Steps: 11; e_form: P=-0.4256, GT=-0.4083, Δ=0.0172, MAE=0.0388
# ✅ # Steps: 22; e_form: P=-0.3654, GT=-0.3668, Δ=0.0014, MAE=0.0387
# ✅ # Steps: 9; e_form: P=-0.0939, GT=-0.0705, Δ=0.0234, MAE=0.0387
# ✅ # Steps: 39; e_form: P=0.0241, GT=-0.0077, Δ=0.0317, MAE=0.0387
# ✅ # Steps: 8; e_form: P=-0.2609, GT=-0.2668, Δ=0.0059, MAE=0.0386
# ✅ # Steps: 12; e_form: P=-0.3476, GT=-0.3127, Δ=0.0350, MAE=0.0386
# ✅ # Steps: 7; e_form: P=-0.5940, GT=-0.5940, Δ=0.0000, MAE=0.0385
# ✅ # Steps: 13; e_form: P=-0.3399, GT=-0.3200, Δ=0.0199, MAE=0.0385
# ✅ # Steps: 5; e_form: P=-1.7263, GT=-1.7240, Δ=0.0023, MAE=0.0384
# ✅ # Steps: 8; e_form: P=-0.9320, GT=-0.8786, Δ=0.0534, MAE=0.0384
# ✅ # Steps: 9; e_form: P=-0.3750, GT=-0.3632, Δ=0.0118, MAE=0.0383
# ✅ # Steps: 37; e_form: P=-0.3429, GT=-0.2736, Δ=0.0693, MAE=0.0384
# ❌ # Steps: 10; e_form: P=-0.7801, GT=-0.6666, Δ=0.1135, MAE=0.0386
# ✅ # Steps: 15; e_form: P=0.7445, GT=0.6818, Δ=0.0627, MAE=0.0386
# ✅ # Steps: 10; e_form: P=-0.6384, GT=-0.6665, Δ=0.0282, MAE=0.0386
# ✅ # Steps: 16; e_form: P=-1.4605, GT=-1.5061, Δ=0.0456, MAE=0.0386
# ✅ # Steps: 16; e_form: P=-0.1148, GT=-0.1093, Δ=0.0055, MAE=0.0386
# ✅ # Steps: 8; e_form: P=-0.6042, GT=-0.5989, Δ=0.0053, MAE=0.0385
# ✅ # Steps: 17; e_form: P=-0.5046, GT=-0.4924, Δ=0.0122, MAE=0.0384
# ✅ # Steps: 17; e_form: P=-1.3396, GT=-1.3336, Δ=0.0060, MAE=0.0383
# ✅ # Steps: 8; e_form: P=-3.2554, GT=-3.2792, Δ=0.0239, MAE=0.0383
# ❌ # Steps: 20; e_form: P=0.2445, GT=0.3832, Δ=0.1387, MAE=0.0385
# ✅ # Steps: 8; e_form: P=0.0661, GT=0.0537, Δ=0.0124, MAE=0.0385
# ✅ # Steps: 20; e_form: P=-0.0381, GT=0.0027, Δ=0.0408, MAE=0.0385
# ✅ # Steps: 11; e_form: P=-0.5447, GT=-0.5196, Δ=0.0251, MAE=0.0385
# ✅ # Steps: 25; e_form: P=-2.2570, GT=-2.2587, Δ=0.0017, MAE=0.0384
# ✅ # Steps: 17; e_form: P=-1.2491, GT=-1.2841, Δ=0.0350, MAE=0.0384
# ✅ # Steps: 13; e_form: P=-0.7488, GT=-0.7231, Δ=0.0257, MAE=0.0383
# ✅ # Steps: 19; e_form: P=-0.4468, GT=-0.4143, Δ=0.0325, MAE=0.0383
# ✅ # Steps: 28; e_form: P=-0.7813, GT=-0.7934, Δ=0.0121, MAE=0.0383
# ✅ # Steps: 21; e_form: P=0.1760, GT=0.1865, Δ=0.0105, MAE=0.0382
# ✅ # Steps: 6; e_form: P=-0.4553, GT=-0.4318, Δ=0.0235, MAE=0.0382
# ✅ # Steps: 14; e_form: P=-0.0780, GT=-0.0863, Δ=0.0083, MAE=0.0381
# ✅ # Steps: 2; e_form: P=-0.7336, GT=-0.7530, Δ=0.0193, MAE=0.0381
# ✅ # Steps: 13; e_form: P=0.0471, GT=-0.0371, Δ=0.0842, MAE=0.0382
# ✅ # Steps: 5; e_form: P=-0.0905, GT=-0.0964, Δ=0.0059, MAE=0.0381
# ✅ # Steps: 6; e_form: P=-0.2886, GT=-0.2518, Δ=0.0368, MAE=0.0381
# ✅ # Steps: 32; e_form: P=-0.4141, GT=-0.4321, Δ=0.0180, MAE=0.0380
# ✅ # Steps: 2; e_form: P=-0.2317, GT=-0.2002, Δ=0.0316, MAE=0.0380
# ✅ # Steps: 5; e_form: P=-2.6072, GT=-2.6040, Δ=0.0032, MAE=0.0380
# ✅ # Steps: 18; e_form: P=-0.0286, GT=0.0170, Δ=0.0455, MAE=0.0380
# ✅ # Steps: 4; e_form: P=-0.4741, GT=-0.4771, Δ=0.0030, MAE=0.0379
# ✅ # Steps: 11; e_form: P=-0.3052, GT=-0.2191, Δ=0.0861, MAE=0.0380
# ✅ # Steps: 36; e_form: P=0.0181, GT=0.0449, Δ=0.0268, MAE=0.0380
# ✅ # Steps: 36; e_form: P=-0.4573, GT=-0.4633, Δ=0.0059, MAE=0.0379
# ✅ # Steps: 5; e_form: P=-1.6571, GT=-1.7061, Δ=0.0491, MAE=0.0379
# ✅ # Steps: 4; e_form: P=-0.3173, GT=-0.2892, Δ=0.0281, MAE=0.0379
# ✅ # Steps: 21; e_form: P=-0.4923, GT=-0.4551, Δ=0.0372, MAE=0.0379
# ✅ # Steps: 22; e_form: P=-0.0216, GT=-0.0117, Δ=0.0099, MAE=0.0378
# ✅ # Steps: 26; e_form: P=-2.3356, GT=-2.3555, Δ=0.0198, MAE=0.0378
# ✅ # Steps: 5; e_form: P=-0.7919, GT=-0.8149, Δ=0.0230, MAE=0.0378
# ✅ # Steps: 6; e_form: P=-0.4909, GT=-0.4467, Δ=0.0442, MAE=0.0378
# ✅ # Steps: 17; e_form: P=0.0104, GT=0.0827, Δ=0.0723, MAE=0.0379
# ✅ # Steps: 25; e_form: P=-0.0203, GT=0.0775, Δ=0.0978, MAE=0.0380
# ✅ # Steps: 30; e_form: P=0.1435, GT=0.1238, Δ=0.0197, MAE=0.0380
# ✅ # Steps: 7; e_form: P=-0.9891, GT=-1.0357, Δ=0.0466, MAE=0.0380
# ✅ # Steps: 71; e_form: P=-2.5658, GT=-2.5686, Δ=0.0028, MAE=0.0379
# ✅ # Steps: 12; e_form: P=-0.4097, GT=-0.3769, Δ=0.0328, MAE=0.0379
# ✅ # Steps: 32; e_form: P=-3.3931, GT=-3.3940, Δ=0.0008, MAE=0.0378
# ✅ # Steps: 4; e_form: P=-0.3029, GT=-0.3032, Δ=0.0003, MAE=0.0377
# ✅ # Steps: 16; e_form: P=-3.3222, GT=-3.3388, Δ=0.0167, MAE=0.0377
# ✅ # Steps: 39; e_form: P=-2.6849, GT=-2.6596, Δ=0.0253, MAE=0.0377
# ✅ # Steps: 33; e_form: P=-2.1358, GT=-2.1376, Δ=0.0018, MAE=0.0376
# ✅ # Steps: 2; e_form: P=-0.0569, GT=-0.0600, Δ=0.0032, MAE=0.0375
# ✅ # Steps: 5; e_form: P=-0.5710, GT=-0.5583, Δ=0.0127, MAE=0.0375
# ✅ # Steps: 14; e_form: P=-0.4835, GT=-0.4692, Δ=0.0142, MAE=0.0374
# ✅ # Steps: 7; e_form: P=-0.1166, GT=-0.0707, Δ=0.0459, MAE=0.0374
# ✅ # Steps: 7; e_form: P=0.0335, GT=0.1151, Δ=0.0816, MAE=0.0375
# ❌ # Steps: 20; e_form: P=0.0053, GT=-0.1343, Δ=0.1396, MAE=0.0377
# ✅ # Steps: 18; e_form: P=-0.2943, GT=-0.3037, Δ=0.0094, MAE=0.0377
# ✅ # Steps: 19; e_form: P=-1.2773, GT=-1.2667, Δ=0.0106, MAE=0.0376
# ✅ # Steps: 23; e_form: P=-0.4450, GT=-0.4045, Δ=0.0405, MAE=0.0376
# ✅ # Steps: 4; e_form: P=-2.2823, GT=-2.2861, Δ=0.0038, MAE=0.0375
# ✅ # Steps: 3; e_form: P=0.1592, GT=0.2393, Δ=0.0801, MAE=0.0376
# ✅ # Steps: 15; e_form: P=-0.9175, GT=-0.8561, Δ=0.0613, MAE=0.0377
# ❌ # Steps: 6; e_form: P=-0.7982, GT=-0.6908, Δ=0.1074, MAE=0.0378
# ✅ # Steps: 3; e_form: P=-0.6316, GT=-0.6344, Δ=0.0028, MAE=0.0378
# ✅ # Steps: 25; e_form: P=-0.0061, GT=-0.0360, Δ=0.0299, MAE=0.0377
# ✅ # Steps: 16; e_form: P=-2.8907, GT=-2.8779, Δ=0.0128, MAE=0.0377
# ✅ # Steps: 5; e_form: P=-0.4945, GT=-0.4743, Δ=0.0202, MAE=0.0377
# ✅ # Steps: 6; e_form: P=-0.1596, GT=-0.1338, Δ=0.0257, MAE=0.0376
# ✅ # Steps: 5; e_form: P=-2.9853, GT=-2.9504, Δ=0.0349, MAE=0.0376
# ✅ # Steps: 11; e_form: P=-1.1656, GT=-1.1308, Δ=0.0347, MAE=0.0376
# ❌ # Steps: 6; e_form: P=-0.2151, GT=-0.0799, Δ=0.1351, MAE=0.0378
# ✅ # Steps: 6; e_form: P=-0.4411, GT=-0.4130, Δ=0.0282, MAE=0.0378
# ✅ # Steps: 11; e_form: P=-0.3077, GT=-0.2272, Δ=0.0805, MAE=0.0379
# ✅ # Steps: 9; e_form: P=-0.7042, GT=-0.7093, Δ=0.0051, MAE=0.0378
# ✅ # Steps: 28; e_form: P=-2.2310, GT=-2.2206, Δ=0.0105, MAE=0.0378
# ✅ # Steps: 10; e_form: P=-0.2995, GT=-0.2893, Δ=0.0102, MAE=0.0377
# ✅ # Steps: 21; e_form: P=-0.0295, GT=0.0387, Δ=0.0683, MAE=0.0378
# ✅ # Steps: 10; e_form: P=0.0175, GT=0.0543, Δ=0.0368, MAE=0.0378
# ✅ # Steps: 33; e_form: P=-1.3416, GT=-1.3329, Δ=0.0087, MAE=0.0377
# ✅ # Steps: 9; e_form: P=-1.2910, GT=-1.2761, Δ=0.0149, MAE=0.0377
# ✅ # Steps: 22; e_form: P=-1.4657, GT=-1.4766, Δ=0.0109, MAE=0.0376
# ✅ # Steps: 5; e_form: P=-0.2342, GT=-0.1685, Δ=0.0657, MAE=0.0377
# ✅ # Steps: 6; e_form: P=0.1204, GT=0.0730, Δ=0.0473, MAE=0.0377
# ✅ # Steps: 13; e_form: P=-0.8707, GT=-0.8669, Δ=0.0037, MAE=0.0376
# ✅ # Steps: 8; e_form: P=-2.6212, GT=-2.6322, Δ=0.0109, MAE=0.0376
# ✅ # Steps: 25; e_form: P=-1.3454, GT=-1.3443, Δ=0.0011, MAE=0.0375
# ✅ # Steps: 27; e_form: P=-0.6311, GT=-0.6475, Δ=0.0165, MAE=0.0375
# ✅ # Steps: 18; e_form: P=-0.1721, GT=-0.1826, Δ=0.0104, MAE=0.0374
# ✅ # Steps: 15; e_form: P=-2.0927, GT=-2.0983, Δ=0.0056, MAE=0.0373
# ✅ # Steps: 20; e_form: P=-0.3710, GT=-0.3503, Δ=0.0206, MAE=0.0373
# ✅ # Steps: 33; e_form: P=-0.1688, GT=-0.1580, Δ=0.0107, MAE=0.0373
# ✅ # Steps: 23; e_form: P=-0.1324, GT=-0.1598, Δ=0.0274, MAE=0.0372
# ✅ # Steps: 16; e_form: P=-0.7323, GT=-0.6876, Δ=0.0447, MAE=0.0372
# ✅ # Steps: 25; e_form: P=-1.2635, GT=-1.2993, Δ=0.0357, MAE=0.0372
# ✅ # Steps: 8; e_form: P=-0.5458, GT=-0.5501, Δ=0.0043, MAE=0.0372
# ✅ # Steps: 6; e_form: P=-1.0692, GT=-1.0896, Δ=0.0204, MAE=0.0372
# ✅ # Steps: 22; e_form: P=-0.4942, GT=-0.4637, Δ=0.0306, MAE=0.0371
# ✅ # Steps: 11; e_form: P=-0.2424, GT=-0.2614, Δ=0.0190, MAE=0.0371
# ❌ # Steps: 6; e_form: P=0.8429, GT=0.6411, Δ=0.2019, MAE=0.0374
# ✅ # Steps: 29; e_form: P=-0.1252, GT=-0.1034, Δ=0.0217, MAE=0.0374
# ✅ # Steps: 15; e_form: P=-0.5159, GT=-0.5191, Δ=0.0032, MAE=0.0373
# ❌ # Steps: 7; e_form: P=-0.4971, GT=-0.1120, Δ=0.3851, MAE=0.0380
# ✅ # Steps: 23; e_form: P=-0.1944, GT=-0.2499, Δ=0.0555, MAE=0.0380
# ✅ # Steps: 23; e_form: P=-2.4791, GT=-2.5247, Δ=0.0456, MAE=0.0380
# ❌ # Steps: 74; e_form: P=-2.5055, GT=-2.0179, Δ=0.4876, MAE=0.0389
# ✅ # Steps: 9; e_form: P=-3.4506, GT=-3.4688, Δ=0.0182, MAE=0.0388
# ✅ # Steps: 46; e_form: P=-1.7589, GT=-1.8129, Δ=0.0540, MAE=0.0389
# ✅ # Steps: 20; e_form: P=-1.6146, GT=-1.5940, Δ=0.0206, MAE=0.0388
# ❌ # Steps: 16; e_form: P=0.4586, GT=0.3225, Δ=0.1362, MAE=0.0390
# ✅ # Steps: 23; e_form: P=-0.4035, GT=-0.3965, Δ=0.0070, MAE=0.0390
# ✅ # Steps: 18; e_form: P=-0.0332, GT=0.0576, Δ=0.0908, MAE=0.0391
# ✅ # Steps: 7; e_form: P=-0.0351, GT=-0.0159, Δ=0.0193, MAE=0.0390
# ✅ # Steps: 12; e_form: P=0.1414, GT=0.1111, Δ=0.0302, MAE=0.0390
# ✅ # Steps: 20; e_form: P=-0.0102, GT=-0.0377, Δ=0.0275, MAE=0.0390
# ✅ # Steps: 11; e_form: P=-0.4977, GT=-0.5141, Δ=0.0164, MAE=0.0389
# ✅ # Steps: 49; e_form: P=-2.0660, GT=-2.1161, Δ=0.0501, MAE=0.0390
# ✅ # Steps: 65; e_form: P=-2.5043, GT=-2.5049, Δ=0.0006, MAE=0.0389
# ✅ # Steps: 6; e_form: P=-0.8271, GT=-0.8271, Δ=0.0000, MAE=0.0388
# ✅ # Steps: 11; e_form: P=-0.4549, GT=-0.5156, Δ=0.0607, MAE=0.0389
# ✅ # Steps: 22; e_form: P=-0.5813, GT=-0.5640, Δ=0.0173, MAE=0.0388
# ✅ # Steps: 15; e_form: P=-1.6750, GT=-1.6820, Δ=0.0070, MAE=0.0388
# ✅ # Steps: 4; e_form: P=-0.3634, GT=-0.3405, Δ=0.0229, MAE=0.0387
# ✅ # Steps: 7; e_form: P=-0.4531, GT=-0.4428, Δ=0.0103, MAE=0.0387
# ✅ # Steps: 9; e_form: P=-1.1316, GT=-1.1451, Δ=0.0136, MAE=0.0386
# ✅ # Steps: 13; e_form: P=-0.6204, GT=-0.6023, Δ=0.0181, MAE=0.0386
# ✅ # Steps: 14; e_form: P=-0.4090, GT=-0.3936, Δ=0.0154, MAE=0.0386
# ✅ # Steps: 10; e_form: P=-0.0488, GT=-0.0421, Δ=0.0067, MAE=0.0385
# ✅ # Steps: 10; e_form: P=-0.9968, GT=-0.9832, Δ=0.0136, MAE=0.0385
# ✅ # Steps: 4; e_form: P=-0.6029, GT=-0.5563, Δ=0.0466, MAE=0.0385
# ✅ # Steps: 21; e_form: P=-0.7876, GT=-0.7670, Δ=0.0207, MAE=0.0384
# ✅ # Steps: 25; e_form: P=-0.1781, GT=-0.1858, Δ=0.0077, MAE=0.0384
# ❌ # Steps: 50; e_form: P=-0.4472, GT=-0.2767, Δ=0.1705, MAE=0.0386
# ✅ # Steps: 18; e_form: P=-0.2411, GT=-0.2254, Δ=0.0157, MAE=0.0386
# ✅ # Steps: 10; e_form: P=-0.6436, GT=-0.6263, Δ=0.0173, MAE=0.0385
# ✅ # Steps: 20; e_form: P=-0.3782, GT=-0.3658, Δ=0.0124, MAE=0.0385
# ✅ # Steps: 9; e_form: P=0.1961, GT=0.2445, Δ=0.0484, MAE=0.0385
# ✅ # Steps: 30; e_form: P=-3.5271, GT=-3.5404, Δ=0.0132, MAE=0.0385
# ✅ # Steps: 5; e_form: P=0.0966, GT=0.1506, Δ=0.0541, MAE=0.0385
# ✅ # Steps: 13; e_form: P=-0.8016, GT=-0.8014, Δ=0.0001, MAE=0.0384
# ✅ # Steps: 4; e_form: P=-0.6381, GT=-0.6250, Δ=0.0130, MAE=0.0384
# ✅ # Steps: 13; e_form: P=-0.7037, GT=-0.7112, Δ=0.0075, MAE=0.0383
# ✅ # Steps: 16; e_form: P=-0.4418, GT=-0.4879, Δ=0.0461, MAE=0.0383
# ✅ # Steps: 7; e_form: P=-0.5255, GT=-0.4465, Δ=0.0790, MAE=0.0384
# ✅ # Steps: 17; e_form: P=-2.4069, GT=-2.3910, Δ=0.0159, MAE=0.0384
# ✅ # Steps: 5; e_form: P=-1.9685, GT=-1.9500, Δ=0.0186, MAE=0.0383
# ✅ # Steps: 5; e_form: P=-0.9710, GT=-1.0008, Δ=0.0297, MAE=0.0383
# ✅ # Steps: 9; e_form: P=-0.5885, GT=-0.6225, Δ=0.0340, MAE=0.0383
# ❌ # Steps: 5; e_form: P=0.0736, GT=0.3101, Δ=0.2365, MAE=0.0387
# ✅ # Steps: 19; e_form: P=-0.4114, GT=-0.3884, Δ=0.0230, MAE=0.0386
# ❌ # Steps: 9; e_form: P=-0.9116, GT=-1.0365, Δ=0.1249, MAE=0.0388
# ✅ # Steps: 14; e_form: P=-0.4121, GT=-0.4187, Δ=0.0066, MAE=0.0387
# ✅ # Steps: 10; e_form: P=-0.4881, GT=-0.4417, Δ=0.0464, MAE=0.0387
# ✅ # Steps: 16; e_form: P=-0.6796, GT=-0.7428, Δ=0.0631, MAE=0.0388
# ✅ # Steps: 29; e_form: P=-0.8817, GT=-0.8597, Δ=0.0220, MAE=0.0388
# ✅ # Steps: 7; e_form: P=-3.5349, GT=-3.5349, Δ=0.0001, MAE=0.0387
# ✅ # Steps: 22; e_form: P=-0.2571, GT=-0.1952, Δ=0.0619, MAE=0.0387
# ✅ # Steps: 4; e_form: P=-0.2048, GT=-0.1935, Δ=0.0112, MAE=0.0387
# ✅ # Steps: 39; e_form: P=-0.7349, GT=-0.7370, Δ=0.0021, MAE=0.0386
# ❌ # Steps: 9; e_form: P=-2.0958, GT=-1.9016, Δ=0.1942, MAE=0.0389
# ✅ # Steps: 7; e_form: P=-1.9425, GT=-1.9823, Δ=0.0398, MAE=0.0389
# ✅ # Steps: 2; e_form: P=-0.3716, GT=-0.3794, Δ=0.0078, MAE=0.0388
# ✅ # Steps: 10; e_form: P=-0.3207, GT=-0.3192, Δ=0.0016, MAE=0.0388
# ✅ # Steps: 15; e_form: P=-1.7009, GT=-1.7090, Δ=0.0081, MAE=0.0387
# ✅ # Steps: 12; e_form: P=-0.3005, GT=-0.2734, Δ=0.0271, MAE=0.0387
# ✅ # Steps: 8; e_form: P=-0.0281, GT=-0.0405, Δ=0.0124, MAE=0.0386
# ✅ # Steps: 10; e_form: P=-0.5402, GT=-0.5576, Δ=0.0174, MAE=0.0386
# ✅ # Steps: 2; e_form: P=-1.2523, GT=-1.2374, Δ=0.0149, MAE=0.0386
# ✅ # Steps: 7; e_form: P=-0.2768, GT=-0.2633, Δ=0.0135, MAE=0.0385
# ❌ # Steps: 5; e_form: P=-0.0736, GT=-0.1758, Δ=0.1023, MAE=0.0386
# ✅ # Steps: 21; e_form: P=-0.1225, GT=-0.1068, Δ=0.0157, MAE=0.0386
# ✅ # Steps: 23; e_form: P=-0.4054, GT=-0.4127, Δ=0.0073, MAE=0.0385
# ✅ # Steps: 33; e_form: P=-0.5047, GT=-0.4826, Δ=0.0221, MAE=0.0385
# ✅ # Steps: 5; e_form: P=-1.4256, GT=-1.4099, Δ=0.0157, MAE=0.0385
# ❌ # Steps: 7; e_form: P=-0.5360, GT=-0.4173, Δ=0.1187, MAE=0.0386
# ✅ # Steps: 24; e_form: P=-0.3358, GT=-0.3197, Δ=0.0161, MAE=0.0386
# ✅ # Steps: 5; e_form: P=-0.2736, GT=-0.2976, Δ=0.0240, MAE=0.0386
# ✅ # Steps: 12; e_form: P=0.0091, GT=-0.0142, Δ=0.0233, MAE=0.0385
# ✅ # Steps: 17; e_form: P=-0.6776, GT=-0.7193, Δ=0.0417, MAE=0.0385
# ✅ # Steps: 15; e_form: P=-0.5712, GT=-0.5270, Δ=0.0442, MAE=0.0385
# ✅ # Steps: 7; e_form: P=-0.5589, GT=-0.5331, Δ=0.0259, MAE=0.0385
# ✅ # Steps: 10; e_form: P=-1.2814, GT=-1.2780, Δ=0.0034, MAE=0.0385
# ❌ # Steps: 9; e_form: P=0.2347, GT=0.9251, Δ=0.6903, MAE=0.0395
# ✅ # Steps: 18; e_form: P=-0.7701, GT=-0.8090, Δ=0.0389, MAE=0.0395
# ✅ # Steps: 4; e_form: P=-0.9088, GT=-0.8695, Δ=0.0393, MAE=0.0395
# ✅ # Steps: 18; e_form: P=-0.3134, GT=-0.3124, Δ=0.0010, MAE=0.0395
# ✅ # Steps: 39; e_form: P=0.6161, GT=0.6197, Δ=0.0036, MAE=0.0394
# ✅ # Steps: 8; e_form: P=-1.4909, GT=-1.4732, Δ=0.0177, MAE=0.0394
# ✅ # Steps: 25; e_form: P=-2.8299, GT=-2.8317, Δ=0.0019, MAE=0.0393
# ✅ # Steps: 25; e_form: P=-0.1730, GT=-0.1441, Δ=0.0290, MAE=0.0393
# ✅ # Steps: 5; e_form: P=0.0447, GT=0.1213, Δ=0.0766, MAE=0.0394
# ✅ # Steps: 2; e_form: P=0.3543, GT=0.3241, Δ=0.0303, MAE=0.0393
# ✅ # Steps: 22; e_form: P=-0.4079, GT=-0.4136, Δ=0.0057, MAE=0.0393
# ✅ # Steps: 21; e_form: P=-0.1665, GT=-0.1356, Δ=0.0309, MAE=0.0393
# ✅ # Steps: 4; e_form: P=-0.4333, GT=-0.4099, Δ=0.0234, MAE=0.0393
# ✅ # Steps: 14; e_form: P=0.0385, GT=0.0589, Δ=0.0204, MAE=0.0392
# ✅ # Steps: 9; e_form: P=-0.6186, GT=-0.5900, Δ=0.0286, MAE=0.0392
# ✅ # Steps: 12; e_form: P=-0.6771, GT=-0.6247, Δ=0.0524, MAE=0.0392
# ✅ # Steps: 11; e_form: P=0.2717, GT=0.2956, Δ=0.0239, MAE=0.0392
# ✅ # Steps: 30; e_form: P=-0.8870, GT=-0.9058, Δ=0.0187, MAE=0.0392
# ❌ # Steps: 6; e_form: P=0.3360, GT=0.0095, Δ=0.3265, MAE=0.0396
# ✅ # Steps: 7; e_form: P=-0.3653, GT=-0.3522, Δ=0.0131, MAE=0.0396
# ❌ # Steps: 7; e_form: P=0.0256, GT=0.2431, Δ=0.2175, MAE=0.0399
# ✅ # Steps: 13; e_form: P=-0.5739, GT=-0.5717, Δ=0.0022, MAE=0.0398
# ✅ # Steps: 22; e_form: P=-0.2834, GT=-0.2693, Δ=0.0141, MAE=0.0398
# ✅ # Steps: 5; e_form: P=-4.0353, GT=-4.0791, Δ=0.0438, MAE=0.0398
# ✅ # Steps: 34; e_form: P=-1.4701, GT=-1.4986, Δ=0.0285, MAE=0.0398
# ✅ # Steps: 13; e_form: P=0.0526, GT=0.0833, Δ=0.0307, MAE=0.0397
# ✅ # Steps: 10; e_form: P=-1.0864, GT=-1.0677, Δ=0.0187, MAE=0.0397
# ✅ # Steps: 7; e_form: P=-0.3397, GT=-0.3062, Δ=0.0335, MAE=0.0397
# ❌ # Steps: 7; e_form: P=-0.3039, GT=-0.1545, Δ=0.1493, MAE=0.0399
# ✅ # Steps: 22; e_form: P=-0.0327, GT=0.0244, Δ=0.0571, MAE=0.0399
# ✅ # Steps: 30; e_form: P=-0.5095, GT=-0.4438, Δ=0.0657, MAE=0.0399
# ✅ # Steps: 25; e_form: P=-0.2079, GT=-0.1853, Δ=0.0227, MAE=0.0399
# ✅ # Steps: 5; e_form: P=-1.3146, GT=-1.2644, Δ=0.0501, MAE=0.0399
# ❌ # Steps: 7; e_form: P=-0.1684, GT=-0.0540, Δ=0.1144, MAE=0.0400
# ✅ # Steps: 8; e_form: P=-0.1771, GT=-0.1437, Δ=0.0334, MAE=0.0400
# ✅ # Steps: 5; e_form: P=-3.0475, GT=-3.0497, Δ=0.0022, MAE=0.0400
# ✅ # Steps: 13; e_form: P=-0.6953, GT=-0.6541, Δ=0.0412, MAE=0.0400
# ✅ # Steps: 28; e_form: P=-0.2971, GT=-0.2734, Δ=0.0237, MAE=0.0400
# ✅ # Steps: 17; e_form: P=-1.6565, GT=-1.6798, Δ=0.0232, MAE=0.0399
# ✅ # Steps: 5; e_form: P=-0.1654, GT=-0.1279, Δ=0.0375, MAE=0.0399
# ✅ # Steps: 35; e_form: P=-0.3837, GT=-0.3732, Δ=0.0104, MAE=0.0399
# ✅ # Steps: 9; e_form: P=-0.0560, GT=-0.0367, Δ=0.0192, MAE=0.0398
# ✅ # Steps: 5; e_form: P=-0.2147, GT=-0.1873, Δ=0.0275, MAE=0.0398
# ✅ # Steps: 6; e_form: P=0.0359, GT=0.0209, Δ=0.0149, MAE=0.0398
# ✅ # Steps: 8; e_form: P=-0.4609, GT=-0.4533, Δ=0.0075, MAE=0.0397
# ✅ # Steps: 11; e_form: P=-0.3184, GT=-0.3175, Δ=0.0009, MAE=0.0397
# ✅ # Steps: 27; e_form: P=-2.3157, GT=-2.2937, Δ=0.0221, MAE=0.0397
# ❌ # Steps: 24; e_form: P=-0.5355, GT=-0.4246, Δ=0.1109, MAE=0.0398
# ✅ # Steps: 33; e_form: P=-0.7878, GT=-0.8142, Δ=0.0264, MAE=0.0397
# ✅ # Steps: 2; e_form: P=-0.0633, GT=-0.0868, Δ=0.0236, MAE=0.0397
# ✅ # Steps: 4; e_form: P=-0.1859, GT=-0.1854, Δ=0.0006, MAE=0.0397
# ✅ # Steps: 40; e_form: P=-3.0596, GT=-3.0680, Δ=0.0084, MAE=0.0396
# ✅ # Steps: 17; e_form: P=-0.5584, GT=-0.5886, Δ=0.0302, MAE=0.0396
# ✅ # Steps: 10; e_form: P=-0.4929, GT=-0.4971, Δ=0.0041, MAE=0.0395
# ❌ # Steps: 17; e_form: P=-1.0417, GT=-0.8129, Δ=0.2287, MAE=0.0398
# ✅ # Steps: 7; e_form: P=-0.4496, GT=-0.3976, Δ=0.0520, MAE=0.0398
# ✅ # Steps: 11; e_form: P=-2.4961, GT=-2.4712, Δ=0.0249, MAE=0.0398
# ✅ # Steps: 17; e_form: P=-1.4538, GT=-1.4284, Δ=0.0254, MAE=0.0398
# ✅ # Steps: 24; e_form: P=-0.6735, GT=-0.6887, Δ=0.0152, MAE=0.0398
# ✅ # Steps: 79; e_form: P=-3.0796, GT=-3.0873, Δ=0.0077, MAE=0.0397
# ✅ # Steps: 6; e_form: P=-0.4601, GT=-0.4195, Δ=0.0406, MAE=0.0397
# ✅ # Steps: 14; e_form: P=-2.9821, GT=-2.9764, Δ=0.0057, MAE=0.0397
# ✅ # Steps: 6; e_form: P=-2.7463, GT=-2.7107, Δ=0.0356, MAE=0.0397
# ✅ # Steps: 18; e_form: P=-0.3908, GT=-0.4271, Δ=0.0364, MAE=0.0397
# ✅ # Steps: 30; e_form: P=-0.7336, GT=-0.7137, Δ=0.0199, MAE=0.0396
# ✅ # Steps: 32; e_form: P=-0.1650, GT=-0.1615, Δ=0.0034, MAE=0.0396
# ✅ # Steps: 5; e_form: P=-0.2326, GT=-0.2211, Δ=0.0115, MAE=0.0395
# ✅ # Steps: 5; e_form: P=-0.0332, GT=-0.0350, Δ=0.0018, MAE=0.0395
# ✅ # Steps: 10; e_form: P=-1.3683, GT=-1.3628, Δ=0.0056, MAE=0.0394
# ✅ # Steps: 14; e_form: P=-0.4807, GT=-0.5107, Δ=0.0300, MAE=0.0394
# ✅ # Steps: 10; e_form: P=-0.1847, GT=-0.1582, Δ=0.0265, MAE=0.0394
# ✅ # Steps: 6; e_form: P=0.4529, GT=0.5155, Δ=0.0626, MAE=0.0394
# ✅ # Steps: 7; e_form: P=-1.5284, GT=-1.4862, Δ=0.0422, MAE=0.0394
# ✅ # Steps: 6; e_form: P=-1.4095, GT=-1.4614, Δ=0.0519, MAE=0.0395
# ✅ # Steps: 11; e_form: P=-1.1652, GT=-1.1514, Δ=0.0138, MAE=0.0394
# ✅ # Steps: 6; e_form: P=-0.5339, GT=-0.4914, Δ=0.0425, MAE=0.0394
# ✅ # Steps: 8; e_form: P=-0.3021, GT=-0.2862, Δ=0.0159, MAE=0.0394
# ✅ # Steps: 60; e_form: P=-1.3381, GT=-1.3198, Δ=0.0183, MAE=0.0394
# ✅ # Steps: 5; e_form: P=-0.5074, GT=-0.5375, Δ=0.0301, MAE=0.0393
# ✅ # Steps: 20; e_form: P=0.0385, GT=0.0398, Δ=0.0013, MAE=0.0393
# ✅ # Steps: 11; e_form: P=-0.8021, GT=-0.7890, Δ=0.0131, MAE=0.0392
# ✅ # Steps: 15; e_form: P=-1.0986, GT=-1.1533, Δ=0.0547, MAE=0.0393
# ✅ # Steps: 23; e_form: P=-0.2232, GT=-0.1661, Δ=0.0571, MAE=0.0393
# ✅ # Steps: 2; e_form: P=0.2099, GT=0.2169, Δ=0.0070, MAE=0.0392
# ✅ # Steps: 9; e_form: P=-0.4256, GT=-0.4335, Δ=0.0079, MAE=0.0392
# ❌ # Steps: 25; e_form: P=-0.1730, GT=-0.2764, Δ=0.1035, MAE=0.0393
# ✅ # Steps: 8; e_form: P=-0.5192, GT=-0.5027, Δ=0.0165, MAE=0.0393
# ✅ # Steps: 17; e_form: P=-0.0654, GT=-0.1192, Δ=0.0538, MAE=0.0393
# ✅ # Steps: 18; e_form: P=-0.1049, GT=-0.1472, Δ=0.0423, MAE=0.0393
# ✅ # Steps: 14; e_form: P=0.2501, GT=0.2683, Δ=0.0182, MAE=0.0393
# ✅ # Steps: 27; e_form: P=0.2987, GT=0.3220, Δ=0.0233, MAE=0.0392
# ✅ # Steps: 2; e_form: P=0.1338, GT=0.1714, Δ=0.0376, MAE=0.0392
# ✅ # Steps: 6; e_form: P=-0.5544, GT=-0.5366, Δ=0.0178, MAE=0.0392
# ✅ # Steps: 11; e_form: P=-0.3273, GT=-0.3268, Δ=0.0005, MAE=0.0391
# ✅ # Steps: 26; e_form: P=-0.0083, GT=-0.0240, Δ=0.0156, MAE=0.0391
# ✅ # Steps: 11; e_form: P=-0.9107, GT=-0.8487, Δ=0.0620, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-1.5062, GT=-1.4929, Δ=0.0132, MAE=0.0391
# ✅ # Steps: 21; e_form: P=-0.6155, GT=-0.6123, Δ=0.0032, MAE=0.0391
# ✅ # Steps: 12; e_form: P=-0.5086, GT=-0.4887, Δ=0.0200, MAE=0.0390
# ✅ # Steps: 11; e_form: P=-0.2542, GT=-0.2442, Δ=0.0100, MAE=0.0390
# ✅ # Steps: 17; e_form: P=-1.2844, GT=-1.2903, Δ=0.0059, MAE=0.0389
# ❌ # Steps: 5; e_form: P=-0.5301, GT=-0.4280, Δ=0.1021, MAE=0.0390
# ✅ # Steps: 10; e_form: P=-2.8482, GT=-2.8920, Δ=0.0438, MAE=0.0390
# ✅ # Steps: 27; e_form: P=-0.1414, GT=-0.1126, Δ=0.0288, MAE=0.0390
# ✅ # Steps: 5; e_form: P=-0.1080, GT=-0.0421, Δ=0.0659, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-0.2887, GT=-0.3080, Δ=0.0193, MAE=0.0390
# ✅ # Steps: 15; e_form: P=-1.2510, GT=-1.2067, Δ=0.0443, MAE=0.0390
# ✅ # Steps: 22; e_form: P=-0.9387, GT=-0.9616, Δ=0.0229, MAE=0.0390
# ✅ # Steps: 11; e_form: P=-0.1602, GT=-0.1473, Δ=0.0129, MAE=0.0390
# ✅ # Steps: 10; e_form: P=0.2410, GT=0.3355, Δ=0.0946, MAE=0.0391
# ✅ # Steps: 23; e_form: P=-0.1059, GT=-0.1085, Δ=0.0025, MAE=0.0390
# ✅ # Steps: 34; e_form: P=-0.2346, GT=-0.2000, Δ=0.0346, MAE=0.0390
# ✅ # Steps: 25; e_form: P=-0.5982, GT=-0.5517, Δ=0.0465, MAE=0.0390
# ✅ # Steps: 22; e_form: P=-1.3925, GT=-1.4016, Δ=0.0091, MAE=0.0390
# ✅ # Steps: 13; e_form: P=-2.9302, GT=-2.9439, Δ=0.0137, MAE=0.0389
# ✅ # Steps: 13; e_form: P=-0.3050, GT=-0.2810, Δ=0.0240, MAE=0.0389
# ✅ # Steps: 13; e_form: P=-0.8844, GT=-0.8819, Δ=0.0024, MAE=0.0389
# ...
# ✅ # Steps: 21; e_form: P=-3.1990, GT=-3.1862, Δ=0.0128, MAE=0.0385
# ✅ # Steps: 20; e_form: P=-0.2155, GT=-0.2866, Δ=0.0711, MAE=0.0386
# ✅ # Steps: 55; e_form: P=-1.3635, GT=-1.3867, Δ=0.0233, MAE=0.0386
# ✅ # Steps: 19; e_form: P=-0.3899, GT=-0.4225, Δ=0.0326, MAE=0.0386
# ✅ # Steps: 2; e_form: P=0.3610, GT=0.4565, Δ=0.0956, MAE=0.0386
# ❌ # Steps: 16; e_form: P=-0.7639, GT=-0.6213, Δ=0.1427, MAE=0.0388
# ✅ # Steps: 24; e_form: P=-3.1852, GT=-3.1831, Δ=0.0021, MAE=0.0387
# ❌ # Steps: 25; e_form: P=-0.9255, GT=-1.0546, Δ=0.1291, MAE=0.0388
# ✅ # Steps: 34; e_form: P=-1.3556, GT=-1.3246, Δ=0.0310, MAE=0.0388
# ✅ # Steps: 4; e_form: P=-0.2670, GT=-0.2372, Δ=0.0298, MAE=0.0388
# ✅ # Steps: 13; e_form: P=-0.4996, GT=-0.4839, Δ=0.0157, MAE=0.0388
# ❌ # Steps: 16; e_form: P=-0.3320, GT=0.2772, Δ=0.6092, MAE=0.0395
# ✅ # Steps: 30; e_form: P=-1.6469, GT=-1.6499, Δ=0.0030, MAE=0.0394
# ✅ # Steps: 2; e_form: P=-2.8564, GT=-2.8493, Δ=0.0072, MAE=0.0394
# ✅ # Steps: 11; e_form: P=-0.1889, GT=-0.2488, Δ=0.0599, MAE=0.0394
# ✅ # Steps: 13; e_form: P=0.5698, GT=0.6009, Δ=0.0311, MAE=0.0394
# ✅ # Steps: 5; e_form: P=-0.6988, GT=-0.6159, Δ=0.0829, MAE=0.0395
# ✅ # Steps: 2; e_form: P=-0.3390, GT=-0.3659, Δ=0.0269, MAE=0.0395
# ✅ # Steps: 29; e_form: P=-0.3728, GT=-0.3843, Δ=0.0115, MAE=0.0394
# ✅ # Steps: 17; e_form: P=0.1098, GT=0.0889, Δ=0.0209, MAE=0.0394
# ✅ # Steps: 9; e_form: P=-1.8532, GT=-1.8723, Δ=0.0190, MAE=0.0394
# ✅ # Steps: 13; e_form: P=-0.3550, GT=-0.3532, Δ=0.0018, MAE=0.0393
# ✅ # Steps: 4; e_form: P=-0.6074, GT=-0.6330, Δ=0.0257, MAE=0.0393
# ✅ # Steps: 27; e_form: P=-0.4047, GT=-0.3911, Δ=0.0136, MAE=0.0393
# ✅ # Steps: 19; e_form: P=-0.4073, GT=-0.4051, Δ=0.0022, MAE=0.0392
# ✅ # Steps: 9; e_form: P=-0.5722, GT=-0.5440, Δ=0.0282, MAE=0.0392
# ✅ # Steps: 27; e_form: P=-0.5624, GT=-0.5438, Δ=0.0186, MAE=0.0392
# ✅ # Steps: 12; e_form: P=-0.0039, GT=-0.0096, Δ=0.0056, MAE=0.0392
# ❌ # Steps: 46; e_form: P=-0.2645, GT=0.2142, Δ=0.4786, MAE=0.0397
# ✅ # Steps: 25; e_form: P=-1.9992, GT=-2.0031, Δ=0.0039, MAE=0.0397
# ✅ # Steps: 4; e_form: P=-0.7365, GT=-0.7304, Δ=0.0061, MAE=0.0396
# ✅ # Steps: 5; e_form: P=-1.1675, GT=-1.1156, Δ=0.0519, MAE=0.0396
# ✅ # Steps: 2; e_form: P=-0.2614, GT=-0.2183, Δ=0.0430, MAE=0.0396
# ✅ # Steps: 7; e_form: P=-0.9691, GT=-0.9451, Δ=0.0240, MAE=0.0396
# ✅ # Steps: 9; e_form: P=0.0385, GT=-0.0231, Δ=0.0616, MAE=0.0396
# ✅ # Steps: 10; e_form: P=-2.7498, GT=-2.7057, Δ=0.0441, MAE=0.0396
# ✅ # Steps: 18; e_form: P=-1.8168, GT=-1.8360, Δ=0.0192, MAE=0.0396
# ✅ # Steps: 9; e_form: P=-0.7188, GT=-0.7217, Δ=0.0029, MAE=0.0396
# ✅ # Steps: 9; e_form: P=-0.8411, GT=-0.8502, Δ=0.0090, MAE=0.0395
# ✅ # Steps: 10; e_form: P=-0.3133, GT=-0.3399, Δ=0.0266, MAE=0.0395
# ✅ # Steps: 2; e_form: P=-0.3823, GT=-0.3750, Δ=0.0073, MAE=0.0395
# ✅ # Steps: 11; e_form: P=-0.3173, GT=-0.2399, Δ=0.0774, MAE=0.0395
# ✅ # Steps: 9; e_form: P=-1.3544, GT=-1.3328, Δ=0.0215, MAE=0.0395
# ✅ # Steps: 154; e_form: P=-1.9417, GT=-1.9224, Δ=0.0193, MAE=0.0395
# ✅ # Steps: 2; e_form: P=-0.0557, GT=-0.0991, Δ=0.0434, MAE=0.0395
# ✅ # Steps: 5; e_form: P=-0.0744, GT=-0.1183, Δ=0.0439, MAE=0.0395
# ✅ # Steps: 11; e_form: P=-0.9610, GT=-0.9094, Δ=0.0516, MAE=0.0395
# ✅ # Steps: 8; e_form: P=-0.6597, GT=-0.6700, Δ=0.0103, MAE=0.0395
# ❌ # Steps: 19; e_form: P=-0.8174, GT=-0.9185, Δ=0.1011, MAE=0.0395
# ✅ # Steps: 12; e_form: P=0.0364, GT=0.0350, Δ=0.0014, MAE=0.0395
# ✅ # Steps: 23; e_form: P=-0.2833, GT=-0.2688, Δ=0.0145, MAE=0.0395
# ✅ # Steps: 30; e_form: P=-0.8001, GT=-0.8164, Δ=0.0163, MAE=0.0394
# ✅ # Steps: 6; e_form: P=-0.7356, GT=-0.7028, Δ=0.0329, MAE=0.0394
# ❌ # Steps: 25; e_form: P=0.2497, GT=0.1311, Δ=0.1185, MAE=0.0395
# ✅ # Steps: 22; e_form: P=-1.9617, GT=-1.9579, Δ=0.0038, MAE=0.0395
# ✅ # Steps: 5; e_form: P=0.1816, GT=0.2206, Δ=0.0390, MAE=0.0395
# ✅ # Steps: 17; e_form: P=-0.1626, GT=-0.1935, Δ=0.0309, MAE=0.0395
# ✅ # Steps: 4; e_form: P=-0.5176, GT=-0.4953, Δ=0.0223, MAE=0.0395
# ✅ # Steps: 17; e_form: P=0.3815, GT=0.3963, Δ=0.0148, MAE=0.0394
# ✅ # Steps: 11; e_form: P=0.0081, GT=0.0346, Δ=0.0265, MAE=0.0394
# ✅ # Steps: 13; e_form: P=-0.4711, GT=-0.5234, Δ=0.0523, MAE=0.0394
# ✅ # Steps: 14; e_form: P=-0.0991, GT=-0.0768, Δ=0.0224, MAE=0.0394
# ✅ # Steps: 5; e_form: P=-1.1295, GT=-1.1193, Δ=0.0101, MAE=0.0394
# ✅ # Steps: 2; e_form: P=-0.4478, GT=-0.4398, Δ=0.0080, MAE=0.0393
# ✅ # Steps: 17; e_form: P=-0.3775, GT=-0.3507, Δ=0.0268, MAE=0.0393
# ✅ # Steps: 12; e_form: P=-0.2346, GT=-0.1553, Δ=0.0793, MAE=0.0394
# ✅ # Steps: 30; e_form: P=-0.2314, GT=-0.2488, Δ=0.0173, MAE=0.0393
# ✅ # Steps: 10; e_form: P=-0.3850, GT=-0.3663, Δ=0.0187, MAE=0.0393
# ✅ # Steps: 25; e_form: P=-0.9759, GT=-0.9867, Δ=0.0108, MAE=0.0393
# ✅ # Steps: 21; e_form: P=-0.9286, GT=-0.9557, Δ=0.0271, MAE=0.0393
# ✅ # Steps: 7; e_form: P=0.3049, GT=0.2244, Δ=0.0805, MAE=0.0393
# ✅ # Steps: 2; e_form: P=-0.5715, GT=-0.5315, Δ=0.0400, MAE=0.0393
# ✅ # Steps: 32; e_form: P=-2.3937, GT=-2.3817, Δ=0.0120, MAE=0.0393
# ✅ # Steps: 27; e_form: P=-0.1698, GT=-0.1975, Δ=0.0278, MAE=0.0393
# ✅ # Steps: 23; e_form: P=-2.9993, GT=-3.0125, Δ=0.0131, MAE=0.0392
# ✅ # Steps: 9; e_form: P=-0.3682, GT=-0.4093, Δ=0.0411, MAE=0.0392
# ❌ # Steps: 21; e_form: P=-0.2458, GT=-0.1265, Δ=0.1193, MAE=0.0393
# ✅ # Steps: 2; e_form: P=0.1450, GT=0.1554, Δ=0.0104, MAE=0.0393
# ✅ # Steps: 41; e_form: P=-2.4374, GT=-2.4323, Δ=0.0051, MAE=0.0393
# ✅ # Steps: 20; e_form: P=-0.7165, GT=-0.7125, Δ=0.0040, MAE=0.0392
# ✅ # Steps: 18; e_form: P=-0.2228, GT=-0.1733, Δ=0.0495, MAE=0.0392
# ✅ # Steps: 11; e_form: P=-0.6780, GT=-0.6863, Δ=0.0082, MAE=0.0392
# ✅ # Steps: 9; e_form: P=0.0093, GT=0.0148, Δ=0.0055, MAE=0.0392
# ✅ # Steps: 23; e_form: P=-0.7992, GT=-0.8141, Δ=0.0149, MAE=0.0391
# ✅ # Steps: 28; e_form: P=-0.6596, GT=-0.6141, Δ=0.0455, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-2.3632, GT=-2.3448, Δ=0.0184, MAE=0.0391
# ✅ # Steps: 6; e_form: P=-0.0610, GT=-0.0540, Δ=0.0069, MAE=0.0391
# ✅ # Steps: 38; e_form: P=-0.6280, GT=-0.6281, Δ=0.0001, MAE=0.0390
# ✅ # Steps: 10; e_form: P=0.0896, GT=0.0599, Δ=0.0296, MAE=0.0390
# ✅ # Steps: 17; e_form: P=-0.2818, GT=-0.3221, Δ=0.0404, MAE=0.0390
# ✅ # Steps: 19; e_form: P=-1.8532, GT=-1.8482, Δ=0.0051, MAE=0.0390
# ❌ # Steps: 35; e_form: P=-2.9299, GT=-3.0579, Δ=0.1280, MAE=0.0391
# ✅ # Steps: 18; e_form: P=-0.9419, GT=-0.8600, Δ=0.0819, MAE=0.0391
# ✅ # Steps: 7; e_form: P=-0.8772, GT=-0.8548, Δ=0.0224, MAE=0.0391
# ✅ # Steps: 7; e_form: P=-0.6164, GT=-0.6173, Δ=0.0009, MAE=0.0391
# ✅ # Steps: 46; e_form: P=-0.0833, GT=-0.1066, Δ=0.0233, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-0.3647, GT=-0.3295, Δ=0.0352, MAE=0.0391
# ✅ # Steps: 5; e_form: P=-0.1948, GT=-0.1909, Δ=0.0039, MAE=0.0390
# ✅ # Steps: 9; e_form: P=-0.4840, GT=-0.4347, Δ=0.0493, MAE=0.0390
# ✅ # Steps: 7; e_form: P=0.9801, GT=0.9515, Δ=0.0286, MAE=0.0390
# ✅ # Steps: 6; e_form: P=-0.0847, GT=-0.0428, Δ=0.0418, MAE=0.0390
# ✅ # Steps: 24; e_form: P=-0.7706, GT=-0.7797, Δ=0.0091, MAE=0.0390
# ✅ # Steps: 5; e_form: P=-3.1448, GT=-3.1435, Δ=0.0013, MAE=0.0389
# ✅ # Steps: 12; e_form: P=-0.2696, GT=-0.2275, Δ=0.0421, MAE=0.0389
# ✅ # Steps: 7; e_form: P=0.2973, GT=0.3174, Δ=0.0201, MAE=0.0389
# ✅ # Steps: 20; e_form: P=-1.0059, GT=-0.9936, Δ=0.0123, MAE=0.0389
# ✅ # Steps: 29; e_form: P=-0.1642, GT=-0.1483, Δ=0.0158, MAE=0.0389
# ❌ # Steps: 26; e_form: P=-1.9947, GT=-1.7992, Δ=0.1955, MAE=0.0390
# ✅ # Steps: 38; e_form: P=-3.0982, GT=-3.0938, Δ=0.0044, MAE=0.0390
# ✅ # Steps: 7; e_form: P=-1.5516, GT=-1.5511, Δ=0.0005, MAE=0.0390
# ✅ # Steps: 14; e_form: P=-3.5869, GT=-3.6437, Δ=0.0568, MAE=0.0390
# ✅ # Steps: 19; e_form: P=-0.5850, GT=-0.5637, Δ=0.0213, MAE=0.0390
# ❌ # Steps: 2; e_form: P=0.3484, GT=0.5587, Δ=0.2104, MAE=0.0392
# ✅ # Steps: 7; e_form: P=-0.2470, GT=-0.1957, Δ=0.0513, MAE=0.0392
# ✅ # Steps: 5; e_form: P=-0.2405, GT=-0.2136, Δ=0.0269, MAE=0.0392
# ✅ # Steps: 5; e_form: P=-0.7323, GT=-0.6731, Δ=0.0591, MAE=0.0392
# ✅ # Steps: 5; e_form: P=-0.9584, GT=-0.8935, Δ=0.0649, MAE=0.0392
# ❌ # Steps: 17; e_form: P=0.0976, GT=0.2243, Δ=0.1267, MAE=0.0393
# ✅ # Steps: 7; e_form: P=0.1213, GT=0.0935, Δ=0.0278, MAE=0.0393
# ✅ # Steps: 13; e_form: P=-2.2808, GT=-2.2954, Δ=0.0146, MAE=0.0393
# ✅ # Steps: 7; e_form: P=-0.7008, GT=-0.6817, Δ=0.0191, MAE=0.0392
# ✅ # Steps: 49; e_form: P=-0.3302, GT=-0.3647, Δ=0.0345, MAE=0.0392
# ✅ # Steps: 14; e_form: P=0.0394, GT=0.0453, Δ=0.0059, MAE=0.0392
# ✅ # Steps: 10; e_form: P=-2.5952, GT=-2.6104, Δ=0.0152, MAE=0.0392
# ✅ # Steps: 6; e_form: P=-0.2672, GT=-0.2549, Δ=0.0123, MAE=0.0391
# ✅ # Steps: 19; e_form: P=-0.1955, GT=-0.1989, Δ=0.0034, MAE=0.0391
# ✅ # Steps: 11; e_form: P=0.4891, GT=0.4712, Δ=0.0179, MAE=0.0391
# ✅ # Steps: 34; e_form: P=-0.0260, GT=-0.0030, Δ=0.0230, MAE=0.0391
# ✅ # Steps: 9; e_form: P=-0.2478, GT=-0.2702, Δ=0.0225, MAE=0.0390
# ✅ # Steps: 19; e_form: P=-0.5408, GT=-0.5372, Δ=0.0037, MAE=0.0390
# ✅ # Steps: 6; e_form: P=-0.0698, GT=-0.0457, Δ=0.0240, MAE=0.0390
# ✅ # Steps: 16; e_form: P=-0.5261, GT=-0.5335, Δ=0.0074, MAE=0.0390
# ✅ # Steps: 38; e_form: P=0.0741, GT=0.1201, Δ=0.0461, MAE=0.0390
# ✅ # Steps: 19; e_form: P=-1.1136, GT=-1.0874, Δ=0.0262, MAE=0.0389
# ✅ # Steps: 36; e_form: P=-2.7735, GT=-2.7770, Δ=0.0035, MAE=0.0389
# ✅ # Steps: 4; e_form: P=-1.0785, GT=-1.1048, Δ=0.0263, MAE=0.0389
# ✅ # Steps: 32; e_form: P=-0.3658, GT=-0.3743, Δ=0.0085, MAE=0.0389
# ✅ # Steps: 15; e_form: P=-0.0022, GT=0.0363, Δ=0.0385, MAE=0.0389
# ✅ # Steps: 18; e_form: P=-0.3961, GT=-0.3760, Δ=0.0201, MAE=0.0388
# ✅ # Steps: 28; e_form: P=-0.9342, GT=-0.9046, Δ=0.0296, MAE=0.0388
# ✅ # Steps: 16; e_form: P=-0.3869, GT=-0.3541, Δ=0.0329, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-0.9144, GT=-0.9104, Δ=0.0040, MAE=0.0388
# ✅ # Steps: 36; e_form: P=-0.3297, GT=-0.3113, Δ=0.0184, MAE=0.0388
# ✅ # Steps: 7; e_form: P=0.0319, GT=0.0566, Δ=0.0247, MAE=0.0387
# ✅ # Steps: 8; e_form: P=-0.6424, GT=-0.5667, Δ=0.0757, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-1.6312, GT=-1.5421, Δ=0.0891, MAE=0.0388
# ✅ # Steps: 11; e_form: P=-0.4368, GT=-0.4317, Δ=0.0051, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-0.1880, GT=-0.1564, Δ=0.0316, MAE=0.0388
# ✅ # Steps: 14; e_form: P=-2.1612, GT=-2.1111, Δ=0.0500, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-0.1461, GT=-0.0939, Δ=0.0522, MAE=0.0388
# ✅ # Steps: 30; e_form: P=-2.7854, GT=-2.7974, Δ=0.0119, MAE=0.0388
# ✅ # Steps: 10; e_form: P=-0.5586, GT=-0.5827, Δ=0.0241, MAE=0.0388
# ✅ # Steps: 4; e_form: P=-3.3331, GT=-3.4296, Δ=0.0965, MAE=0.0388
# ✅ # Steps: 9; e_form: P=-0.3428, GT=-0.3281, Δ=0.0148, MAE=0.0388
# ✅ # Steps: 4; e_form: P=-0.3859, GT=-0.3999, Δ=0.0140, MAE=0.0388
# ✅ # Steps: 12; e_form: P=-0.2643, GT=-0.2261, Δ=0.0382, MAE=0.0388
# ✅ # Steps: 6; e_form: P=0.0065, GT=-0.0728, Δ=0.0793, MAE=0.0388
# ✅ # Steps: 11; e_form: P=0.0168, GT=0.0085, Δ=0.0082, MAE=0.0388
# ✅ # Steps: 28; e_form: P=-0.6332, GT=-0.5824, Δ=0.0509, MAE=0.0388
# ✅ # Steps: 7; e_form: P=-0.0258, GT=-0.0091, Δ=0.0167, MAE=0.0388
# ✅ # Steps: 8; e_form: P=-0.0780, GT=-0.0442, Δ=0.0339, MAE=0.0388
# ✅ # Steps: 24; e_form: P=-2.8297, GT=-2.8235, Δ=0.0062, MAE=0.0387
# ✅ # Steps: 7; e_form: P=-1.9114, GT=-1.9013, Δ=0.0101, MAE=0.0387
# ✅ # Steps: 31; e_form: P=-0.0956, GT=-0.0475, Δ=0.0481, MAE=0.0387
# ✅ # Steps: 28; e_form: P=-1.1907, GT=-1.2078, Δ=0.0171, MAE=0.0387
# ✅ # Steps: 13; e_form: P=-0.1626, GT=-0.1637, Δ=0.0010, MAE=0.0387
# ✅ # Steps: 10; e_form: P=-0.6120, GT=-0.5761, Δ=0.0359, MAE=0.0387
# ✅ # Steps: 2; e_form: P=0.1571, GT=0.1568, Δ=0.0003, MAE=0.0386
# ✅ # Steps: 23; e_form: P=-0.3030, GT=-0.3436, Δ=0.0406, MAE=0.0386
# ✅ # Steps: 20; e_form: P=-0.3022, GT=-0.3194, Δ=0.0172, MAE=0.0386
# ✅ # Steps: 2; e_form: P=-1.5795, GT=-1.5818, Δ=0.0023, MAE=0.0386
# ❌ # Steps: 2; e_form: P=0.3405, GT=0.5770, Δ=0.2365, MAE=0.0388
# ✅ # Steps: 36; e_form: P=-0.2216, GT=-0.2169, Δ=0.0046, MAE=0.0387
# ❌ # Steps: 100; e_form: P=-1.9326, GT=-1.8275, Δ=0.1051, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-0.2722, GT=-0.2535, Δ=0.0187, MAE=0.0388
# ✅ # Steps: 2; e_form: P=-2.7530, GT=-2.7607, Δ=0.0076, MAE=0.0388
# ✅ # Steps: 14; e_form: P=-0.3760, GT=-0.3948, Δ=0.0188, MAE=0.0387
# ✅ # Steps: 10; e_form: P=-0.1922, GT=-0.1468, Δ=0.0454, MAE=0.0387
# ✅ # Steps: 2; e_form: P=-0.1832, GT=-0.1065, Δ=0.0766, MAE=0.0388
# ✅ # Steps: 26; e_form: P=-1.1912, GT=-1.1210, Δ=0.0702, MAE=0.0388
# ✅ # Steps: 6; e_form: P=-0.3571, GT=-0.2676, Δ=0.0895, MAE=0.0389
# ✅ # Steps: 22; e_form: P=-0.5630, GT=-0.5560, Δ=0.0070, MAE=0.0388
# ✅ # Steps: 33; e_form: P=-0.6489, GT=-0.5960, Δ=0.0529, MAE=0.0388
# ✅ # Steps: 5; e_form: P=-0.3868, GT=-0.3718, Δ=0.0150, MAE=0.0388
# ✅ # Steps: 20; e_form: P=-2.0181, GT=-2.0274, Δ=0.0093, MAE=0.0388
# ✅ # Steps: 37; e_form: P=-0.2649, GT=-0.2564, Δ=0.0085, MAE=0.0388
# ✅ # Steps: 20; e_form: P=-0.2670, GT=-0.2337, Δ=0.0333, MAE=0.0388
# ✅ # Steps: 31; e_form: P=-3.4772, GT=-3.4785, Δ=0.0013, MAE=0.0387
# ✅ # Steps: 7; e_form: P=-3.0483, GT=-3.0074, Δ=0.0409, MAE=0.0387
# ✅ # Steps: 13; e_form: P=-0.2376, GT=-0.2525, Δ=0.0150, MAE=0.0387
# ✅ # Steps: 30; e_form: P=-0.2991, GT=-0.2939, Δ=0.0052, MAE=0.0387
# ✅ # Steps: 16; e_form: P=-0.7472, GT=-0.7279, Δ=0.0194, MAE=0.0386
# ✅ # Steps: 20; e_form: P=-0.4403, GT=-0.4437, Δ=0.0034, MAE=0.0386
# ✅ # Steps: 13; e_form: P=-0.2019, GT=-0.1949, Δ=0.0070, MAE=0.0386
# ✅ # Steps: 22; e_form: P=-0.8053, GT=-0.7958, Δ=0.0094, MAE=0.0385
# ✅ # Steps: 10; e_form: P=-0.4014, GT=-0.3861, Δ=0.0153, MAE=0.0385
# ✅ # Steps: 5; e_form: P=-0.0779, GT=0.0020, Δ=0.0799, MAE=0.0386
# ✅ # Steps: 18; e_form: P=-2.4440, GT=-2.4231, Δ=0.0209, MAE=0.0385
# ✅ # Steps: 28; e_form: P=-2.4052, GT=-2.3923, Δ=0.0128, MAE=0.0385
# ✅ # Steps: 10; e_form: P=-3.3256, GT=-3.3838, Δ=0.0582, MAE=0.0385
# ✅ # Steps: 12; e_form: P=-0.0985, GT=-0.1283, Δ=0.0297, MAE=0.0385
# ✅ # Steps: 14; e_form: P=-0.5663, GT=-0.5110, Δ=0.0553, MAE=0.0385
# ✅ # Steps: 13; e_form: P=-0.6194, GT=-0.6149, Δ=0.0045, MAE=0.0385
# ✅ # Steps: 5; e_form: P=-0.2681, GT=-0.2405, Δ=0.0276, MAE=0.0385
# ✅ # Steps: 27; e_form: P=-0.3044, GT=-0.3139, Δ=0.0095, MAE=0.0385
# ✅ # Steps: 2; e_form: P=-0.4878, GT=-0.4718, Δ=0.0160, MAE=0.0384
# ❌ # Steps: 5; e_form: P=-1.6682, GT=-1.5122, Δ=0.1560, MAE=0.0386
# ✅ # Steps: 5; e_form: P=-0.2939, GT=-0.2475, Δ=0.0464, MAE=0.0386
# ✅ # Steps: 20; e_form: P=-2.9193, GT=-2.9445, Δ=0.0251, MAE=0.0386
# ✅ # Steps: 10; e_form: P=-0.5896, GT=-0.5732, Δ=0.0164, MAE=0.0385
# ✅ # Steps: 31; e_form: P=-1.1228, GT=-1.1198, Δ=0.0030, MAE=0.0385
# ✅ # Steps: 44; e_form: P=-0.9062, GT=-0.9185, Δ=0.0122, MAE=0.0385
# ❌ # Steps: 5; e_form: P=-0.2377, GT=-0.4203, Δ=0.1826, MAE=0.0386
# ✅ # Steps: 28; e_form: P=-0.7282, GT=-0.7145, Δ=0.0137, MAE=0.0386
# ✅ # Steps: 5; e_form: P=-0.8446, GT=-0.8450, Δ=0.0003, MAE=0.0386
# ❌ # Steps: 20; e_form: P=-0.2437, GT=-0.0715, Δ=0.1722, MAE=0.0387
# ✅ # Steps: 10; e_form: P=-1.1287, GT=-1.0688, Δ=0.0598, MAE=0.0387
# ✅ # Steps: 5; e_form: P=-0.3474, GT=-0.2747, Δ=0.0727, MAE=0.0387
# ❌ # Steps: 5; e_form: P=0.1970, GT=0.3054, Δ=0.1085, MAE=0.0388
# ✅ # Steps: 11; e_form: P=-0.8510, GT=-0.7781, Δ=0.0729, MAE=0.0388
# ✅ # Steps: 20; e_form: P=-0.4841, GT=-0.4802, Δ=0.0039, MAE=0.0388
# ✅ # Steps: 18; e_form: P=-0.1867, GT=-0.1610, Δ=0.0256, MAE=0.0388
# ✅ # Steps: 6; e_form: P=-0.1452, GT=-0.1797, Δ=0.0345, MAE=0.0388
# ✅ # Steps: 2; e_form: P=-1.3939, GT=-1.4017, Δ=0.0078, MAE=0.0388
# ✅ # Steps: 15; e_form: P=-0.3084, GT=-0.2996, Δ=0.0088, MAE=0.0387
# ✅ # Steps: 28; e_form: P=-2.8187, GT=-2.8112, Δ=0.0075, MAE=0.0387
# ✅ # Steps: 15; e_form: P=-3.6141, GT=-3.6233, Δ=0.0092, MAE=0.0387
# ✅ # Steps: 28; e_form: P=-0.6531, GT=-0.6740, Δ=0.0209, MAE=0.0387
# ✅ # Steps: 8; e_form: P=-0.4420, GT=-0.4104, Δ=0.0316, MAE=0.0386
# ✅ # Steps: 6; e_form: P=-0.0748, GT=-0.0330, Δ=0.0418, MAE=0.0387
# ✅ # Steps: 30; e_form: P=-2.4997, GT=-2.5160, Δ=0.0163, MAE=0.0386
# ✅ # Steps: 12; e_form: P=-3.3906, GT=-3.4413, Δ=0.0508, MAE=0.0386
# ✅ # Steps: 6; e_form: P=-0.1143, GT=-0.1190, Δ=0.0047, MAE=0.0386
# ✅ # Steps: 21; e_form: P=-0.3167, GT=-0.2882, Δ=0.0285, MAE=0.0386
# ✅ # Steps: 6; e_form: P=-1.5930, GT=-1.6352, Δ=0.0422, MAE=0.0386
# ✅ # Steps: 5; e_form: P=-0.1179, GT=-0.0945, Δ=0.0234, MAE=0.0386
# ✅ # Steps: 16; e_form: P=0.3009, GT=0.2147, Δ=0.0862, MAE=0.0386
# ✅ # Steps: 31; e_form: P=-2.2656, GT=-2.2732, Δ=0.0077, MAE=0.0386
# ❌ # Steps: 11; e_form: P=-0.5246, GT=-0.2774, Δ=0.2472, MAE=0.0388
# ✅ # Steps: 8; e_form: P=-0.2109, GT=-0.1887, Δ=0.0222, MAE=0.0388
# ✅ # Steps: 28; e_form: P=-2.0987, GT=-2.1022, Δ=0.0035, MAE=0.0388

# %%
import ase
import ase.visualize
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set_theme()


class UpdatedProblematicSample(TypedDict):
    error: float
    initial_data: Batch
    relaxed_data: Batch
    relax_out: RelaxationOutput

    s2e_energies: list[float]
    s2re_energies: list[float]


def _update_sample(sample: ProblematicSample) -> UpdatedProblematicSample:
    relax_out = sample["relax_out"]

    initial_data = move_data_to_device(
        copy.deepcopy(sample["initial_data"]), model.device
    )
    data = move_data_to_device(copy.deepcopy(sample["initial_data"]), model.device)

    s2e_energies = []
    s2re_energies = []
    for f in tqdm(relax_out.trajectory.frames):
        data.pos = f.pos.type_as(data.pos).reshape_as(data.pos).to(data.pos.device)
        data.cell = f.cell.type_as(data.cell).reshape_as(data.cell).to(data.cell.device)

        out = model_fn(data, initial_data, use_y_relaxed=True)
        # yield out["energy"].item()
        s2e_energies.append(out["current_energy"].item())
        s2re_energies.append(out["relaxed_energy"].item())

    return {**sample, "s2e_energies": s2e_energies, "s2re_energies": s2re_energies}


def plot_energy_vs_steps(sample: UpdatedProblematicSample, ax: plt.Axes | None = None):
    initial_data = sample["initial_data"]

    e_form_true = initial_data.y_formation.item()

    if ax is None:
        _, ax = plt.subplots()
    ax.plot(sample["s2e_energies"], label="S2E Pred")
    ax.plot(sample["s2re_energies"], label="S2RE Pred")
    ax.axhline(y=e_form_true, color="r", linestyle="--", label="True")

    ax.set_xlabel("Step")
    ax.set_ylabel("Formation Energy")
    ax.legend()

    return ax


def plot_initial_structure(sample: ProblematicSample):
    initial_data = sample["initial_data"]
    atoms = ase.Atoms(
        numbers=initial_data.atomic_numbers.cpu().numpy(),
        positions=initial_data.pos.cpu().numpy(),
        cell=initial_data.cell.cpu().squeeze(0).numpy(),
        pbc=[True, True, True],
    )

    return ase.visualize.view(atoms, viewer="ngl")


def plot_trajectory(sample: ProblematicSample):
    initial_data = move_data_to_device(copy.deepcopy(sample["initial_data"]), "cpu")
    atoms_list = [
        ase.Atoms(
            numbers=initial_data.atomic_numbers.cpu().numpy(),
            positions=f.pos.cpu().numpy(),
            cell=f.cell.cpu().squeeze(0).numpy(),
            pbc=[True, True, True],
        )
        for f in sample["relax_out"].trajectory.frames
    ]

    return ase.visualize.view(atoms_list, viewer="ngl")


def debug_system(idx: int, figsize: tuple[int, int] = (3, 2)):
    sample = problematic_samples[idx]
    updated_sample = _update_sample(sample)

    # display(plot_initial_structure(updated_sample))
    display(plot_trajectory(updated_sample))

    fig, ax = plt.subplots(figsize=figsize)
    plot_energy_vs_steps(updated_sample, ax=ax)
    plt.show()

# %%
max_error_idx = np.argmax([s["error"] for s in problematic_samples])
print(
    f"Max error index: {max_error_idx}, error: {problematic_samples[max_error_idx]['error']}"
)
debug_system(max_error_idx)
# Out:
# Max error index: 47, error: 0.6903281807899475
#   0%|          | 0/9 [00:00<?, ?it/s]
# HBox(children=(NGLWidget(max_frame=8), VBox(children=(Dropdown(description='Show', options=('All', 'Tl', 'Pu')…

# %%
idx = 10
max_error_idx = np.argsort([s["error"] for s in problematic_samples])[-idx]
print(f"index: {max_error_idx}, error: {problematic_samples[max_error_idx]['error']}")
debug_system(max_error_idx)
# Out:
# index: 6, error: 0.27349376678466797
#   0%|          | 0/21 [00:00<?, ?it/s]
# HBox(children=(NGLWidget(max_frame=20), VBox(children=(Dropdown(description='Show', options=('All', 'K', 'Zn',…

# %%
idx = 12
max_error_idx = np.argsort([s["error"] for s in problematic_samples])[-idx]
print(f"index: {max_error_idx}, error: {problematic_samples[max_error_idx]['error']}")
debug_system(max_error_idx)
# Out:
# index: 25, error: 0.25337085127830505
#   0%|          | 0/7 [00:00<?, ?it/s]
# HBox(children=(NGLWidget(max_frame=6), VBox(children=(Dropdown(description='Show', options=('All', 'Mn', 'Er',…

# %%
# Sort by error
problematic_samples_sorted = sorted(
    problematic_samples,
    key=lambda x: len(x["relax_out"].trajectory.frames),
    reverse=True,
)
for i, sample in enumerate(problematic_samples_sorted):
    print(
        f"Index: {i}, Error: {sample['error']:.4f}, # Steps: {len(sample['relax_out'].trajectory.frames)}"
    )
    display(plot_trajectory(sample))

    if i == 10:
        break
# Out:
# Index: 0, Error: 0.1051, # Steps: 100
# HBox(children=(NGLWidget(max_frame=99), VBox(children=(Dropdown(description='Show', options=('All', 'Br', 'Tm'…
# Index: 1, Error: 0.4876, # Steps: 74
# HBox(children=(NGLWidget(max_frame=73), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'Cl',…
# Index: 2, Error: 0.1577, # Steps: 56
# HBox(children=(NGLWidget(max_frame=55), VBox(children=(Dropdown(description='Show', options=('All', 'Rh', 'Zn'…
# Index: 3, Error: 0.1705, # Steps: 50
# HBox(children=(NGLWidget(max_frame=49), VBox(children=(Dropdown(description='Show', options=('All', 'Sb', 'Ti'…
# Index: 4, Error: 0.1532, # Steps: 47
# HBox(children=(NGLWidget(max_frame=46), VBox(children=(Dropdown(description='Show', options=('All', 'S', 'Ba')…
# Index: 5, Error: 0.4786, # Steps: 46
# HBox(children=(NGLWidget(max_frame=45), VBox(children=(Dropdown(description='Show', options=('All', 'V', 'Ru',…
# Index: 6, Error: 0.1669, # Steps: 44
# HBox(children=(NGLWidget(max_frame=43), VBox(children=(Dropdown(description='Show', options=('All', 'Os', 'As'…
# Index: 7, Error: 0.1032, # Steps: 36
# HBox(children=(NGLWidget(max_frame=35), VBox(children=(Dropdown(description='Show', options=('All', 'Nd', 'Os'…
# Index: 8, Error: 0.1280, # Steps: 35
# HBox(children=(NGLWidget(max_frame=34), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'Pt',…
# Index: 9, Error: 0.1872, # Steps: 29
# HBox(children=(NGLWidget(max_frame=28), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'Rb',…
# Index: 10, Error: 0.3945, # Steps: 26
# HBox(children=(NGLWidget(max_frame=25), VBox(children=(Dropdown(description='Show', options=('All', 'Fe', 'Ir'…
