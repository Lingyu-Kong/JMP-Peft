# %%
import os

os.environ["LL_DISABLE_TYPECHECKING"] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"


import ll
import rich
import torch

ll.pretty()

torch.no_grad().__enter__()
torch.inference_mode().__enter__()
# Out:
# TensorBoard/TensorBoardX not found. Disabling TensorBoardLogger. Please install TensorBoard with `pip install tensorboard` or TensorBoardX with `pip install tensorboardx` to enable TensorBoard logging.

# %%
from jmppeft.tasks.finetune.base import FinetuneMatBenchDiscoveryIS2REDatasetConfig

dataset_config = FinetuneMatBenchDiscoveryIS2REDatasetConfig(
    # sample_n=DatasetSampleNConfig(sample_n=16, seed=42)
)
print(dataset_config)

dataset_og = dataset_config.create_dataset()
dataset_og, len(dataset_og)
# Out:
# [14:16:49] CRITICAL Type checking is disabled due to the environment variable                       ]8;id=961634;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/ll/src/ll/typecheck.py\typecheck.py]8;;\:]8;id=266053;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/ll/src/ll/typecheck.py#55\55]8;;\
#                     LL_DISABLE_TYPECHECKING.
# [14:16:50] INFO     PyTorch version 2.2.2 available.                                                   ]8;id=268551;file:///net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/datasets/config.py\config.py]8;;\:]8;id=687431;file:///net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/datasets/config.py#58\58]8;;\
# Loading 'wbm_summary' from cached file at '/nethome/nsg6/.cache/matbench-discovery/1.0.0/wbm/2023-12-13-wbm-summary.csv.gz'
# (<jmppeft.datasets.mpd_is2re.MatBenchDiscoveryIS2REDataset at 0x7fdcdf9606d0>,
#  256963)

# %%
from pathlib import Path

run_id = "9ruj4euu"
ckpt_path = Path(
    f"/net/csefiles/coc-fung-cluster/nima/shared/experiment-data/lltrainer/{run_id}/checkpoint/last.ckpt"
)
# If the file is a symlink, get the target
if ckpt_path.is_symlink():
    print(f"Symlink found {ckpt_path} => {ckpt_path.resolve()}")
    ckpt_path = ckpt_path.resolve()

ckpt_path
# Out:
# Symlink found /net/csefiles/coc-fung-cluster/nima/shared/experiment-data/lltrainer/9ruj4euu/checkpoint/last.ckpt => /net/csefiles/coc-fung-cluster/nima/shared/experiment-data/lltrainer/9ruj4euu/checkpoint/epoch=13-step=202832-val_matbench_discovery_force_mae=0.03905104473233223.ckpt
# Path('/net/csefiles/coc-fung-cluster/nima/shared/experiment-data/lltrainer/9ruj4euu/checkpoint/epoch=13-step=202832-val_matbench_discovery_force_mae=0.03905104473233223.ckpt')

# %%
from jmppeft.tasks.finetune import matbench_discovery as M


def _update_dataset_(dataset_config):
    energy_column_mapping = {}
    if (energy_column := dataset_config.pop("energy_column", None)) is not None:
        energy_column_mapping["y"] = energy_column
    if (
        relaxed_energy_column := dataset_config.pop("relaxed_energy_column", None)
    ) is not None:
        energy_column_mapping["y_relaxed"] = relaxed_energy_column
    dataset_config["energy_column_mapping"] = energy_column_mapping


hparams = torch.load(ckpt_path)["hyper_parameters"]
_update_dataset_(hparams["train_dataset"])
_update_dataset_(hparams["val_dataset"])
_update_dataset_(hparams["test_dataset"])

default_dtype = torch.float32
model = M.MatbenchDiscoveryModel.load_checkpoint(
    ckpt_path,
    hparams=hparams,
    map_location="cuda",
)
model = model.to(default_dtype)
model
# Out:
# [14:17:20] CRITICAL Using regular backbone                                                              ]8;id=966152;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py\base.py]8;;\:]8;id=873663;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py#605\605]8;;\
# Unrecognized arguments:  dict_keys(['name', 'learnable_rbf', 'learnable_rbf_stds', 'unique_basis_per_layer', 'dropout', 'edge_dropout', 'ln_per_layer', 'scale_factor_to_ln'])
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=557318;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=257547;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=833929;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=164545;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=276457;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=881043;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=115385;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=791735;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=542912;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=200170;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=294278;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=679770;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
#            INFO     [RadialBasis] Using absolute cutoff of 12.0 Angstroms.       ]8;id=101323;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py\radial_basis_dynamic_cutoff.py]8;;\:]8;id=174083;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/layers/radial_basis_dynamic_cutoff.py#213\213]8;;\
# [14:17:23] CRITICAL Constructed backbone with dlora=None                                                ]8;id=191714;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py\base.py]8;;\:]8;id=715756;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py#616\616]8;;\
#            INFO     Registered 12 shared parameters                                         ]8;id=742807;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/ll/src/ll/model/modules/shared_parameters.py\shared_parameters.py]8;;\:]8;id=484988;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/ll/src/ll/model/modules/shared_parameters.py#72\72]8;;\
#            INFO     List of ignored parameters: []                                                      ]8;id=106344;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py\base.py]8;;\:]8;id=677968;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py#694\694]8;;\
#            CRITICAL Freezing 0 parameters (0.00%) out of 40,983,796 total parameters (40,983,796        ]8;id=216534;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py\base.py]8;;\:]8;id=241486;file:///net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py#923\923]8;;\
#                     trainable)
# MatbenchDiscoveryModel(config=MatbenchDiscoveryConfig(name=mptrj-jmps-direct-bsz100, project=jmp_mptrj), device=cuda:0)

# %%
from collections import Counter

import jmppeft.modules.dataset.dataset_transform as DT
import torch.utils._pytree as tree
from lightning.fabric.utilities.apply_func import move_data_to_device
from torch_geometric.data import Batch, Data


def data_transform(data: Data):
    data = model.data_transform(data)
    data = Data.from_dict(
        tree.tree_map(
            lambda x: x.type(default_dtype)
            if torch.is_tensor(x) and torch.is_floating_point(x)
            else x,
            data.to_dict(),
        )
    )
    return data


def composition(data: Batch):
    return dict(Counter(data.atomic_numbers.tolist()))


num_items = 1024

dataset = DT.transform(dataset_og, data_transform)
dataset = DT.sample_n_transform(dataset, n=num_items, seed=42)


idx = 32
data = Batch.from_data_list([dataset[idx]])
rich.print(data.to_dict(), composition(data))
# Out:
# {
#     'pos': tensor[11, 3] n=33 x∈[-4.287, 6.937] μ=1.412 σ=2.423,
#     'id': ['wbm-3-72883'],
#     'atomic_numbers': tensor[11] i64 x∈[50, 79] μ=62.000 σ=14.269,
#     'cell': tensor[1, 3, 3] n=9 x∈[-3.509, 6.938] μ=1.065 σ=4.112 [[[6.029, 0., -3.509], [-2.037, 5.674, -3.509],
# [0., 0., 6.938]]],
#     'y_formation': tensor[1] [-0.236],
#     'y_formation_correction': tensor[1] [0.],
#     'y_above_hull': tensor[1] [0.093],
#     'natoms': tensor[1] i64 [11],
#     'tags': tensor[11] i64 x∈[2, 2] μ=2.000 σ=0.,
#     'fixed': tensor[11] bool all_zeros,
#     'batch': tensor[11] i64 all_zeros,
#     'ptr': tensor[2] i64 μ=5.500 σ=7.778 [0, 11]
# }
# {66: 1, 50: 6, 79: 4}

# %%
from jmppeft.modules.relaxer import ModelOutput, Relaxer
from matbench_discovery.energy import get_e_form_per_atom

USE_Y_RELAXED = True


def model_fn(data, initial_data, *, use_y_relaxed: bool = USE_Y_RELAXED) -> ModelOutput:
    model_out = model.forward_denormalized(data)

    energy = model_out["y_relaxed"] if use_y_relaxed else model_out["y"]
    # energy = model_out["y"]
    # relaxed_energy = model_out["y_relaxed"]
    forces = model_out["force"]
    stress = model_out["stress"]

    # JMP-S v2 energy is corrected_energy, i.e., DFT total energy
    # This energy is now DFT total energy, we need to convert it to formation energy per atom
    energy = get_e_form_per_atom(
        {
            "composition": composition(data),
            "energy": energy,
        }
    )
    assert isinstance(energy, torch.Tensor)
    # assert isinstance(relaxed_energy, torch.Tensor)

    # Add the correction factor
    if False:
        energy += initial_data.y_formation_correction.item()

    # energy, relaxed_energy = tree.tree_map(
    #     lambda energy: energy.view(1), (energy, relaxed_energy)
    # )
    energy = energy.view(1)
    forces = forces.view(-1, 3)
    stress = stress.view(1, 3, 3) if stress.numel() == 9 else stress.view(1, 6)

    return {
        "energy": energy,
        # "relaxed_energy": relaxed_energy,
        "forces": forces,
        "stress": stress,
    }


data = move_data_to_device(data, model.device)
model_fn(data, data)
# Out:
# {'energy': tensor[1] cuda:0 [-0.178],
#  'forces': tensor[11, 3] n=33 x∈[-0.525, 0.427] μ=-0.000 σ=0.276 cuda:0,
#  'stress': tensor[1, 3, 3] n=9 x∈[-0.115, -0.002] μ=-0.040 σ=0.055 cuda:0 [[[-0.112, -0.002, -0.004], [-0.002, -0.113, -0.005], [-0.004, -0.005, -0.115]]]}

# %%
from jmppeft.modules.relaxer import RelaxerConfig

config = RelaxerConfig(
    compute_stress=True,
    stress_weight=0.1,
    optimizer="FIRE",
    fmax=0.05,
    ase_filter="frechet",
)
relaxer = Relaxer(
    config=config,
    model=model_fn,
    collate_fn=model.collate_fn,
    device=model.device,
)
rich.print(data.y_formation)
relax_out = relaxer.relax(data)
# rich.print(relax_out)

energy = relax_out.atoms.get_total_energy()
rich.print(energy, data.y_formation)
# Out:
# tensor[1] cuda:0 [-0.236]
#       Step     Time          Energy          fmax
# FIRE:    0 14:17:24       -0.178493        0.618104
# FIRE:    1 14:17:24       -0.184624        0.443483
# FIRE:    2 14:17:24       -0.189731        0.243220
# FIRE:    3 14:17:24       -0.196843        0.240160
# FIRE:    4 14:17:24       -0.206898        0.381866
# FIRE:    5 14:17:24       -0.213569        0.446014
# FIRE:    6 14:17:24       -0.211816        0.365210
# FIRE:    7 14:17:24       -0.225216        0.228593
# FIRE:    8 14:17:25       -0.212263        0.201816
# FIRE:    9 14:17:25       -0.207363        0.191520
# FIRE:   10 14:17:25       -0.205297        0.201810
# FIRE:   11 14:17:25       -0.205400        0.164929
# FIRE:   12 14:17:25       -0.231709        0.143650
# FIRE:   13 14:17:25       -0.248433        0.212884
# FIRE:   14 14:17:25       -0.237526        0.241347
# FIRE:   15 14:17:25       -0.216050        0.158709
# FIRE:   16 14:17:25       -0.177974        0.228640
# FIRE:   17 14:17:25       -0.159583        0.223314
# FIRE:   18 14:17:25       -0.161501        0.258610
# FIRE:   19 14:17:25       -0.172934        0.329021
# FIRE:   20 14:17:25       -0.191197        0.260547
# FIRE:   21 14:17:25       -0.213588        0.294365
# FIRE:   22 14:17:25       -0.229009        0.254288
# FIRE:   23 14:17:25       -0.234924        0.196356
# FIRE:   24 14:17:26       -0.233094        0.158293
# FIRE:   25 14:17:26       -0.226304        0.052138
# FIRE:   26 14:17:26       -0.227632        0.037543
# -0.22763165831565857 tensor[1] cuda:0 [-0.236]

# %%
from collections import defaultdict

import numpy as np
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

config = RelaxerConfig(
    compute_stress=True,
    stress_weight=0.1,
    optimizer="FIRE",
    # fmax=0.01,
    # ase_filter="frechet",
    fmax=0.05,
    ase_filter="exp",
)
relaxer = Relaxer(
    config=config,
    model=model_fn,
    collate_fn=model.collate_fn,
    device=model.device,
)

dl = DataLoader(
    dataset,
    batch_size=1,
    collate_fn=model.collate_fn,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

preds_targets = defaultdict[str, list[tuple[float, float]]](lambda: [])

for data in tqdm(dl, total=len(dl)):
    data = move_data_to_device(data, model.device)
    relax_out = relaxer.relax(data, verbose=False)

    e_form_true = data.y_formation.item()
    e_form_pred = relax_out.atoms.get_total_energy()
    preds_targets["e_form"].append((e_form_pred, e_form_true))

    e_above_hull_true = data.y_above_hull.item()
    e_above_hull_pred = e_above_hull_true + (e_form_pred - e_form_true)
    preds_targets["e_above_hull"].append((e_above_hull_pred, e_above_hull_true))

    nsteps = len(relax_out.trajectory.frames)

    print(
        f"# Steps: {nsteps}; e_form: P={e_form_pred:.4f}, GT={e_form_true:.4f}, Δ={abs(e_form_pred - e_form_true):.4f}"
    )
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# # Steps: 18; e_form: P=-0.8765, GT=-0.8008, Δ=0.0757
# # Steps: 30; e_form: P=0.1099, GT=-0.0220, Δ=0.1319
# # Steps: 11; e_form: P=-0.5945, GT=-0.6088, Δ=0.0142

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matbench_discovery.metrics import stable_metrics

sns.set_context("notebook")

e_form_true, e_form_pred = zip(*preds_targets["e_form"])
e_form_true = np.array(e_form_true)
e_form_pred = np.array(e_form_pred)

e_above_hull_true, e_above_hull_pred = zip(*preds_targets["e_above_hull"])
e_above_hull_true = np.array(e_above_hull_true)
e_above_hull_pred = np.array(e_above_hull_pred)

rich.print(
    {
        "e_form": {"pred": e_form_pred.shape, "true": e_form_true.shape},
        "e_above_hull": {
            "pred": e_above_hull_pred.shape,
            "true": e_above_hull_true.shape,
        },
    }
)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes = axes.flatten()

ax = axes[0]
sns.histplot(e_form_pred, label="Predicted formation energy", ax=ax)
sns.histplot(e_form_true, label="True formation energy", ax=ax)
ax.legend()

ax = axes[1]
sns.scatterplot(y=e_form_true, x=e_form_pred, ax=ax)
ax.set_xlabel("Predicted formation energy")
ax.set_ylabel("True formation energy")

fig.tight_layout()
plt.show()

metrics = stable_metrics(e_above_hull_true, e_above_hull_pred, fillna=False)
rich.print(metrics)
# Out:
# {'e_form': {'pred': (1024,), 'true': (1024,)}, 'e_above_hull': {'pred': (1024,), 'true': (1024,)}}
# /tmp/ipykernel_3501241/3062433637.py:38: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# {
#     'F1': 0.596244131455399,
#     'DAF': 2.988235294117647,
#     'Precision': 0.7470588235294118,
#     'Recall': 0.49609375,
#     'Accuracy': 0.83203125,
#     'TPR': 0.49609375,
#     'FPR': 0.055989583333333336,
#     'TNR': 0.9440104166666666,
#     'FNR': 0.50390625,
#     'TP': 127,
#     'FP': 43,
#     'TN': 725,
#     'FN': 129,
#     'MAE': 0.060424236244216445,
#     'RMSE': 0.08839768190307308,
#     'R2': 0.8999186534585991
# }

# %%
from collections import defaultdict
from functools import partial

import numpy as np
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

config = RelaxerConfig(
    compute_stress=True,
    stress_weight=0.1,
    optimizer="FIRE",
    # fmax=0.01,
    # ase_filter="frechet",
    fmax=0.05,
    ase_filter="exp",
)
relaxer = Relaxer(
    config=config,
    model=partial(model_fn, use_y_relaxed=False),
    collate_fn=model.collate_fn,
    device=model.device,
)

dl = DataLoader(
    dataset,
    batch_size=1,
    collate_fn=model.collate_fn,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
)

preds_targets = defaultdict[str, list[tuple[float, float]]](lambda: [])

for data in tqdm(dl, total=len(dl)):
    data = move_data_to_device(data, model.device)
    relax_out = relaxer.relax(data, verbose=False)

    e_form_true = data.y_formation.item()
    e_form_pred = relax_out.atoms.get_total_energy()
    preds_targets["e_form"].append((e_form_pred, e_form_true))

    e_above_hull_true = data.y_above_hull.item()
    e_above_hull_pred = e_above_hull_true + (e_form_pred - e_form_true)
    preds_targets["e_above_hull"].append((e_above_hull_pred, e_above_hull_true))

    nsteps = len(relax_out.trajectory.frames)

    print(
        f"# Steps: {nsteps}; e_form: P={e_form_pred:.4f}, GT={e_form_true:.4f}, Δ={abs(e_form_pred - e_form_true):.4f}"
    )
# Out:
#   0%|          | 0/1024 [00:00<?, ?it/s]
# # Steps: 32; e_form: P=-0.8683, GT=-0.8008, Δ=0.0674
# # Steps: 46; e_form: P=0.0898, GT=-0.0220, Δ=0.1118
# # Steps: 34; e_form: P=-0.6808, GT=-0.6088, Δ=0.0720
# # Steps: 139; e_form: P=-0.1897, GT=-0.1544, Δ=0.0353
# # Steps: 68; e_form: P=-0.2621, GT=-0.1154, Δ=0.1467
# # Steps: 49; e_form: P=-0.3178, GT=-0.3905, Δ=0.0726
# # Steps: 7; e_form: P=-0.2022, GT=-0.2468, Δ=0.0446
# # Steps: 32; e_form: P=-0.5408, GT=-0.4542, Δ=0.0866
# # Steps: 8; e_form: P=-1.8716, GT=-1.9089, Δ=0.0373
# # Steps: 14; e_form: P=-0.1960, GT=-0.1224, Δ=0.0737
# # Steps: 10; e_form: P=-1.7839, GT=-1.8781, Δ=0.0942
# # Steps: 56; e_form: P=-1.5394, GT=-1.6101, Δ=0.0706
# # Steps: 34; e_form: P=-1.8830, GT=-1.8180, Δ=0.0650
# # Steps: 4; e_form: P=-0.2295, GT=-0.3333, Δ=0.1037
# # Steps: 17; e_form: P=-0.7500, GT=-0.7299, Δ=0.0201
# # Steps: 21; e_form: P=-0.0087, GT=-0.0433, Δ=0.0346
# # Steps: 29; e_form: P=-0.5687, GT=-0.5591, Δ=0.0096
# # Steps: 26; e_form: P=-3.1841, GT=-3.0844, Δ=0.0997
# # Steps: 25; e_form: P=-1.5585, GT=-1.7130, Δ=0.1545
# # Steps: 30; e_form: P=-2.6180, GT=-2.8650, Δ=0.2470
# # Steps: 26; e_form: P=-2.3324, GT=-2.3807, Δ=0.0483
# # Steps: 37; e_form: P=-0.6562, GT=-0.6476, Δ=0.0085
# # Steps: 17; e_form: P=-0.4688, GT=-0.4119, Δ=0.0569
# # Steps: 15; e_form: P=0.0728, GT=-0.0061, Δ=0.0789
# # Steps: 40; e_form: P=-0.5639, GT=-0.5812, Δ=0.0173
# # Steps: 30; e_form: P=-0.5189, GT=-0.4616, Δ=0.0574
# # Steps: 53; e_form: P=-1.0656, GT=-1.0945, Δ=0.0290
# # Steps: 48; e_form: P=-2.1302, GT=-2.0012, Δ=0.1291
# # Steps: 21; e_form: P=-2.2458, GT=-2.1870, Δ=0.0588
# # Steps: 21; e_form: P=-0.6050, GT=-0.7626, Δ=0.1575
# # Steps: 44; e_form: P=-1.9055, GT=-1.9263, Δ=0.0209
# # Steps: 9; e_form: P=-0.1006, GT=-0.1229, Δ=0.0223
# # Steps: 33; e_form: P=-0.2035, GT=-0.2364, Δ=0.0329
# # Steps: 34; e_form: P=-0.2058, GT=-0.1713, Δ=0.0345
# # Steps: 14; e_form: P=-0.5425, GT=-0.5257, Δ=0.0167
# # Steps: 27; e_form: P=-0.3997, GT=-0.4484, Δ=0.0487
# # Steps: 43; e_form: P=-0.8826, GT=-0.9048, Δ=0.0221
# # Steps: 31; e_form: P=0.0289, GT=-0.2392, Δ=0.2682
# # Steps: 62; e_form: P=-0.5975, GT=-0.6018, Δ=0.0042
# # Steps: 13; e_form: P=-0.3629, GT=-0.4596, Δ=0.0967
# # Steps: 32; e_form: P=0.0054, GT=0.0228, Δ=0.0173
# # Steps: 19; e_form: P=-0.5927, GT=-0.6482, Δ=0.0555
# # Steps: 29; e_form: P=-0.3233, GT=-0.3384, Δ=0.0150
# # Steps: 62; e_form: P=0.1165, GT=0.0744, Δ=0.0421
# # Steps: 11; e_form: P=-0.3525, GT=-0.2690, Δ=0.0835
# # Steps: 52; e_form: P=-3.0371, GT=-2.9990, Δ=0.0381
# # Steps: 48; e_form: P=-1.0888, GT=-1.0127, Δ=0.0762
# # Steps: 502; e_form: P=-0.4160, GT=-0.4317, Δ=0.0157
# # Steps: 8; e_form: P=-0.8575, GT=-0.8011, Δ=0.0564
# # Steps: 36; e_form: P=-3.3068, GT=-3.2035, Δ=0.1033
# # Steps: 33; e_form: P=-0.1879, GT=-0.1638, Δ=0.0241
# # Steps: 44; e_form: P=-1.3972, GT=-1.3358, Δ=0.0614
# # Steps: 19; e_form: P=-1.1337, GT=-1.1612, Δ=0.0275
# # Steps: 2; e_form: P=-0.0961, GT=-0.1789, Δ=0.0828
# # Steps: 44; e_form: P=-0.3641, GT=-0.3186, Δ=0.0455
# # Steps: 27; e_form: P=0.4263, GT=0.4827, Δ=0.0564
# # Steps: 30; e_form: P=-1.5519, GT=-1.7589, Δ=0.2070
# # Steps: 18; e_form: P=-0.2884, GT=-0.2765, Δ=0.0118
# # Steps: 18; e_form: P=-3.3341, GT=-3.3041, Δ=0.0300
# # Steps: 10; e_form: P=-0.3161, GT=-0.3660, Δ=0.0499
# # Steps: 33; e_form: P=-0.7035, GT=-0.6369, Δ=0.0666
# # Steps: 56; e_form: P=-2.6061, GT=-2.6335, Δ=0.0275
# # Steps: 34; e_form: P=-1.7923, GT=-1.5591, Δ=0.2332
# # Steps: 28; e_form: P=0.1385, GT=0.1733, Δ=0.0348
# # Steps: 53; e_form: P=-0.2514, GT=-0.1928, Δ=0.0586
# # Steps: 36; e_form: P=0.0412, GT=0.0012, Δ=0.0399
# # Steps: 36; e_form: P=-0.8511, GT=-0.8882, Δ=0.0371
# # Steps: 2; e_form: P=-0.5945, GT=-0.5519, Δ=0.0426
# # Steps: 123; e_form: P=-2.1527, GT=-2.1893, Δ=0.0366
# # Steps: 27; e_form: P=-0.0535, GT=-0.0716, Δ=0.0181
# # Steps: 13; e_form: P=-0.0057, GT=0.0055, Δ=0.0112
# # Steps: 26; e_form: P=0.1722, GT=0.2183, Δ=0.0461
# # Steps: 39; e_form: P=0.0082, GT=-0.0323, Δ=0.0405
# # Steps: 33; e_form: P=-1.2319, GT=-1.2014, Δ=0.0306
# # Steps: 19; e_form: P=0.4263, GT=0.3216, Δ=0.1047
# # Steps: 25; e_form: P=-3.7086, GT=-3.7061, Δ=0.0024
# # Steps: 17; e_form: P=-2.4200, GT=-2.3751, Δ=0.0449
# # Steps: 17; e_form: P=-0.6252, GT=-0.4485, Δ=0.1767
# # Steps: 60; e_form: P=-0.7024, GT=-1.1411, Δ=0.4388
# # Steps: 2; e_form: P=0.4112, GT=0.3030, Δ=0.1082
# # Steps: 4; e_form: P=-0.2550, GT=-0.2621, Δ=0.0071
# # Steps: 13; e_form: P=0.0800, GT=0.1009, Δ=0.0209
# # Steps: 58; e_form: P=-0.2497, GT=-0.2268, Δ=0.0229
# # Steps: 6; e_form: P=-0.4715, GT=-0.4042, Δ=0.0673
# # Steps: 51; e_form: P=-0.7535, GT=-0.7625, Δ=0.0090
# # Steps: 33; e_form: P=-0.0941, GT=-0.0655, Δ=0.0286
# # Steps: 19; e_form: P=0.0445, GT=0.2421, Δ=0.1976
# # Steps: 16; e_form: P=-0.5662, GT=-0.5644, Δ=0.0018
# # Steps: 15; e_form: P=-0.8770, GT=-0.9880, Δ=0.1110
# # Steps: 26; e_form: P=0.0932, GT=0.0243, Δ=0.0689
# # Steps: 32; e_form: P=-0.1100, GT=-0.2068, Δ=0.0968
# # Steps: 39; e_form: P=-1.0507, GT=-1.0161, Δ=0.0347
# # Steps: 48; e_form: P=-0.6155, GT=-0.6459, Δ=0.0304
# # Steps: 16; e_form: P=0.0137, GT=-0.0518, Δ=0.0655
# # Steps: 16; e_form: P=0.0824, GT=0.2311, Δ=0.1487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 37
#      35 for data in tqdm(dl, total=len(dl)):
#      36     data = move_data_to_device(data, model.device)
# ---> 37     relax_out = relaxer.relax(data, verbose=False)
#      39     e_form_true = data.y_formation.item()
#      40     e_form_pred = relax_out.atoms.get_total_energy()
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/modules/relaxer/_mixin.py:279, in Relaxer.relax(self, graph, verbose)
#     268 atoms = self._graph_to_atoms(graph)
#     270 relaxer = _Relaxer(
#     271     potential=partial(self._potential, initial_graph=graph),
#     272     graph_converter=partial(self._atoms_to_graph, initial_graph=graph),
#    (...)
#     277     ase_filter=self.config.ase_filter,
#     278 )
# --> 279 return relaxer.relax(
#     280     atoms,
#     281     fmax=self.config.fmax,
#     282     steps=self.config.steps,
#     283     traj_file=str(self.config.traj_file.absolute())
#     284     if self.config.traj_file
#     285     else None,
#     286     interval=self.config.interval,
#     287     verbose=verbose,
#     288     **self.config.optimizer_kwargs,
#     289 )
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/modules/relaxer/_relaxer.py:332, in Relaxer.relax(self, atoms, fmax, steps, traj_file, interval, verbose, **kwargs)
#     330     optimizer = self.optimizer_cls(atoms, **kwargs)
#     331     optimizer.attach(obs, interval=interval)
# --> 332     optimizer.run(fmax=fmax, steps=steps)
#     333     obs()
#     334 if traj_file is not None:
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/optimize/optimize.py:430, in Optimizer.run(self, fmax, steps)
#     415 """Run optimizer.
#     416
#     417 Parameters
#    (...)
#     427     True if the forces on atoms are converged.
#     428 """
#     429 self.fmax = fmax
# --> 430 return Dynamics.run(self, steps=steps)
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/optimize/optimize.py:275, in Dynamics.run(self, steps)
#     257 def run(self, steps=DEFAULT_MAX_STEPS):
#     258     """Run dynamics algorithm.
#     259
#     260     This method will return when the forces on all individual
#    (...)
#     272         True if the forces on atoms are converged.
#     273     """
# --> 275     for converged in Dynamics.irun(self, steps=steps):
#     276         pass
#     277     return converged
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/optimize/optimize.py:250, in Dynamics.irun(self, steps)
#     247 self.nsteps += 1
#     249 # log the step
# --> 250 self.log()
#     251 self.call_observers()
#     253 # check convergence
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/optimize/optimize.py:440, in Optimizer.log(self, forces)
#     438 def log(self, forces=None):
#     439     if forces is None:
# --> 440         forces = self.optimizable.get_forces()
#     441     fmax = sqrt((forces ** 2).sum(axis=1).max())
#     442     e = self.optimizable.get_potential_energy()
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/filters.py:29, in OptimizableFilter.get_forces(self)
#      28 def get_forces(self):
# ---> 29     return self.filterobj.get_forces()
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/filters.py:612, in FrechetCellFilter.get_forces(self, **kwargs)
#     609 def get_forces(self, **kwargs):
#     610     # forces on atoms are same as UnitCellFilter, we just
#     611     # need to modify the stress contribution
# --> 612     stress = self.atoms.get_stress(**kwargs)
#     613     volume = self.atoms.get_volume()
#     614     virial = -volume * (voigt_6_to_full_3x3_stress(stress) +
#     615                         np.diag([self.scalar_pressure] * 3))
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/atoms.py:844, in Atoms.get_stress(self, voigt, apply_constraint, include_ideal_gas)
#     841 if self._calc is None:
#     842     raise RuntimeError('Atoms object has no calculator.')
# --> 844 stress = self._calc.get_stress(self)
#     845 shape = stress.shape
#     847 if shape == (3, 3):
#     848     # Convert to the Voigt form before possibly applying
#     849     # constraints and adding the dynamic part of the stress
#     850     # (the "ideal gas contribution").
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/calculators/abc.py:33, in GetPropertiesMixin.get_stress(self, atoms)
#      32 def get_stress(self, atoms=None):
# ---> 33     return self.get_property('stress', atoms)
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/ase/calculators/calculator.py:538, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     535     if self.use_cache:
#     536         self.atoms = atoms.copy()
# --> 538     self.calculate(atoms, [name], system_changes)
#     540 if name not in self.results:
#     541     # For some reason the calculator was not able to do what we want,
#     542     # and that is OK.
#     543     raise PropertyNotImplementedError(
#     544         '{} not present in this ' 'calculation'.format(name)
#     545     )
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/modules/relaxer/_relaxer.py:118, in Calculator.calculate(self, atoms, properties, system_changes)
#     113 super().calculate(
#     114     atoms=atoms, properties=properties, system_changes=system_changes
#     115 )
#     117 graph = self.graph_converter(atoms)
# --> 118 results = self.potential(graph)
#     119 self.results.update(
#     120     energy=results["energy"].numpy().ravel()[0],
#     121     free_energy=results["energy"].numpy().ravel()[0],
#     122     forces=results["forces"].numpy(),
#     123 )
#     124 # if (relaxed_energy := results.get("relaxed_energy")) is not None:
#     125 #     self.results.update(relaxed_energy=relaxed_energy.numpy().ravel()[0])
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/modules/relaxer/_mixin.py:238, in Relaxer._potential(self, graph, initial_graph)
#     234 graph = graph.to(self.device)
#     236 # Compute the energy and forces
#     237 # If self.model takes 2 arguments, pass the initial graph as well
# --> 238 model_out = self.model(graph, initial_graph)
#     239 energy = model_out["energy"]
#     240 forces = model_out["forces"]
#
# Cell In[6], line 8, in model_fn(data, initial_data, use_y_relaxed)
#       7 def model_fn(data, initial_data, *, use_y_relaxed: bool = USE_Y_RELAXED) -> ModelOutput:
# ----> 8     model_out = model.forward_denormalized(data)
#      10     energy = model_out["y_relaxed"] if use_y_relaxed else model_out["y"]
#      11     # energy = model_out["y"]
#      12     # relaxed_energy = model_out["y_relaxed"]
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/base.py:1126, in FinetuneModelBase.forward_denormalized(self, data, detach)
#    1125 def forward_denormalized(self, data: BaseData, detach: bool = True):
# -> 1126     preds = self(data)
#    1127     if detach:
#    1128         preds = {
#    1129             k: v.detach() if torch.is_tensor(v) else v for k, v in preds.items()
#    1130         }
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/tasks/finetune/energy_forces_base.py:236, in EnergyForcesModelBase.forward(self, data)
#     234 atomic_numbers = data.atomic_numbers - 1
#     235 h = self.embedding(atomic_numbers)  # (N, d_model)
# --> 236 out = cast(GOCBackboneOutput, self.backbone(data, h=h))
#     238 graph_preds: dict[str, torch.Tensor] = {}
#     239 node_preds: dict[str, torch.Tensor] = {}
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /net/csefiles/coc-fung-cluster/nima/miniforge3/envs/jmp-peft/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/backbone.py:849, in GemNetOCBackbone.forward(self, data, h)
#     836 if self.regress_forces and not self.direct_forces:
#     837     pos.requires_grad_(True)
#     839 (
#     840     main_graph,
#     841     a2a_graph,
#     842     a2ee2a_graph,
#     843     qint_graph,
#     844     id_swap,
#     845     trip_idx_e2e,
#     846     trip_idx_a2e,
#     847     trip_idx_e2a,
#     848     quad_idx,
# --> 849 ) = self.get_graphs_and_indices(data)
#     850 ll.ActSave(
#     851     {
#     852         "pos": pos,
#    (...)
#     856     }
#     857 )
#     858 idx_s, idx_t = main_graph["edge_index"]
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/backbone.py:679, in GemNetOCBackbone.get_graphs_and_indices(self, data)
#     677 # Symmetrize edges for swapping in symmetric message passing
#     678 if True:
# --> 679     main_graph, id_swap = self.symmetrize_edges(main_graph, data.batch)
#     680 else:
#     681     raise NotImplementedError
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/backbone.py:651, in GemNetOCBackbone.symmetrize_edges(self, graph, batch_idx)
#     649 order_edge_ids = torch.argsort(edge_ids)
#     650 inv_order_edge_ids = torch.argsort(order_edge_ids)
# --> 651 edge_ids_counter = get_edge_id(
#     652     new_graph["edge_index"].flip(0),
#     653     -new_graph["cell_offset"],
#     654     num_atoms,
#     655 )
#     656 order_edge_ids_counter = torch.argsort(edge_ids_counter)
#     657 id_swap = order_edge_ids_counter[inv_order_edge_ids]
#
# File /net/csefiles/coc-fung-cluster/nima/shared/repositories/jmp-peft/src/jmppeft/models/gemnet/utils.py:460, in get_edge_id(edge_idx, cell_offsets, num_atoms)
#     457 def get_edge_id(edge_idx, cell_offsets, num_atoms):
#     458     cell_basis = cell_offsets.max() - cell_offsets.min() + 1
#     459     cell_id = (
# --> 460         (cell_offsets * cell_offsets.new_tensor([[1, cell_basis, cell_basis**2]]))
#     461         .sum(-1)
#     462         .long()
#     463     )
#     464     edge_id = edge_idx[0] + edge_idx[1] * num_atoms + cell_id * num_atoms**2
#     465     return edge_id
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matbench_discovery.metrics import stable_metrics

sns.set_context("notebook")

e_form_true, e_form_pred = zip(*preds_targets["e_form"])
e_form_true = np.array(e_form_true)
e_form_pred = np.array(e_form_pred)

e_above_hull_true, e_above_hull_pred = zip(*preds_targets["e_above_hull"])
e_above_hull_true = np.array(e_above_hull_true)
e_above_hull_pred = np.array(e_above_hull_pred)

rich.print(
    {
        "e_form": {"pred": e_form_pred.shape, "true": e_form_true.shape},
        "e_above_hull": {
            "pred": e_above_hull_pred.shape,
            "true": e_above_hull_true.shape,
        },
    }
)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
axes = axes.flatten()

ax = axes[0]
sns.histplot(e_form_pred, label="Predicted formation energy", ax=ax)
sns.histplot(e_form_true, label="True formation energy", ax=ax)
ax.legend()

ax = axes[1]
sns.scatterplot(y=e_form_true, x=e_form_pred, ax=ax)
ax.set_xlabel("Predicted formation energy")
ax.set_ylabel("True formation energy")

fig.tight_layout()
plt.show()

metrics = stable_metrics(e_above_hull_true, e_above_hull_pred, fillna=False)
rich.print(metrics)
# Out:
# {'e_form': {'pred': (1024,), 'true': (1024,)}, 'e_above_hull': {'pred': (1024,), 'true': (1024,)}}
# /tmp/ipykernel_3361876/3062433637.py:38: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
# {
#     'F1': 0.7080745341614908,
#     'DAF': 4.517647058823529,
#     'Precision': 0.6705882352941176,
#     'Recall': 0.75,
#     'Accuracy': 0.908203125,
#     'TPR': 0.75,
#     'FPR': 0.06422018348623854,
#     'TNR': 0.9357798165137615,
#     'FNR': 0.25,
#     'TP': 114,
#     'FP': 56,
#     'TN': 816,
#     'FN': 38,
#     'MAE': 0.04739447414078768,
#     'RMSE': 0.08317770728162838,
#     'R2': 0.905135205131942
# }
